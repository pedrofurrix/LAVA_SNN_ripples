# %% [markdown]
# # SNN Evaluation on Real-Time Data
# In this notebook, we test the performance of trained SNNs on a real-time stream of data.
# Based (or copied) from Mesquita's [repository](https://github.com/monkin77/snn-torch/blob/master/src/hfo/5_detection/hfo_evaluation.ipynb)

# %%
# Show current directory
import os
curr_dir = os.getcwd()
print(curr_dir)

from collections import deque
# Out:
# c:\Users\NCN\Documents\PedroFelix\LAVA_SNN_ripples\snnTorch

# %% [markdown]
# ## Add Parent Directory to Path

# %%
import sys
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
# Add the grandparent directory to the system path
# grandparent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir, os.pardir))
sys.path.append(parent_dir)
print(sys.path)
# Out:
# ['c:\\nrn\\lib\\python', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\python39.zip', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\DLLs', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples', '', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib\\site-packages', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib\\site-packages\\win32', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib\\site-packages\\win32\\lib', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib\\site-packages\\Pythonwin', 'c:\\Users\\NCN\\Documents\\PedroFelix\\LAVA_SNN_ripples']

# %% [markdown]
# ## Check if Cuda is available

# %%
import torch
import numpy as np

# Check CUDA Installation
print(torch.cuda.is_available())

# Get the number of available GPUs
num_gpus = torch.cuda.device_count()
print(f"Number of GPUs: {num_gpus}")

# Get information about each GPU
for i in range(num_gpus):
    device_props = torch.cuda.get_device_properties(i)
    print(f"\nGPU {i}:")
    print(f"  Name: {device_props.name}")
    print(f"  Total memory: {device_props.total_memory / 1024**3:.2f} GB")
    print(f"  Multiprocessor count: {device_props.multi_processor_count}")
    print(f"  Major compute capability: {device_props.major}")
    print(f"  Minor compute capability: {device_props.minor}")
# Out:
# False
# Number of GPUs: 0

# %% [markdown]
# ## Define the Device that will be used to train the SNN

# %%
# Set the device to be used
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")     # torch.device("cpu") #

print("device: ", device)
# Out:
# device:  cpu

# %% [markdown]
# ## Define Problem and Simulation Parameters

# %%
# ----- Simulation Time Parameters -----
dt = 1                         # Time between two timesteps (ms), a.k.a. virtual time step interval. (NOT ALIGNED WITH THE SAMPLING RATE OF THE INPUT DATA (2048 Hz)
init_offset = 0 # 900 # 33400      #

# %%
# unit: timesteps (ms) - The time window after the GT annotation where the network should predict the burst (GT_time, GT_time + PRED_CAUSALITY_WINDOW)
# This is needed to give the network some extra time steps to increase the membrane potential and spike
RIPPLE_DETECTION_OFFSET = [18, 45, 31, 20]
PRED_CAUSALITY_WINDOW = int(5)     # Giving PRED_CAUSALITY_WINDOW ms for the network to update its inner state and spike  
# in timesteps (ms) - Max time from the Insertion Timing to the GT annotation

MAX_DETECTION_OFFSET = int(RIPPLE_DETECTION_OFFSET[1]) * 1.5 + PRED_CAUSALITY_WINDOW   # in timesteps (ms)

print(f"PRED_CAUSALITY_WINDOW: {PRED_CAUSALITY_WINDOW}")
print(f"MAX_DETECTION_OFFSET: {MAX_DETECTION_OFFSET} ms")
# Out:
# PRED_CAUSALITY_WINDOW: 5
# MAX_DETECTION_OFFSET: 72.5 ms

# %% [markdown]
# ## Read the Input Data and the Ground Truth

# %%
downsampled_fs="30000_1000"
data_dir=os.path.join(parent_dir,"extract_Nripples","train_pedro","dataset_up_down",str(downsampled_fs))

# %%
concat_data=np.load(os.path.join(data_dir,"concat_spikes.npy"),allow_pickle=True)
ripples_GT=np.load(os.path.join(data_dir,"concat_ripples.npy"),allow_pickle=True)

# %%
print("Number of UP spikes: ", np.sum(concat_data[:, 0]))
print("Number of DN spikes: ", np.sum(concat_data[:, 1]))
# Out:
# Number of UP spikes:  275624
# Number of DN spikes:  277940

# %% [markdown]
# ## Point of Situation
#
# Right now, we have the following:
#
# -  `concat_data` of shape (num_steps, 2) containing the UP and DN spikes.
# - `ripples_GT` of shape (num_gt_events,2) containing the timestamps (beginning and end) of every ripple

# %%
# Define the number of total timesteps
total_num_steps = concat_data.shape[0]
num_hfo_events = ripples_GT.shape[0]
num_hfo_timesteps=np.sum(ripples_GT[:, 1] - ripples_GT[:, 0])
print(f"Number of HFO Events: {num_hfo_events}")
print(f"Total number of timesteps: {total_num_steps}")
print("Num of Ripple timesteps:", num_hfo_timesteps)
# Out:
# Number of HFO Events: 3664
# Total number of timesteps: 8321032
# Num of Ripple timesteps: 185776

# %%
# Transform ripples_GT into the time of onset...
ripples_start=ripples_GT[:,0]
print("Ripples start: ", ripples_start[:10])
# Out:
# Ripples start:  [ 568  969 1629 3952 5006 5225 5772 6039 6479 6869]

# %%
distance_ripples=ripples_start[1:] - ripples_start[:-1]
average_distance=np.mean(distance_ripples)
median_distance=np.median(distance_ripples)
min_distance=np.min(distance_ripples)
percentile_25=np.percentile(distance_ripples, 10)                            
print(f"Average distance between ripples: {average_distance} ms")
print(f"Median distance between ripples: {median_distance} ms")
print(f"Minimum distance between ripples: {min_distance} ms")
print(f"25th Percentile distance between ripples: {percentile_25} ms")
# Out:
# Average distance between ripples: 2271.054873054873 ms
# Median distance between ripples: 475.0 ms
# Minimum distance between ripples: 62 ms
# 25th Percentile distance between ripples: 128.0 ms

# %%
# ------------------- Network Parameters -------------------
# We know that 2 relevant events do not occur within the confidence window of an HFO event, so we set the refractory period accordingly
refrac_period_fp =100 # floor(MAX_DETECTION_OFFSET / dt)   # Number of time-steps for the refractory period
refrac_period_gt= 100
print(f"Refractory Period: {refrac_period_gt} steps")
print(f"Refractory Period: {refrac_period_fp} steps")
# Out:
# Refractory Period: 100 steps
# Refractory Period: 100 steps

# %% [markdown]
# ## Create the Dataset and Dataloader to user tensor-ready data

# %%
from torch.utils.data import TensorDataset, DataLoader

# Convert numpy arrays to PyTorch tensors and move them to the selected device
input_tensor = torch.tensor(concat_data,dtype=torch.float32).to(device)
gt_tensor=torch.tensor(ripples_start,dtype=torch.float32).to(device)
# gt_tensor = torch.from_numpy(ripples_start).to(device)
# gt_tensor = torch.from_numpy(ripples_start).to(device)

# %%
# Show the shape of the tensors
print("Input tensor shape: ", input_tensor.shape)
print("GT tensor shape: ", gt_tensor.shape)
# Out:
# Input tensor shape:  torch.Size([8321032, 2])
# GT tensor shape:  torch.Size([3664])

# %% [markdown]
# ## Define the SNN Architecture
# Similar to what we trained before

# %%
import snntorch as snn
import torch.nn as nn
from snntorch import surrogate

# Global Parameters
v_thr = 1.0
placeholder_val = 0.5

# Define the surrogate gradient function to propagate spikes through the network
spike_grad = surrogate.fast_sigmoid()   # surrogate.atan()

# %%
# Parameters for Dense Layers
inputDataDim = 2       # max_channel_idx - min_channel_idx + 1    # Number of input channels

input_to_hidden = (inputDataDim, 24) # 16 # TODO: Increase the size of this layer # (inputDataDim, 100) # (inputDataDim, 500)  # Number of neurons in the first Fully-Connected Layer

hiddenL2Dim = (input_to_hidden[1], input_to_hidden[1])  # Number of neurons in the Recurrent Fully-Connected Layer (L2)

hiddenL3Dim = (input_to_hidden[1], 16)  # Number of neurons in the Fully-Connected Layer (L3)

hiddenL4Dim = (hiddenL3Dim[1], input_to_hidden[1])  # Number of neurons in the Recurrent Fully-Connected Layer (L4)

hidden_to_out = (hiddenL3Dim[1], 1)  # Number of neurons in the Output Fully-Connected Layer
# In this case, we only need 1 output neuron -> Fires when HFO is detected

# %%
# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        
        # Create a Linear Layer to serve input to LIF1
        self.fc_in = nn.Linear(input_to_hidden[0], input_to_hidden[1],
                bias=False,
                dtype=torch.float32     # Set the data type of the weights to float32
        )

        # TODO: Should the LIF neurons be able to get a negative membrane potential? I think so?
        self.lif1 = snn.Synaptic(
            alpha=torch.full(size=(input_to_hidden[1],), fill_value=placeholder_val), 
            beta=torch.full(size=(input_to_hidden[1],), fill_value=placeholder_val),
            threshold=v_thr,
            reset_mechanism="zero", reset_delay=False,
            # TODO: How to add Refractory Period?
            # init_hidden=True,   # enables the methods in snntorch.backprop to automatically clear the hidden states and detach them from the comp. graph
            spike_grad=spike_grad,
            learn_alpha=True,   # Learn the alpha parameter
            learn_beta=True,    # Learn the beta parameter
            learn_threshold=False,   # Learn the threshold parameter
            
        )      

        """ self.fc2 = nn.Linear(
            hiddenL2Dim[0], hiddenL2Dim[1],
            bias=False,
            dtype=torch.float32     # Set the data type of the weights to float32
        ) """

        self.fc3 = nn.Linear(
            hiddenL3Dim[0], hiddenL3Dim[1],
            bias=False,
            dtype=torch.float32     # Set the data type of the weights to float32
        )

        self.lif2 = snn.Synaptic(
            alpha=torch.full(size=(hiddenL3Dim[1],), fill_value=placeholder_val), 
            beta=torch.full(size=(hiddenL3Dim[1],), fill_value=placeholder_val),
            threshold=v_thr,
            reset_mechanism="zero", reset_delay=False,
            # TODO: How to add Refractory Period?
            # init_hidden=True,   # enables the methods in snntorch.backprop to automatically clear the hidden states and detach them from the comp. graph
            spike_grad=spike_grad,
            learn_alpha=True,   # Learn the alpha parameter
            learn_beta=True,    # Learn the beta parameter
            learn_threshold=False,   # Learn the threshold parameter
        )   

        """ self.fc4 = nn.Linear(
            hiddenL4Dim[0], hiddenL4Dim[1],
            bias=False,
            dtype=torch.float32     # Set the data type of the weights to float32
        ) """

        self.fc_out = nn.Linear(
            hidden_to_out[0], hidden_to_out[1],
            bias=False,
            dtype=torch.float32     # Set the data type of the weights to float32
        )

        self.lif_out = snn.Synaptic(
            alpha=placeholder_val, 
            beta=placeholder_val,
            threshold=v_thr,
            reset_mechanism="zero", reset_delay=False,
            # init_hidden=True,   # enables the methods in snntorch.backprop to automatically clear the hidden states and detach them from the comp. graph
            spike_grad=spike_grad,
            learn_alpha=True,   # Learn the alpha parameter
            learn_beta=True,    # Learn the beta parameter
            learn_threshold=False,   # Learn the threshold parameter
        )

        # Initialize the membrane potential of each LIF neuron
        self.syn1, self.mem1, self.spk1 = None, None, None
        self.syn2, self.mem2, self.spk2 = None, None, None
        self.syn_out, self.mem_out, self.spk_out = None, None, None

    """
    Function called during the forward pass of the network
    """
    def forward(self, x: torch.Tensor) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        '''
        Forward Pass of the Network (Single Step Update)

        Parameters:
        - x: input tensor. Shape: (batch_size, num_features)

        Returns:
        - spk_vals: tuple of tensors containing the spikes of the neurons. Shape: (batch_size, num_neurons)
        - mem_vals: tuple of tensors containing the membrane potentials of the neurons. Shape: (batch_size, num_neurons)
        - syn_vals: tuple of tensors containing the currents of the neurons. Shape: (batch_size, num_neurons)
        '''
        cur_batch_size, cur_num_channels = x.shape

        # --- Lazy State Initialization
        if self.mem1 is None:
            device = x.device   # Get the device of the input tensor

            # Initialize the membrane potential of each LIF neuron
            self.syn1, self.mem1 = self.lif1.reset_mem()
            self.syn2, self.mem2 = self.lif2.reset_mem()
            self.syn_out, self.mem_out = self.lif_out.reset_mem()

            # # Define small residual for spk1
            # spk1_factor = 0.01
            # self.spk1 = torch.rand(size=(cur_batch_size, input_to_hidden[1]), dtype=torch.float32, device=device) * spk1_factor
            # self.spk2 = torch.zeros(size=(cur_batch_size, hiddenL3Dim[1]), dtype=torch.float32, device=device) * spk1_factor
            # self.spk_out = torch.zeros(size=(cur_batch_size, hidden_to_out[1]), dtype=torch.float32, device=device)

        # 
        if len(x.shape) == 1:
            # If the input is 1D, it means we have only one feature (one channel)
            # Unsqueeze the input to add the num_features dimension
            x = x.unsqueeze(1)
            
        ############# State Update #############
        # Calculate Input Current for LIF1 from the Input Layer (FC1) Input -> LIF1
        cur_fc1 = self.fc_in(x) 
    
        # Calculate Input Current from Recurrent Layer (FC2) LIF1 -> LIF1
        # cur_fc2 = self.fc2(spk1)   # Connect LIF1 to itself using FC Layer 2 (Recurrent Layer)

        # Join the input currents for LIF1 (FC1 + FC2)
        cur1 = cur_fc1 # + cur_fc2  # TODO: Not feeding Recurent Layer to LIF1 for now

        # Feed the joined input current to LIF1
        self.spk1, self.syn1, self.mem1 = self.lif1(cur1, self.syn1, self.mem1)  # Feed input to LIF1

        # Calculate Input Current for LIF2 from LIF1 (FC3) LIF1 -> LIF2
        cur2 = self.fc3(self.spk1)   # Connect LIF1 to LIF2 using FC Layer 3
        # Feed the input current to LIF2 and get the spikes, synaptic currents and membrane potentials
        self.spk2, self.syn2, self.mem2 = self.lif2(cur2, self.syn2, self.mem2)  # Feed input to LIF2

        # Calculate Input Current for LIF_OUT from LIF2 (FC4) LIF2 -> LIF_OUT
        cur_out = self.fc_out(self.spk2)
        # Feed the input current to LIF_OUT and get the spikes, synaptic currents and membrane potentials
        self.spk_out, self.syn_out, self.mem_out = self.lif_out(cur_out, self.syn_out, self.mem_out)  # Feed input to LIF_OUT

        # Return the currents, membrane potentials and spikes of the current timestep
        syn_val = (self.syn1, self.syn2, self.syn_out)
        mem_vals = (self.mem1, self.mem2, self.mem_out)
        spk_vals = (self.spk1, self.spk2, self.spk_out)

        # TODO: Check if the dimensions are correct
        return (spk_vals, mem_vals, syn_val)

# %% [markdown]
# ## Load the Trained Network

# %%
# Load the network onto CUDA if available
net = Net().to(device)
prefix="updnb4ds_100_6"
# Load the Trained Parameters from a file
net_filename = f"out/{prefix}_trained_net_loss.pth"  # trained_net_loss_penalty.pth
net.load_state_dict(torch.load(net_filename, map_location=device))

# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (fc_in): Linear(in_features=2, out_features=24, bias=False)
#   (lif1): Synaptic()
#   (fc3): Linear(in_features=24, out_features=16, bias=False)
#   (lif2): Synaptic()
#   (fc_out): Linear(in_features=16, out_features=1, bias=False)
#   (lif_out): Synaptic()
# )

# %% [markdown]
# ## Show the Network Parameters

# %%
# Display the network architecture
total_params = 0    # Accumulator for the total params in the network
# Iterate through the layers of the network
for idx, (name, param) in enumerate(net.named_parameters()):
    # print("param: ", param)
    if param.shape == torch.Size([]):
        print(f"Scalar Param ({name}) | Shape={param.shape} | Value={param} \n")
    elif len(param.shape) == 1:
        print(f"Vector Param ({name}) | Shape={param.shape} | Value={param} \n")
    else:
        print(f"Tensor Param ({name}) | Shape={param.shape}. Total={param.numel()} Preview: {param[:8, :8]}\n")

    # Add the number of parameters in the layer to the total
    total_params += param.numel()

# Print the total number of parameters in the network
print(f"Total Parameters: {total_params}")
# Out:
# Tensor Param (fc_in.weight) | Shape=torch.Size([24, 2]). Total=48 Preview: tensor([[ 0.2043, -0.1214],
#         [ 0.0436,  0.1871],
#         [ 1.4993,  0.6257],
#         [ 0.2375,  0.6981],
#         [ 0.2985,  0.1416],
#         [-1.3174, -1.8931],
#         [-4.9019, -1.5510],
#         [-2.7407, -1.1690]], grad_fn=<SliceBackward0>)
#
# Vector Param (lif1.beta) | Shape=torch.Size([24]) | Value=Parameter containing:
# tensor([0.8344, 0.0455, 0.6980, 0.5272, 0.1591, 0.5071, 0.8516, 0.8722, 0.3189,
#         0.8948, 0.7706, 0.6098, 0.2903, 0.8892, 0.3383, 0.8560, 0.5303, 0.8767,
#         0.4795, 0.9838, 0.1967, 0.9144, 0.7177, 0.6355], requires_grad=True)
#
# Vector Param (lif1.alpha) | Shape=torch.Size([24]) | Value=Parameter containing:
# tensor([0.3894, 0.0257, 0.3175, 0.5971, 0.8574, 0.6284, 0.8558, 0.8870, 0.3361,
#         0.5127, 0.7994, 0.0995, 0.2675, 0.8133, 0.2387, 0.9896, 0.5580, 0.8793,
#         0.3214, 0.9884, 0.2962, 0.9143, 0.7169, 0.5686], requires_grad=True)
#
# Tensor Param (fc3.weight) | Shape=torch.Size([16, 24]). Total=384 Preview: tensor([[-1.1689e-01,  9.7223e-01, -1.0260e-02,  7.2576e-01,  2.2429e-01,
#           6.6135e-01,  7.3596e-02, -6.7760e-01],
#         [-3.7323e-03,  4.4592e-01,  8.4536e-01, -4.2945e-01,  3.8847e-01,
#          -1.3263e-01,  5.1101e-01, -4.2648e-01],
#         [ 7.2276e-01, -3.5728e-01,  2.9701e-01, -4.3122e-02,  4.3959e-01,
#           4.5695e-01,  8.4286e-01,  7.4187e-02],
#         [ 6.0086e-01, -5.2267e-02,  9.5798e-04, -2.1532e-01, -2.3877e-01,
#           7.8331e-01, -3.2708e-01,  2.8457e-01],
#         [ 5.6857e-01, -1.3961e-01, -5.0749e-01, -2.9146e-01, -2.3364e-01,
#           4.2477e-01,  3.0973e-01,  8.1382e-02],
#         [-4.9256e-01,  8.2887e-01, -2.6903e-01,  7.1559e-01,  4.8919e-01,
#          -7.6133e-02,  4.4353e-01,  6.0765e-01],
#         [-3.6438e-01, -1.6157e-01, -9.0313e-02,  6.7516e-01, -2.5017e-01,
#          -1.2354e-02, -1.7711e-01,  5.3742e-01],
#         [ 5.8758e-01,  5.1876e-01, -4.4521e-01,  3.4893e-01,  6.7236e-01,
#           4.0676e-01, -1.1078e-01,  4.6324e-01]], grad_fn=<SliceBackward0>)
#
# Vector Param (lif2.beta) | Shape=torch.Size([16]) | Value=Parameter containing:
# tensor([0.1005, 0.6267, 0.7369, 0.6210, 0.6359, 0.4435, 0.7272, 0.2515, 0.8576,
#         0.4092, 0.9899, 0.4086, 0.9672, 0.2627, 0.4890, 0.6168],
#        requires_grad=True)
#
# Vector Param (lif2.alpha) | Shape=torch.Size([16]) | Value=Parameter containing:
# tensor([0.2623, 0.8935, 0.6147, 0.6232, 0.5083, 0.5375, 0.4817, 0.2009, 0.3919,
#         0.4189, 0.9899, 0.3591, 0.9087, 0.0842, 0.2062, 0.2271],
#        requires_grad=True)
#
# Tensor Param (fc_out.weight) | Shape=torch.Size([1, 16]). Total=16 Preview: tensor([[-0.4128, -0.4975,  0.3530,  0.0026,  0.3645,  0.3050,  0.0076,  0.0040]],
#        grad_fn=<SliceBackward0>)
#
# Scalar Param (lif_out.beta) | Shape=torch.Size([]) | Value=Parameter containing:
# tensor(0.3360, requires_grad=True)
#
# Scalar Param (lif_out.alpha) | Shape=torch.Size([]) | Value=Parameter containing:
# tensor(0.3360, requires_grad=True)
#
# Total Parameters: 530

# %% [markdown]
# ## Feed the Data in Real-Time

# %%
# Store Confusion Matrix for Predictions
TP, TN, FP, FN = 0, 0, 0, 0

# %%
"""
Tensor to store the next timestep when each output neuron may spike (after the refractory period).
When a neuron spikes, it will be set to the current timestep + refractory period.
"""
lif_out_refrac_times = torch.full(size=(hidden_to_out[1]*2,), fill_value=0.0, device=device)

print("lif_out_refrac_times: ", lif_out_refrac_times)
# Out:
# lif_out_refrac_times:  tensor([0., 0.])

# %%
curr_gt_idx = 0 # Index of the current GT event
curr_gt = None  # Stores the current GT event (GT Insertion Timing)
'''
# Active GT Time-To-Live (TTL). This is a counter that decrements every timestep until it reaches 0.
If it reaches 0, it means the Network failed to predict the HFO within the GT tolerance window.
None -> No GT Event is active
'''
active_gts = deque()  # Queue of active GT events: each item is (gt_time, remaining_ttl)
out_spikes=[]
# Disable gradient calculation for inference
with torch.no_grad():
    for step in range(total_num_steps):
        # Get the current input (UP/DN spikes)
        curr_input = input_tensor[step]

        # Unsqueeze the input to add the num_batches dimension
        curr_input = curr_input.unsqueeze(0)
        # print(f"curr_input: {curr_input}")

        ADDED_FN = False    # Tracks if a False Negative was added in this timestep

        # # Check if a GT event leaves the detection window
        # if active_gt_ttl is not None and active_gt_ttl < 0:
        #     # GT Event Expired
        #     print(f"GT Event expired at timestep {step} with GT Insertion Timing: {curr_gt}")

        #     # Add a False Negative to the Confusion Matrix
        #     FN += 1
        #     # Set the TTL to None
        #     active_gt_ttl = None
        #     # Move to the next GT event
        #     curr_gt_idx += 1
        #     # Set ADDED_FN to True
        #     ADDED_FN = True

        # Check if a GT event enters the detection window
        if curr_gt_idx < num_hfo_events :
            curr_gt = int(gt_tensor[curr_gt_idx].item())  # Get the current GT Insertion Timing
            if curr_gt == step:
                # Check if a GT event was already active
                print(f"GT Event {curr_gt_idx} Insertion Timing: {curr_gt} at timestep {step}")
                active_gts.append((curr_gt, MAX_DETECTION_OFFSET))
                # if active_gt_ttl is not None:
                #     raise ValueError("[Error] Two GT events detected inside the Detection Window!")

                # GT Event starts at this timestep
                # print(f"GT Event starts at timestep {step} with GT Insertion Timing: {curr_gt}")
                
                # Set the TTL to the Maximum Detection Offset from the GT Insertion Timing
                # active_gt_ttl = MAX_DETECTION_OFFSET
                curr_gt_idx+=1
            
        # --------   State Update   --------
        spk, mem, syn = net(curr_input)

        # Get the spikes, membrane potentials and synaptic currents of the current timestep
        spk1, spk2, spk_out = spk
        mem1, mem2, mem_out = mem
        syn1, syn2, syn_out = syn
        # print(f"spk1: {spk1.shape} | spk2: {spk2.shape} | spk_out: {spk_out.shape}")
        # print(f"mem1: {mem1.shape} | mem2: {mem2.shape} | mem_out: {mem_out.shape}")
        # print(f"syn1: {syn1.shape} | syn2: {syn2.shape} | syn_out: {syn_out.shape}")

        if ADDED_FN:
            """
            If a FN was added -> GT event was not detected -> The problem formulation does not allow
            2 HFO events to be closer together than the confidence window, so we can skip this step
            """
            continue

        """ if torch.sum(spk2) > 0:
            # TODO: Remove this print statement
            print(f"LIF2 spiked at timestep {step} with spikes: {spk2}") """
        
        # Track which GTs remain active
        new_active_gts = deque()
        for gt_time, ttl in active_gts:
            if ttl < 0:
                FN += 1
                print(f"[FN] GT event at {gt_time} expired at timestep {step}")
            else:
                new_active_gts.append((gt_time, ttl - 1))
        active_gts = new_active_gts

        if torch.sum(spk_out) > 0:
            # Convert spk_out to int for bitwise operations (Squeeze the batch dimension)
            spk_out_int = spk_out.squeeze(0).int()
            out_spikes.append(step*dt)
            # Consider the refractory period of the output neurons
            REFRAC_STATE_MASK = lif_out_refrac_times[0] > step * dt    # Check if each output neuron is in the refractory period
            # Bitwise AND between the spikes by the refractory state mask
            # Gets a mask of the neurons that spiked and are not in the refractory state
            valid_spk_out = torch.Tensor.bool(spk_out_int & (~REFRAC_STATE_MASK))
         

            # Check if any Valid Output Neuron spiked
            if torch.sum(valid_spk_out) > 0:
                # print(f"valid_spk_out: {valid_spk_out} | lif_out_refrac_times: {lif_out_refrac_times}")
                # Set the refractory period for the spiking output neurons
            
                # If an Output Neuron spiked -> Predicted an HFO
                # Let's check if the predicted HFO is within the GT tolerance window
                if active_gts:
                    # The GT event is active -> Valid Prediction
                    gt_time, _ = active_gts.popleft()
                    TP += 1
                    print(f"[TP] Spike matched GT event at timestep {step} (GT: {gt_time})")
                    lif_out_refrac_times[0] = float(step * dt + refrac_period_gt)
                else:
                    if lif_out_refrac_times[1] < step * dt:
                        # The GT event is not active -> Invalid Prediction
                        FP += 1
                        print(f"[FP] Network detected HFO at timestep {step} without an active GT event")
                        lif_out_refrac_times[1] = float(step * dt + refrac_period_fp)
            else:
                # No valid output neuron spiked -> No HFO Detected
                TN += 1     # Increment True Negatives (No HFO detected)
            
        else:
            # If the Output Neuron did not spike -> No HFO detected
            TN += 1     # Increment True Negatives (No HFO detected)


        if step % 100000 == 0:
            print(f"Processed step {step}/{total_num_steps} ({(step /total_num_steps) * 100:.2f}%)")
# Out:
# Processed step 0/8321032 (0.00%)
# [FP] Network detected HFO at timestep 368 without an active GT event
# [FP] Network detected HFO at timestep 470 without an active GT event
# GT Event 0 Insertion Timing: 568 at timestep 568
# [TP] Spike matched GT event at timestep 599 (GT: 568)
# [FP] Network detected HFO at timestep 721 without an active GT event
# [FP] Network detected HFO at timestep 833 without an active GT event
# [FP] Network detected HFO at timestep 941 without an active GT event
# GT Event 1 Insertion Timing: 969 at timestep 969
# [TP] Spike matched GT event at timestep 983 (GT: 969)
# [FP] Network detected HFO at timestep 1086 without an active GT event
# [FP] Network detected HFO at timestep 1305 without an active GT event
# [FP] Network detected HFO at timestep 1407 without an active GT event
# [FP] Network detected HFO at timestep 1529 without an active GT event
# GT Event 2 Insertion Timing: 1629 at timestep 1629
# [TP] Spike matched GT event at timestep 1643 (GT: 1629)
# [FP] Network detected HFO at timestep 1766 without an active GT event
# [FP] Network detected HFO at timestep 1895 without an active GT event
# [FP] Network detected HFO at timestep 2008 without an active GT event
# [FP] Network detected HFO at timestep 2150 without an active GT event
# [FP] Network detected HFO at timestep 2251 without an active GT event
# [FP] Network detected HFO at timestep 2373 without an active GT event
# [FP] Network detected HFO at timestep 2730 without an active GT event
# [FP] Network detected HFO at timestep 3624 without an active GT event
# [FP] Network detected HFO at timestep 3726 without an active GT event
# [FP] Network detected HFO at timestep 3829 without an active GT event
# GT Event 3 Insertion Timing: 3952 at timestep 3952
# [TP] Spike matched GT event at timestep 4003 (GT: 3952)
# [FP] Network detected HFO at timestep 4104 without an active GT event
# [FP] Network detected HFO at timestep 4220 without an active GT event
# [FP] Network detected HFO at timestep 4367 without an active GT event
# GT Event 4 Insertion Timing: 5006 at timestep 5006
# [FN] GT event at 5006 expired at timestep 5079
# [FP] Network detected HFO at timestep 5175 without an active GT event
# GT Event 5 Insertion Timing: 5225 at timestep 5225
# [TP] Spike matched GT event at timestep 5255 (GT: 5225)
# [FP] Network detected HFO at timestep 5357 without an active GT event
# [FP] Network detected HFO at timestep 5514 without an active GT event
# [FP] Network detected HFO at timestep 5693 without an active GT event
# GT Event 6 Insertion Timing: 5772 at timestep 5772
# [TP] Spike matched GT event at timestep 5792 (GT: 5772)
# [FP] Network detected HFO at timestep 5892 without an active GT event
# [FP] Network detected HFO at timestep 5997 without an active GT event
# GT Event 7 Insertion Timing: 6039 at timestep 6039
# [TP] Spike matched GT event at timestep 6088 (GT: 6039)
# [FP] Network detected HFO at timestep 6190 without an active GT event
# [FP] Network detected HFO at timestep 6291 without an active GT event
# [FP] Network detected HFO at timestep 6392 without an active GT event
# GT Event 8 Insertion Timing: 6479 at timestep 6479
# [TP] Spike matched GT event at timestep 6502 (GT: 6479)
# [FP] Network detected HFO at timestep 6603 without an active GT event
# [FP] Network detected HFO at timestep 6709 without an active GT event
# GT Event 9 Insertion Timing: 6869 at timestep 6869
# [TP] Spike matched GT event at timestep 6891 (GT: 6869)
# [FP] Network detected HFO at timestep 7000 without an active GT event
# [FP] Network detected HFO at timestep 7106 without an active GT event
# [FP] Network detected HFO at timestep 7207 without an active GT event
# [FP] Network detected HFO at timestep 7308 without an active GT event
# [FP] Network detected HFO at timestep 7562 without an active GT event
# [FP] Network detected HFO at timestep 7933 without an active GT event
# [FP] Network detected HFO at timestep 8252 without an active GT event
# [FP] Network detected HFO at timestep 8424 without an active GT event
# [FP] Network detected HFO at timestep 8525 without an active GT event
# [FP] Network detected HFO at timestep 8627 without an active GT event
# [FP] Network detected HFO at timestep 8764 without an active GT event
# [FP] Network detected HFO at timestep 8934 without an active GT event
# [FP] Network detected HFO at timestep 9044 without an active GT event
# [FP] Network detected HFO at timestep 9191 without an active GT event
# [FP] Network detected HFO at timestep 9321 without an active GT event
# [FP] Network detected HFO at timestep 9752 without an active GT event
# [FP] Network detected HFO at timestep 9865 without an active GT event
# [FP] Network detected HFO at timestep 9971 without an active GT event
# [FP] Network detected HFO at timestep 10691 without an active GT event
# [FP] Network detected HFO at timestep 10943 without an active GT event
# [FP] Network detected HFO at timestep 11058 without an active GT event
# [FP] Network detected HFO at timestep 11160 without an active GT event
# [FP] Network detected HFO at timestep 11265 without an active GT event
# [FP] Network detected HFO at timestep 11367 without an active GT event
# [FP] Network detected HFO at timestep 11497 without an active GT event
# [FP] Network detected HFO at timestep 11637 without an active GT event
# [FP] Network detected HFO at timestep 11779 without an active GT event
# [FP] Network detected HFO at timestep 12098 without an active GT event
# [FP] Network detected HFO at timestep 12370 without an active GT event
# [FP] Network detected HFO at timestep 12473 without an active GT event
# [FP] Network detected HFO at timestep 12610 without an active GT event
# [FP] Network detected HFO at timestep 12761 without an active GT event
# [FP] Network detected HFO at timestep 12865 without an active GT event
# [FP] Network detected HFO at timestep 13062 without an active GT event
# [FP] Network detected HFO at timestep 13482 without an active GT event
# [FP] Network detected HFO at timestep 13665 without an active GT event
# [FP] Network detected HFO at timestep 13771 without an active GT event
# [FP] Network detected HFO at timestep 13949 without an active GT event
# [FP] Network detected HFO at timestep 14050 without an active GT event
# [FP] Network detected HFO at timestep 14215 without an active GT event
# [FP] Network detected HFO at timestep 14326 without an active GT event
# [FP] Network detected HFO at timestep 14738 without an active GT event
# [FP] Network detected HFO at timestep 14870 without an active GT event
# GT Event 10 Insertion Timing: 14958 at timestep 14958
# [TP] Spike matched GT event at timestep 14958 (GT: 14958)
# [FP] Network detected HFO at timestep 15059 without an active GT event
# [FP] Network detected HFO at timestep 15163 without an active GT event
# GT Event 11 Insertion Timing: 15495 at timestep 15495
# [TP] Spike matched GT event at timestep 15533 (GT: 15495)
# [FP] Network detected HFO at timestep 15635 without an active GT event
# [FP] Network detected HFO at timestep 15738 without an active GT event
# [FP] Network detected HFO at timestep 15862 without an active GT event
# [FP] Network detected HFO at timestep 16052 without an active GT event
# [FP] Network detected HFO at timestep 16153 without an active GT event
# GT Event 12 Insertion Timing: 16177 at timestep 16177
# [TP] Spike matched GT event at timestep 16188 (GT: 16177)
# [FP] Network detected HFO at timestep 16289 without an active GT event
# [FP] Network detected HFO at timestep 16395 without an active GT event
# [FP] Network detected HFO at timestep 16501 without an active GT event
# [FP] Network detected HFO at timestep 16602 without an active GT event
# [FP] Network detected HFO at timestep 16706 without an active GT event
# [FP] Network detected HFO at timestep 16865 without an active GT event
# [FP] Network detected HFO at timestep 17077 without an active GT event
# [FP] Network detected HFO at timestep 17291 without an active GT event
# [FP] Network detected HFO at timestep 17392 without an active GT event
# [FP] Network detected HFO at timestep 17510 without an active GT event
# [FP] Network detected HFO at timestep 17612 without an active GT event
# GT Event 13 Insertion Timing: 17645 at timestep 17645
# [TP] Spike matched GT event at timestep 17693 (GT: 17645)
# [FP] Network detected HFO at timestep 17798 without an active GT event
# [FP] Network detected HFO at timestep 17926 without an active GT event
# [FP] Network detected HFO at timestep 18030 without an active GT event
# GT Event 14 Insertion Timing: 18088 at timestep 18088
# [TP] Spike matched GT event at timestep 18116 (GT: 18088)
# [FP] Network detected HFO at timestep 18240 without an active GT event
# [FP] Network detected HFO at timestep 18344 without an active GT event
# GT Event 15 Insertion Timing: 18434 at timestep 18434
# [TP] Spike matched GT event at timestep 18439 (GT: 18434)
# [FP] Network detected HFO at timestep 18540 without an active GT event
# [FP] Network detected HFO at timestep 18641 without an active GT event
# [FP] Network detected HFO at timestep 18742 without an active GT event
# [FP] Network detected HFO at timestep 18844 without an active GT event
# [FP] Network detected HFO at timestep 18946 without an active GT event
# GT Event 16 Insertion Timing: 19022 at timestep 19022
# [TP] Spike matched GT event at timestep 19042 (GT: 19022)
# [FP] Network detected HFO at timestep 19143 without an active GT event
# [FP] Network detected HFO at timestep 19245 without an active GT event
# [FP] Network detected HFO at timestep 19346 without an active GT event
# [FP] Network detected HFO at timestep 19448 without an active GT event
# [FP] Network detected HFO at timestep 19553 without an active GT event
# [FP] Network detected HFO at timestep 19656 without an active GT event
# [FP] Network detected HFO at timestep 19757 without an active GT event
# [FP] Network detected HFO at timestep 19866 without an active GT event
# [FP] Network detected HFO at timestep 19968 without an active GT event
# [FP] Network detected HFO at timestep 20069 without an active GT event
# [FP] Network detected HFO at timestep 20436 without an active GT event
# [FP] Network detected HFO at timestep 20591 without an active GT event
# [FP] Network detected HFO at timestep 20802 without an active GT event
# [FP] Network detected HFO at timestep 21321 without an active GT event
# [FP] Network detected HFO at timestep 21505 without an active GT event
# [FP] Network detected HFO at timestep 22641 without an active GT event
# [FP] Network detected HFO at timestep 23149 without an active GT event
# [FP] Network detected HFO at timestep 23273 without an active GT event
# [FP] Network detected HFO at timestep 23376 without an active GT event
# [FP] Network detected HFO at timestep 23517 without an active GT event
# [FP] Network detected HFO at timestep 23620 without an active GT event
# [FP] Network detected HFO at timestep 23815 without an active GT event
# [FP] Network detected HFO at timestep 23917 without an active GT event
# [FP] Network detected HFO at timestep 24022 without an active GT event
# [FP] Network detected HFO at timestep 24189 without an active GT event
# [FP] Network detected HFO at timestep 24290 without an active GT event
# [FP] Network detected HFO at timestep 24394 without an active GT event
# [FP] Network detected HFO at timestep 24706 without an active GT event
# [FP] Network detected HFO at timestep 24848 without an active GT event
# [FP] Network detected HFO at timestep 25072 without an active GT event
# [FP] Network detected HFO at timestep 25174 without an active GT event
# [FP] Network detected HFO at timestep 25276 without an active GT event
# [FP] Network detected HFO at timestep 25399 without an active GT event
# [FP] Network detected HFO at timestep 25502 without an active GT event
# [FP] Network detected HFO at timestep 25604 without an active GT event
# [FP] Network detected HFO at timestep 25723 without an active GT event
# [FP] Network detected HFO at timestep 25997 without an active GT event
# [FP] Network detected HFO at timestep 26172 without an active GT event
# [FP] Network detected HFO at timestep 26319 without an active GT event
# [FP] Network detected HFO at timestep 26428 without an active GT event
# [FP] Network detected HFO at timestep 26539 without an active GT event
# [FP] Network detected HFO at timestep 26640 without an active GT event
# [FP] Network detected HFO at timestep 26747 without an active GT event
# [FP] Network detected HFO at timestep 26886 without an active GT event
# GT Event 17 Insertion Timing: 26891 at timestep 26891
# [TP] Spike matched GT event at timestep 26894 (GT: 26891)
# [FP] Network detected HFO at timestep 26998 without an active GT event
# [FP] Network detected HFO at timestep 27104 without an active GT event
# [FP] Network detected HFO at timestep 27207 without an active GT event
# [FP] Network detected HFO at timestep 27366 without an active GT event
# [FP] Network detected HFO at timestep 27486 without an active GT event
# GT Event 18 Insertion Timing: 27626 at timestep 27626
# [TP] Spike matched GT event at timestep 27662 (GT: 27626)
# [FP] Network detected HFO at timestep 27763 without an active GT event
# [FP] Network detected HFO at timestep 27871 without an active GT event
# GT Event 19 Insertion Timing: 27887 at timestep 27887
# [TP] Spike matched GT event at timestep 27908 (GT: 27887)
# [FP] Network detected HFO at timestep 28012 without an active GT event
# [FP] Network detected HFO at timestep 28113 without an active GT event
# [FP] Network detected HFO at timestep 28214 without an active GT event
# [FP] Network detected HFO at timestep 28319 without an active GT event
# [FP] Network detected HFO at timestep 28421 without an active GT event
# [FP] Network detected HFO at timestep 28542 without an active GT event
# [FP] Network detected HFO at timestep 28669 without an active GT event
# [FP] Network detected HFO at timestep 28951 without an active GT event
# [FP] Network detected HFO at timestep 29054 without an active GT event
# [FP] Network detected HFO at timestep 29337 without an active GT event
# [FP] Network detected HFO at timestep 29458 without an active GT event
# [FP] Network detected HFO at timestep 29737 without an active GT event
# [FP] Network detected HFO at timestep 29892 without an active GT event
# [FP] Network detected HFO at timestep 30002 without an active GT event
# [FP] Network detected HFO at timestep 30117 without an active GT event
# [FP] Network detected HFO at timestep 30220 without an active GT event
# [FP] Network detected HFO at timestep 30321 without an active GT event
# GT Event 20 Insertion Timing: 30375 at timestep 30375
# [TP] Spike matched GT event at timestep 30375 (GT: 30375)
# [FP] Network detected HFO at timestep 30476 without an active GT event
# [FP] Network detected HFO at timestep 30604 without an active GT event
# GT Event 21 Insertion Timing: 30697 at timestep 30697
# [TP] Spike matched GT event at timestep 30715 (GT: 30697)
# [FP] Network detected HFO at timestep 30816 without an active GT event
# [FP] Network detected HFO at timestep 30926 without an active GT event
# [FP] Network detected HFO at timestep 31027 without an active GT event
# [FP] Network detected HFO at timestep 31129 without an active GT event
# [FP] Network detected HFO at timestep 31231 without an active GT event
# [FP] Network detected HFO at timestep 31407 without an active GT event
# [FP] Network detected HFO at timestep 31511 without an active GT event
# [FP] Network detected HFO at timestep 31613 without an active GT event
# [FP] Network detected HFO at timestep 31762 without an active GT event
# [FP] Network detected HFO at timestep 31943 without an active GT event
# GT Event 22 Insertion Timing: 32162 at timestep 32162
# [TP] Spike matched GT event at timestep 32167 (GT: 32162)
# [FP] Network detected HFO at timestep 32268 without an active GT event
# [FP] Network detected HFO at timestep 32381 without an active GT event
# [FP] Network detected HFO at timestep 32484 without an active GT event
# [FP] Network detected HFO at timestep 32604 without an active GT event
# [FP] Network detected HFO at timestep 32705 without an active GT event
# [FP] Network detected HFO at timestep 32808 without an active GT event
# [FP] Network detected HFO at timestep 32968 without an active GT event
# GT Event 23 Insertion Timing: 33044 at timestep 33044
# [TP] Spike matched GT event at timestep 33047 (GT: 33044)
# [FP] Network detected HFO at timestep 33148 without an active GT event
# [FP] Network detected HFO at timestep 33254 without an active GT event
# [FP] Network detected HFO at timestep 33355 without an active GT event
# [FP] Network detected HFO at timestep 33653 without an active GT event
# [FP] Network detected HFO at timestep 33767 without an active GT event
# [FP] Network detected HFO at timestep 33934 without an active GT event
# [FP] Network detected HFO at timestep 34054 without an active GT event
# [FP] Network detected HFO at timestep 34159 without an active GT event
# [FP] Network detected HFO at timestep 34405 without an active GT event
# [FP] Network detected HFO at timestep 34596 without an active GT event
# [FP] Network detected HFO at timestep 34722 without an active GT event
# [FP] Network detected HFO at timestep 35367 without an active GT event
# [FP] Network detected HFO at timestep 35468 without an active GT event
# [FP] Network detected HFO at timestep 35690 without an active GT event
# [FP] Network detected HFO at timestep 35800 without an active GT event
# [FP] Network detected HFO at timestep 36104 without an active GT event
# [FP] Network detected HFO at timestep 36207 without an active GT event
# [FP] Network detected HFO at timestep 36315 without an active GT event
# [FP] Network detected HFO at timestep 36416 without an active GT event
# [FP] Network detected HFO at timestep 36584 without an active GT event
# [FP] Network detected HFO at timestep 36686 without an active GT event
# [FP] Network detected HFO at timestep 36811 without an active GT event
# [FP] Network detected HFO at timestep 36924 without an active GT event
# [FP] Network detected HFO at timestep 37042 without an active GT event
# [FP] Network detected HFO at timestep 37187 without an active GT event
# [FP] Network detected HFO at timestep 37442 without an active GT event
# [FP] Network detected HFO at timestep 37741 without an active GT event
# [FP] Network detected HFO at timestep 37867 without an active GT event
# [FP] Network detected HFO at timestep 37971 without an active GT event
# [FP] Network detected HFO at timestep 38079 without an active GT event
# [FP] Network detected HFO at timestep 38185 without an active GT event
# [FP] Network detected HFO at timestep 38289 without an active GT event
# [FP] Network detected HFO at timestep 38745 without an active GT event
# [FP] Network detected HFO at timestep 38848 without an active GT event
# [FP] Network detected HFO at timestep 39174 without an active GT event
# [FP] Network detected HFO at timestep 39277 without an active GT event
# [FP] Network detected HFO at timestep 39384 without an active GT event
# GT Event 24 Insertion Timing: 39752 at timestep 39752
# [TP] Spike matched GT event at timestep 39804 (GT: 39752)
# [FP] Network detected HFO at timestep 39905 without an active GT event
# [FP] Network detected HFO at timestep 40006 without an active GT event
# [FP] Network detected HFO at timestep 40126 without an active GT event
# [FP] Network detected HFO at timestep 40231 without an active GT event
# [FP] Network detected HFO at timestep 40341 without an active GT event
# GT Event 25 Insertion Timing: 40388 at timestep 40388
# [TP] Spike matched GT event at timestep 40406 (GT: 40388)
# [FP] Network detected HFO at timestep 40537 without an active GT event
# [FP] Network detected HFO at timestep 40641 without an active GT event
# [FP] Network detected HFO at timestep 40759 without an active GT event
# [FP] Network detected HFO at timestep 40860 without an active GT event
# [FP] Network detected HFO at timestep 40968 without an active GT event
# [FP] Network detected HFO at timestep 41073 without an active GT event
# [FP] Network detected HFO at timestep 41178 without an active GT event
# [FP] Network detected HFO at timestep 41286 without an active GT event
# [FP] Network detected HFO at timestep 41424 without an active GT event
# [FP] Network detected HFO at timestep 41525 without an active GT event
# [FP] Network detected HFO at timestep 41635 without an active GT event
# [FP] Network detected HFO at timestep 41738 without an active GT event
# [FP] Network detected HFO at timestep 41848 without an active GT event
# [FP] Network detected HFO at timestep 42542 without an active GT event
# [FP] Network detected HFO at timestep 42678 without an active GT event
# [FP] Network detected HFO at timestep 42801 without an active GT event
# GT Event 26 Insertion Timing: 42876 at timestep 42876
# [TP] Spike matched GT event at timestep 42887 (GT: 42876)
# GT Event 27 Insertion Timing: 42980 at timestep 42980
# [TP] Spike matched GT event at timestep 43008 (GT: 42980)
# [FP] Network detected HFO at timestep 43108 without an active GT event
# [FP] Network detected HFO at timestep 43210 without an active GT event
# [FP] Network detected HFO at timestep 43362 without an active GT event
# [FP] Network detected HFO at timestep 43535 without an active GT event
# [FP] Network detected HFO at timestep 43636 without an active GT event
# [FP] Network detected HFO at timestep 43738 without an active GT event
# [FP] Network detected HFO at timestep 43840 without an active GT event
# [FP] Network detected HFO at timestep 43959 without an active GT event
# [FP] Network detected HFO at timestep 44061 without an active GT event
# [FP] Network detected HFO at timestep 44250 without an active GT event
# [FP] Network detected HFO at timestep 44352 without an active GT event
# [FP] Network detected HFO at timestep 44472 without an active GT event
# [FP] Network detected HFO at timestep 44767 without an active GT event
# [FP] Network detected HFO at timestep 44894 without an active GT event
# [FP] Network detected HFO at timestep 45036 without an active GT event
# [FP] Network detected HFO at timestep 45143 without an active GT event
# [FP] Network detected HFO at timestep 45246 without an active GT event
# [FP] Network detected HFO at timestep 45390 without an active GT event
# GT Event 28 Insertion Timing: 45485 at timestep 45485
# [TP] Spike matched GT event at timestep 45508 (GT: 45485)
# [FP] Network detected HFO at timestep 45608 without an active GT event
# [FP] Network detected HFO at timestep 45716 without an active GT event
# [FP] Network detected HFO at timestep 45822 without an active GT event
# [FP] Network detected HFO at timestep 45925 without an active GT event
# [FP] Network detected HFO at timestep 46032 without an active GT event
# [FP] Network detected HFO at timestep 46138 without an active GT event
# GT Event 29 Insertion Timing: 46310 at timestep 46310
# [TP] Spike matched GT event at timestep 46326 (GT: 46310)
# [FP] Network detected HFO at timestep 46430 without an active GT event
# [FP] Network detected HFO at timestep 46534 without an active GT event
# [FP] Network detected HFO at timestep 46648 without an active GT event
# GT Event 30 Insertion Timing: 46689 at timestep 46689
# [TP] Spike matched GT event at timestep 46691 (GT: 46689)
# [FP] Network detected HFO at timestep 46796 without an active GT event
# [FP] Network detected HFO at timestep 46898 without an active GT event
# [FP] Network detected HFO at timestep 46999 without an active GT event
# [FP] Network detected HFO at timestep 47118 without an active GT event
# [FP] Network detected HFO at timestep 47450 without an active GT event
# [FP] Network detected HFO at timestep 47559 without an active GT event
# [FP] Network detected HFO at timestep 47675 without an active GT event
# [FP] Network detected HFO at timestep 47796 without an active GT event
# GT Event 31 Insertion Timing: 47806 at timestep 47806
# [TP] Spike matched GT event at timestep 47831 (GT: 47806)
# [FP] Network detected HFO at timestep 47932 without an active GT event
# GT Event 32 Insertion Timing: 48011 at timestep 48011
# [TP] Spike matched GT event at timestep 48012 (GT: 48011)
# [FP] Network detected HFO at timestep 48118 without an active GT event
# [FP] Network detected HFO at timestep 48223 without an active GT event
# [FP] Network detected HFO at timestep 48324 without an active GT event
# [FP] Network detected HFO at timestep 48429 without an active GT event
# [FP] Network detected HFO at timestep 48535 without an active GT event
# [FP] Network detected HFO at timestep 48636 without an active GT event
# [FP] Network detected HFO at timestep 48739 without an active GT event
# GT Event 33 Insertion Timing: 48802 at timestep 48802
# [TP] Spike matched GT event at timestep 48802 (GT: 48802)
# [FP] Network detected HFO at timestep 48902 without an active GT event
# [FP] Network detected HFO at timestep 49020 without an active GT event
# [FP] Network detected HFO at timestep 49121 without an active GT event
# [FP] Network detected HFO at timestep 49222 without an active GT event
# [FP] Network detected HFO at timestep 49397 without an active GT event
# [FP] Network detected HFO at timestep 49572 without an active GT event
# [FP] Network detected HFO at timestep 49684 without an active GT event
# [FP] Network detected HFO at timestep 49834 without an active GT event
# [FP] Network detected HFO at timestep 49944 without an active GT event
# [FP] Network detected HFO at timestep 50532 without an active GT event
# [FP] Network detected HFO at timestep 51060 without an active GT event
# [FP] Network detected HFO at timestep 51556 without an active GT event
# [FP] Network detected HFO at timestep 51659 without an active GT event
# [FP] Network detected HFO at timestep 51764 without an active GT event
# [FP] Network detected HFO at timestep 51866 without an active GT event
# [FP] Network detected HFO at timestep 51967 without an active GT event
# [FP] Network detected HFO at timestep 52103 without an active GT event
# GT Event 34 Insertion Timing: 52116 at timestep 52116
# [TP] Spike matched GT event at timestep 52116 (GT: 52116)
# [FP] Network detected HFO at timestep 52220 without an active GT event
# GT Event 35 Insertion Timing: 52261 at timestep 52261
# [TP] Spike matched GT event at timestep 52273 (GT: 52261)
# [FP] Network detected HFO at timestep 52373 without an active GT event
# [FP] Network detected HFO at timestep 52504 without an active GT event
# [FP] Network detected HFO at timestep 52611 without an active GT event
# [FP] Network detected HFO at timestep 52712 without an active GT event
# [FP] Network detected HFO at timestep 52819 without an active GT event
# [FP] Network detected HFO at timestep 52920 without an active GT event
# [FP] Network detected HFO at timestep 53076 without an active GT event
# [FP] Network detected HFO at timestep 54344 without an active GT event
# [FP] Network detected HFO at timestep 54742 without an active GT event
# [FP] Network detected HFO at timestep 54857 without an active GT event
# GT Event 36 Insertion Timing: 55114 at timestep 55114
# [TP] Spike matched GT event at timestep 55119 (GT: 55114)
# [FP] Network detected HFO at timestep 55220 without an active GT event
# [FP] Network detected HFO at timestep 55327 without an active GT event
# [FP] Network detected HFO at timestep 55429 without an active GT event
# [FP] Network detected HFO at timestep 55531 without an active GT event
# [FP] Network detected HFO at timestep 55632 without an active GT event
# [FP] Network detected HFO at timestep 55736 without an active GT event
# GT Event 37 Insertion Timing: 55823 at timestep 55823
# [TP] Spike matched GT event at timestep 55853 (GT: 55823)
# [FP] Network detected HFO at timestep 55954 without an active GT event
# [FP] Network detected HFO at timestep 56061 without an active GT event
# [FP] Network detected HFO at timestep 56162 without an active GT event
# [FP] Network detected HFO at timestep 56684 without an active GT event
# [FP] Network detected HFO at timestep 56791 without an active GT event
# [FP] Network detected HFO at timestep 56892 without an active GT event
# [FP] Network detected HFO at timestep 56993 without an active GT event
# [FP] Network detected HFO at timestep 57115 without an active GT event
# [FP] Network detected HFO at timestep 57217 without an active GT event
# GT Event 38 Insertion Timing: 57268 at timestep 57268
# [TP] Spike matched GT event at timestep 57269 (GT: 57268)
# [FP] Network detected HFO at timestep 57370 without an active GT event
# [FP] Network detected HFO at timestep 57472 without an active GT event
# [FP] Network detected HFO at timestep 57686 without an active GT event
# [FP] Network detected HFO at timestep 57812 without an active GT event
# GT Event 39 Insertion Timing: 57820 at timestep 57820
# [TP] Spike matched GT event at timestep 57872 (GT: 57820)
# [FP] Network detected HFO at timestep 57978 without an active GT event
# [FP] Network detected HFO at timestep 58085 without an active GT event
# GT Event 40 Insertion Timing: 58098 at timestep 58098
# [TP] Spike matched GT event at timestep 58104 (GT: 58098)
# [FP] Network detected HFO at timestep 58205 without an active GT event
# [FP] Network detected HFO at timestep 58327 without an active GT event
# [FP] Network detected HFO at timestep 58446 without an active GT event
# GT Event 41 Insertion Timing: 58489 at timestep 58489
# [TP] Spike matched GT event at timestep 58496 (GT: 58489)
# [FP] Network detected HFO at timestep 58597 without an active GT event
# GT Event 42 Insertion Timing: 58624 at timestep 58624
# [TP] Spike matched GT event at timestep 58626 (GT: 58624)
# [FP] Network detected HFO at timestep 58727 without an active GT event
# GT Event 43 Insertion Timing: 58844 at timestep 58844
# [TP] Spike matched GT event at timestep 58886 (GT: 58844)
# [FP] Network detected HFO at timestep 58987 without an active GT event
# [FP] Network detected HFO at timestep 59091 without an active GT event
# [FP] Network detected HFO at timestep 59225 without an active GT event
# [FP] Network detected HFO at timestep 59446 without an active GT event
# [FP] Network detected HFO at timestep 59548 without an active GT event
# [FP] Network detected HFO at timestep 59649 without an active GT event
# [FP] Network detected HFO at timestep 59766 without an active GT event
# [FP] Network detected HFO at timestep 59871 without an active GT event
# [FP] Network detected HFO at timestep 59975 without an active GT event
# [FP] Network detected HFO at timestep 60078 without an active GT event
# [FP] Network detected HFO at timestep 60223 without an active GT event
# [FP] Network detected HFO at timestep 60396 without an active GT event
# [FP] Network detected HFO at timestep 60535 without an active GT event
# [FP] Network detected HFO at timestep 60739 without an active GT event
# [FP] Network detected HFO at timestep 60857 without an active GT event
# [FP] Network detected HFO at timestep 61117 without an active GT event
# [FP] Network detected HFO at timestep 61315 without an active GT event
# [FP] Network detected HFO at timestep 61422 without an active GT event
# [FP] Network detected HFO at timestep 61849 without an active GT event
# [FP] Network detected HFO at timestep 61977 without an active GT event
# [FP] Network detected HFO at timestep 62084 without an active GT event
# [FP] Network detected HFO at timestep 62185 without an active GT event
# [FP] Network detected HFO at timestep 62301 without an active GT event
# [FP] Network detected HFO at timestep 62409 without an active GT event
# [FP] Network detected HFO at timestep 62510 without an active GT event
# [FP] Network detected HFO at timestep 62618 without an active GT event
# [FP] Network detected HFO at timestep 62758 without an active GT event
# [FP] Network detected HFO at timestep 62859 without an active GT event
# GT Event 44 Insertion Timing: 62952 at timestep 62952
# [TP] Spike matched GT event at timestep 62952 (GT: 62952)
# [FP] Network detected HFO at timestep 63052 without an active GT event
# [FP] Network detected HFO at timestep 63154 without an active GT event
# GT Event 45 Insertion Timing: 63243 at timestep 63243
# [TP] Spike matched GT event at timestep 63264 (GT: 63243)
# [FP] Network detected HFO at timestep 63371 without an active GT event
# [FP] Network detected HFO at timestep 63479 without an active GT event
# [FP] Network detected HFO at timestep 63580 without an active GT event
# [FP] Network detected HFO at timestep 63683 without an active GT event
# [FP] Network detected HFO at timestep 63785 without an active GT event
# [FP] Network detected HFO at timestep 63887 without an active GT event
# GT Event 46 Insertion Timing: 64006 at timestep 64006
# [TP] Spike matched GT event at timestep 64027 (GT: 64006)
# [FP] Network detected HFO at timestep 64127 without an active GT event
# GT Event 47 Insertion Timing: 64212 at timestep 64212
# [TP] Spike matched GT event at timestep 64240 (GT: 64212)
# [FP] Network detected HFO at timestep 64340 without an active GT event
# [FP] Network detected HFO at timestep 64454 without an active GT event
# [FP] Network detected HFO at timestep 64556 without an active GT event
# [FP] Network detected HFO at timestep 64657 without an active GT event
# [FP] Network detected HFO at timestep 64761 without an active GT event
# [FP] Network detected HFO at timestep 64869 without an active GT event
# [FP] Network detected HFO at timestep 64993 without an active GT event
# [FP] Network detected HFO at timestep 65097 without an active GT event
# [FP] Network detected HFO at timestep 65200 without an active GT event
# [FP] Network detected HFO at timestep 65301 without an active GT event
# [FP] Network detected HFO at timestep 65410 without an active GT event
# [FP] Network detected HFO at timestep 65541 without an active GT event
# [FP] Network detected HFO at timestep 65642 without an active GT event
# [FP] Network detected HFO at timestep 65839 without an active GT event
# [FP] Network detected HFO at timestep 65972 without an active GT event
# [FP] Network detected HFO at timestep 66402 without an active GT event
# [FP] Network detected HFO at timestep 66780 without an active GT event
# [FP] Network detected HFO at timestep 67110 without an active GT event
# [FP] Network detected HFO at timestep 67214 without an active GT event
# [FP] Network detected HFO at timestep 68028 without an active GT event
# [FP] Network detected HFO at timestep 68239 without an active GT event
# [FP] Network detected HFO at timestep 68356 without an active GT event
# [FP] Network detected HFO at timestep 68461 without an active GT event
# [FP] Network detected HFO at timestep 68566 without an active GT event
# [FP] Network detected HFO at timestep 68816 without an active GT event
# [FP] Network detected HFO at timestep 68965 without an active GT event
# [FP] Network detected HFO at timestep 69074 without an active GT event
# [FP] Network detected HFO at timestep 69210 without an active GT event
# [FP] Network detected HFO at timestep 69313 without an active GT event
# [FP] Network detected HFO at timestep 69421 without an active GT event
# [FP] Network detected HFO at timestep 69538 without an active GT event
# [FP] Network detected HFO at timestep 69670 without an active GT event
# [FP] Network detected HFO at timestep 69773 without an active GT event
# [FP] Network detected HFO at timestep 69874 without an active GT event
# [FP] Network detected HFO at timestep 70424 without an active GT event
# [FP] Network detected HFO at timestep 70827 without an active GT event
# [FP] Network detected HFO at timestep 70953 without an active GT event
# [FP] Network detected HFO at timestep 71055 without an active GT event
# [FP] Network detected HFO at timestep 71731 without an active GT event
# [FP] Network detected HFO at timestep 71853 without an active GT event
# [FP] Network detected HFO at timestep 71971 without an active GT event
# [FP] Network detected HFO at timestep 72260 without an active GT event
# [FP] Network detected HFO at timestep 72383 without an active GT event
# [FP] Network detected HFO at timestep 72592 without an active GT event
# [FP] Network detected HFO at timestep 72894 without an active GT event
# GT Event 48 Insertion Timing: 72965 at timestep 72965
# [TP] Spike matched GT event at timestep 72992 (GT: 72965)
# [FP] Network detected HFO at timestep 73101 without an active GT event
# [FP] Network detected HFO at timestep 73267 without an active GT event
# [FP] Network detected HFO at timestep 73416 without an active GT event
# [FP] Network detected HFO at timestep 73565 without an active GT event
# [FP] Network detected HFO at timestep 73670 without an active GT event
# [FP] Network detected HFO at timestep 73870 without an active GT event
# [FP] Network detected HFO at timestep 73988 without an active GT event
# [FP] Network detected HFO at timestep 74393 without an active GT event
# [FP] Network detected HFO at timestep 74503 without an active GT event
# [FP] Network detected HFO at timestep 74847 without an active GT event
# [FP] Network detected HFO at timestep 74954 without an active GT event
# [FP] Network detected HFO at timestep 75081 without an active GT event
# [FP] Network detected HFO at timestep 75184 without an active GT event
# [FP] Network detected HFO at timestep 75286 without an active GT event
# [FP] Network detected HFO at timestep 75392 without an active GT event
# [FP] Network detected HFO at timestep 75493 without an active GT event
# [FP] Network detected HFO at timestep 75594 without an active GT event
# [FP] Network detected HFO at timestep 75730 without an active GT event
# [FP] Network detected HFO at timestep 75833 without an active GT event
# [FP] Network detected HFO at timestep 75935 without an active GT event
# [FP] Network detected HFO at timestep 76046 without an active GT event
# [FP] Network detected HFO at timestep 76150 without an active GT event
# [FP] Network detected HFO at timestep 77294 without an active GT event
# [FP] Network detected HFO at timestep 77397 without an active GT event
# GT Event 49 Insertion Timing: 78570 at timestep 78570
# [TP] Spike matched GT event at timestep 78574 (GT: 78570)
# [FP] Network detected HFO at timestep 78675 without an active GT event
# [FP] Network detected HFO at timestep 78776 without an active GT event
# [FP] Network detected HFO at timestep 78956 without an active GT event
# [FP] Network detected HFO at timestep 79390 without an active GT event
# [FP] Network detected HFO at timestep 79670 without an active GT event
# [FP] Network detected HFO at timestep 79811 without an active GT event
# [FP] Network detected HFO at timestep 79918 without an active GT event
# GT Event 50 Insertion Timing: 80076 at timestep 80076
# [TP] Spike matched GT event at timestep 80095 (GT: 80076)
# [FP] Network detected HFO at timestep 80201 without an active GT event
# [FP] Network detected HFO at timestep 80371 without an active GT event
# [FP] Network detected HFO at timestep 80662 without an active GT event
# [FP] Network detected HFO at timestep 81188 without an active GT event
# [FP] Network detected HFO at timestep 81289 without an active GT event
# GT Event 51 Insertion Timing: 82355 at timestep 82355
# [TP] Spike matched GT event at timestep 82380 (GT: 82355)
# [FP] Network detected HFO at timestep 82486 without an active GT event
# [FP] Network detected HFO at timestep 82589 without an active GT event
# [FP] Network detected HFO at timestep 82699 without an active GT event
# [FP] Network detected HFO at timestep 82801 without an active GT event
# [FP] Network detected HFO at timestep 82904 without an active GT event
# [FP] Network detected HFO at timestep 83005 without an active GT event
# [FP] Network detected HFO at timestep 83109 without an active GT event
# [FP] Network detected HFO at timestep 83450 without an active GT event
# [FP] Network detected HFO at timestep 83564 without an active GT event
# [FP] Network detected HFO at timestep 83700 without an active GT event
# [FP] Network detected HFO at timestep 83808 without an active GT event
# [FP] Network detected HFO at timestep 83912 without an active GT event
# [FP] Network detected HFO at timestep 84688 without an active GT event
# [FP] Network detected HFO at timestep 84791 without an active GT event
# [FP] Network detected HFO at timestep 85038 without an active GT event
# [FP] Network detected HFO at timestep 85236 without an active GT event
# [FP] Network detected HFO at timestep 85724 without an active GT event
# [FP] Network detected HFO at timestep 85845 without an active GT event
# [FP] Network detected HFO at timestep 86255 without an active GT event
# [FP] Network detected HFO at timestep 86367 without an active GT event
# [FP] Network detected HFO at timestep 86973 without an active GT event
# [FP] Network detected HFO at timestep 87128 without an active GT event
# [FP] Network detected HFO at timestep 87520 without an active GT event
# [FP] Network detected HFO at timestep 87621 without an active GT event
# [FP] Network detected HFO at timestep 88383 without an active GT event
# [FP] Network detected HFO at timestep 88490 without an active GT event
# [FP] Network detected HFO at timestep 88722 without an active GT event
# GT Event 52 Insertion Timing: 88752 at timestep 88752
# [TP] Spike matched GT event at timestep 88788 (GT: 88752)
# [FP] Network detected HFO at timestep 88889 without an active GT event
# [FP] Network detected HFO at timestep 89001 without an active GT event
# [FP] Network detected HFO at timestep 89373 without an active GT event
# [FP] Network detected HFO at timestep 89479 without an active GT event
# [FP] Network detected HFO at timestep 89580 without an active GT event
# [FP] Network detected HFO at timestep 89682 without an active GT event
# [FP] Network detected HFO at timestep 89789 without an active GT event
# [FP] Network detected HFO at timestep 89912 without an active GT event
# [FP] Network detected HFO at timestep 90214 without an active GT event
# [FP] Network detected HFO at timestep 90422 without an active GT event
# [FP] Network detected HFO at timestep 90530 without an active GT event
# [FP] Network detected HFO at timestep 90633 without an active GT event
# [FP] Network detected HFO at timestep 90791 without an active GT event
# [FP] Network detected HFO at timestep 90895 without an active GT event
# [FP] Network detected HFO at timestep 91027 without an active GT event
# [FP] Network detected HFO at timestep 91163 without an active GT event
# [FP] Network detected HFO at timestep 91265 without an active GT event
# [FP] Network detected HFO at timestep 91366 without an active GT event
# [FP] Network detected HFO at timestep 91596 without an active GT event
# [FP] Network detected HFO at timestep 91698 without an active GT event
# [FP] Network detected HFO at timestep 91806 without an active GT event
# [FP] Network detected HFO at timestep 91910 without an active GT event
# [FP] Network detected HFO at timestep 92088 without an active GT event
# [FP] Network detected HFO at timestep 92189 without an active GT event
# [FP] Network detected HFO at timestep 92291 without an active GT event
# [FP] Network detected HFO at timestep 92423 without an active GT event
# [FP] Network detected HFO at timestep 92580 without an active GT event
# [FP] Network detected HFO at timestep 92763 without an active GT event
# [FP] Network detected HFO at timestep 92969 without an active GT event
# [FP] Network detected HFO at timestep 93077 without an active GT event
# [FP] Network detected HFO at timestep 93182 without an active GT event
# [FP] Network detected HFO at timestep 93308 without an active GT event
# [FP] Network detected HFO at timestep 93411 without an active GT event
# [FP] Network detected HFO at timestep 93515 without an active GT event
# [FP] Network detected HFO at timestep 93618 without an active GT event
# [FP] Network detected HFO at timestep 93753 without an active GT event
# [FP] Network detected HFO at timestep 93881 without an active GT event
# [FP] Network detected HFO at timestep 93992 without an active GT event
# [FP] Network detected HFO at timestep 94099 without an active GT event
# [FP] Network detected HFO at timestep 94211 without an active GT event
# [FP] Network detected HFO at timestep 94316 without an active GT event
# [FP] Network detected HFO at timestep 94614 without an active GT event
# [FP] Network detected HFO at timestep 94855 without an active GT event
# [FP] Network detected HFO at timestep 95243 without an active GT event
# [FP] Network detected HFO at timestep 95506 without an active GT event
# [FP] Network detected HFO at timestep 95609 without an active GT event
# [FP] Network detected HFO at timestep 95726 without an active GT event
# [FP] Network detected HFO at timestep 95871 without an active GT event
# [FP] Network detected HFO at timestep 96360 without an active GT event
# [FP] Network detected HFO at timestep 96461 without an active GT event
# [FP] Network detected HFO at timestep 96566 without an active GT event
# [FP] Network detected HFO at timestep 96684 without an active GT event
# [FP] Network detected HFO at timestep 96803 without an active GT event
# [FP] Network detected HFO at timestep 96906 without an active GT event
# [FP] Network detected HFO at timestep 97008 without an active GT event
# GT Event 53 Insertion Timing: 97053 at timestep 97053
# [TP] Spike matched GT event at timestep 97088 (GT: 97053)
# [FP] Network detected HFO at timestep 97188 without an active GT event
# [FP] Network detected HFO at timestep 97303 without an active GT event
# [FP] Network detected HFO at timestep 97414 without an active GT event
# [FP] Network detected HFO at timestep 97601 without an active GT event
# GT Event 54 Insertion Timing: 97709 at timestep 97709
# [TP] Spike matched GT event at timestep 97742 (GT: 97709)
# [FP] Network detected HFO at timestep 97846 without an active GT event
# GT Event 55 Insertion Timing: 97919 at timestep 97919
# [TP] Spike matched GT event at timestep 97957 (GT: 97919)
# [FP] Network detected HFO at timestep 98057 without an active GT event
# [FP] Network detected HFO at timestep 98165 without an active GT event
# GT Event 56 Insertion Timing: 98166 at timestep 98166
# [TP] Spike matched GT event at timestep 98193 (GT: 98166)
# GT Event 57 Insertion Timing: 98235 at timestep 98235
# [TP] Spike matched GT event at timestep 98293 (GT: 98235)
# [FP] Network detected HFO at timestep 98408 without an active GT event
# [FP] Network detected HFO at timestep 98693 without an active GT event
# [FP] Network detected HFO at timestep 99227 without an active GT event
# [FP] Network detected HFO at timestep 99370 without an active GT event
# [FP] Network detected HFO at timestep 99814 without an active GT event
# [FP] Network detected HFO at timestep 99915 without an active GT event
# Processed step 100000/8321032 (1.20%)
# [FP] Network detected HFO at timestep 100020 without an active GT event
# [FP] Network detected HFO at timestep 100126 without an active GT event
# [FP] Network detected HFO at timestep 100254 without an active GT event
# [FP] Network detected HFO at timestep 100363 without an active GT event
# [FP] Network detected HFO at timestep 100601 without an active GT event
# [FP] Network detected HFO at timestep 100745 without an active GT event
# [FP] Network detected HFO at timestep 100851 without an active GT event
# [FP] Network detected HFO at timestep 100953 without an active GT event
# [FP] Network detected HFO at timestep 101060 without an active GT event
# [FP] Network detected HFO at timestep 101237 without an active GT event
# GT Event 58 Insertion Timing: 101330 at timestep 101330
# [TP] Spike matched GT event at timestep 101337 (GT: 101330)
# [FP] Network detected HFO at timestep 101438 without an active GT event
# GT Event 59 Insertion Timing: 101602 at timestep 101602
# [TP] Spike matched GT event at timestep 101645 (GT: 101602)
# [FP] Network detected HFO at timestep 101746 without an active GT event
# [FP] Network detected HFO at timestep 101847 without an active GT event
# [FP] Network detected HFO at timestep 101949 without an active GT event
# [FP] Network detected HFO at timestep 102053 without an active GT event
# [FP] Network detected HFO at timestep 102159 without an active GT event
# [FP] Network detected HFO at timestep 102270 without an active GT event
# [FP] Network detected HFO at timestep 102379 without an active GT event
# GT Event 60 Insertion Timing: 102475 at timestep 102475
# [TP] Spike matched GT event at timestep 102490 (GT: 102475)
# [FP] Network detected HFO at timestep 102592 without an active GT event
# GT Event 61 Insertion Timing: 102634 at timestep 102634
# [TP] Spike matched GT event at timestep 102650 (GT: 102634)
# ...
# GT Event 2190 Insertion Timing: 5906940 at timestep 5906940
# [TP] Spike matched GT event at timestep 5907010 (GT: 5906940)
# GT Event 2191 Insertion Timing: 5907175 at timestep 5907175
# [TP] Spike matched GT event at timestep 5907207 (GT: 5907175)
# [FP] Network detected HFO at timestep 5907311 without an active GT event
# GT Event 2192 Insertion Timing: 5907962 at timestep 5907962
# [TP] Spike matched GT event at timestep 5907986 (GT: 5907962)
# [FP] Network detected HFO at timestep 5908093 without an active GT event
# [FP] Network detected HFO at timestep 5908492 without an active GT event
# GT Event 2193 Insertion Timing: 5908568 at timestep 5908568
# [TP] Spike matched GT event at timestep 5908597 (GT: 5908568)
# [FP] Network detected HFO at timestep 5908702 without an active GT event
# GT Event 2194 Insertion Timing: 5908736 at timestep 5908736
# [TP] Spike matched GT event at timestep 5908750 (GT: 5908736)
# [FP] Network detected HFO at timestep 5908851 without an active GT event
# [FP] Network detected HFO at timestep 5908953 without an active GT event
# [FP] Network detected HFO at timestep 5909054 without an active GT event
# [FP] Network detected HFO at timestep 5909155 without an active GT event
# [FP] Network detected HFO at timestep 5910758 without an active GT event
# GT Event 2195 Insertion Timing: 5910880 at timestep 5910880
# [TP] Spike matched GT event at timestep 5910922 (GT: 5910880)
# [FP] Network detected HFO at timestep 5911025 without an active GT event
# [FP] Network detected HFO at timestep 5911620 without an active GT event
# GT Event 2196 Insertion Timing: 5911634 at timestep 5911634
# [TP] Spike matched GT event at timestep 5911653 (GT: 5911634)
# [FP] Network detected HFO at timestep 5911753 without an active GT event
# GT Event 2197 Insertion Timing: 5912022 at timestep 5912022
# [TP] Spike matched GT event at timestep 5912052 (GT: 5912022)
# [FP] Network detected HFO at timestep 5912155 without an active GT event
# [FP] Network detected HFO at timestep 5912260 without an active GT event
# GT Event 2198 Insertion Timing: 5912420 at timestep 5912420
# [TP] Spike matched GT event at timestep 5912468 (GT: 5912420)
# [FP] Network detected HFO at timestep 5912568 without an active GT event
# [FP] Network detected HFO at timestep 5912671 without an active GT event
# GT Event 2199 Insertion Timing: 5912672 at timestep 5912672
# [TP] Spike matched GT event at timestep 5912710 (GT: 5912672)
# GT Event 2200 Insertion Timing: 5912771 at timestep 5912771
# [TP] Spike matched GT event at timestep 5912811 (GT: 5912771)
# [FP] Network detected HFO at timestep 5912917 without an active GT event
# GT Event 2201 Insertion Timing: 5914613 at timestep 5914613
# [TP] Spike matched GT event at timestep 5914662 (GT: 5914613)
# [FP] Network detected HFO at timestep 5914765 without an active GT event
# [FP] Network detected HFO at timestep 5919828 without an active GT event
# [FP] Network detected HFO at timestep 5919930 without an active GT event
# [FP] Network detected HFO at timestep 5920032 without an active GT event
# [FP] Network detected HFO at timestep 5920135 without an active GT event
# [FP] Network detected HFO at timestep 5921483 without an active GT event
# GT Event 2202 Insertion Timing: 5921523 at timestep 5921523
# [TP] Spike matched GT event at timestep 5921551 (GT: 5921523)
# [FP] Network detected HFO at timestep 5921653 without an active GT event
# [FP] Network detected HFO at timestep 5922296 without an active GT event
# [FP] Network detected HFO at timestep 5922576 without an active GT event
# GT Event 2203 Insertion Timing: 5922780 at timestep 5922780
# [TP] Spike matched GT event at timestep 5922817 (GT: 5922780)
# [FP] Network detected HFO at timestep 5922918 without an active GT event
# [FP] Network detected HFO at timestep 5923019 without an active GT event
# [FP] Network detected HFO at timestep 5924155 without an active GT event
# [FP] Network detected HFO at timestep 5926713 without an active GT event
# [FP] Network detected HFO at timestep 5926882 without an active GT event
# [FP] Network detected HFO at timestep 5927047 without an active GT event
# [FP] Network detected HFO at timestep 5927469 without an active GT event
# [FP] Network detected HFO at timestep 5927585 without an active GT event
# [FP] Network detected HFO at timestep 5927874 without an active GT event
# [FP] Network detected HFO at timestep 5929060 without an active GT event
# [FP] Network detected HFO at timestep 5929169 without an active GT event
# [FP] Network detected HFO at timestep 5929724 without an active GT event
# [FP] Network detected HFO at timestep 5929828 without an active GT event
# [FP] Network detected HFO at timestep 5929932 without an active GT event
# [FP] Network detected HFO at timestep 5930035 without an active GT event
# [FP] Network detected HFO at timestep 5930424 without an active GT event
# [FP] Network detected HFO at timestep 5930577 without an active GT event
# [FP] Network detected HFO at timestep 5930963 without an active GT event
# [FP] Network detected HFO at timestep 5931236 without an active GT event
# [FP] Network detected HFO at timestep 5932237 without an active GT event
# GT Event 2204 Insertion Timing: 5932701 at timestep 5932701
# [TP] Spike matched GT event at timestep 5932734 (GT: 5932701)
# [FP] Network detected HFO at timestep 5932862 without an active GT event
# [FP] Network detected HFO at timestep 5932969 without an active GT event
# GT Event 2205 Insertion Timing: 5933033 at timestep 5933033
# [TP] Spike matched GT event at timestep 5933042 (GT: 5933033)
# [FP] Network detected HFO at timestep 5933142 without an active GT event
# GT Event 2206 Insertion Timing: 5933228 at timestep 5933228
# [TP] Spike matched GT event at timestep 5933244 (GT: 5933228)
# [FP] Network detected HFO at timestep 5933345 without an active GT event
# [FP] Network detected HFO at timestep 5933888 without an active GT event
# [FP] Network detected HFO at timestep 5934799 without an active GT event
# [FP] Network detected HFO at timestep 5934913 without an active GT event
# [FP] Network detected HFO at timestep 5935114 without an active GT event
# [FP] Network detected HFO at timestep 5935249 without an active GT event
# [FP] Network detected HFO at timestep 5935350 without an active GT event
# [FP] Network detected HFO at timestep 5935607 without an active GT event
# [FP] Network detected HFO at timestep 5935708 without an active GT event
# GT Event 2207 Insertion Timing: 5936481 at timestep 5936481
# [TP] Spike matched GT event at timestep 5936533 (GT: 5936481)
# [FP] Network detected HFO at timestep 5937057 without an active GT event
# [FP] Network detected HFO at timestep 5937449 without an active GT event
# [FP] Network detected HFO at timestep 5937885 without an active GT event
# [FP] Network detected HFO at timestep 5938137 without an active GT event
# [FP] Network detected HFO at timestep 5938239 without an active GT event
# GT Event 2208 Insertion Timing: 5938303 at timestep 5938303
# [TP] Spike matched GT event at timestep 5938323 (GT: 5938303)
# [FP] Network detected HFO at timestep 5938423 without an active GT event
# [FP] Network detected HFO at timestep 5938524 without an active GT event
# [FP] Network detected HFO at timestep 5938629 without an active GT event
# [FP] Network detected HFO at timestep 5938865 without an active GT event
# [FP] Network detected HFO at timestep 5939466 without an active GT event
# [FP] Network detected HFO at timestep 5940229 without an active GT event
# GT Event 2209 Insertion Timing: 5941565 at timestep 5941565
# [TP] Spike matched GT event at timestep 5941585 (GT: 5941565)
# [FP] Network detected HFO at timestep 5941685 without an active GT event
# [FP] Network detected HFO at timestep 5941794 without an active GT event
# [FP] Network detected HFO at timestep 5941967 without an active GT event
# [FP] Network detected HFO at timestep 5942451 without an active GT event
# GT Event 2210 Insertion Timing: 5942523 at timestep 5942523
# [TP] Spike matched GT event at timestep 5942533 (GT: 5942523)
# [FP] Network detected HFO at timestep 5942634 without an active GT event
# [FP] Network detected HFO at timestep 5942737 without an active GT event
# [FP] Network detected HFO at timestep 5943296 without an active GT event
# GT Event 2211 Insertion Timing: 5943358 at timestep 5943358
# [TP] Spike matched GT event at timestep 5943368 (GT: 5943358)
# [FP] Network detected HFO at timestep 5943468 without an active GT event
# GT Event 2212 Insertion Timing: 5943735 at timestep 5943735
# [TP] Spike matched GT event at timestep 5943761 (GT: 5943735)
# [FP] Network detected HFO at timestep 5943903 without an active GT event
# [FP] Network detected HFO at timestep 5944314 without an active GT event
# [FP] Network detected HFO at timestep 5947116 without an active GT event
# [FP] Network detected HFO at timestep 5947909 without an active GT event
# [FP] Network detected HFO at timestep 5949643 without an active GT event
# [FP] Network detected HFO at timestep 5949840 without an active GT event
# [FP] Network detected HFO at timestep 5952153 without an active GT event
# GT Event 2213 Insertion Timing: 5952212 at timestep 5952212
# [TP] Spike matched GT event at timestep 5952233 (GT: 5952212)
# [FP] Network detected HFO at timestep 5952333 without an active GT event
# GT Event 2214 Insertion Timing: 5952347 at timestep 5952347
# [TP] Spike matched GT event at timestep 5952362 (GT: 5952347)
# [FP] Network detected HFO at timestep 5952470 without an active GT event
# GT Event 2215 Insertion Timing: 5952476 at timestep 5952476
# [TP] Spike matched GT event at timestep 5952479 (GT: 5952476)
# [FP] Network detected HFO at timestep 5952586 without an active GT event
# [FP] Network detected HFO at timestep 5954991 without an active GT event
# GT Event 2216 Insertion Timing: 5956291 at timestep 5956291
# [TP] Spike matched GT event at timestep 5956334 (GT: 5956291)
# [FP] Network detected HFO at timestep 5956455 without an active GT event
# [FP] Network detected HFO at timestep 5956803 without an active GT event
# [FP] Network detected HFO at timestep 5956985 without an active GT event
# [FP] Network detected HFO at timestep 5957386 without an active GT event
# [FP] Network detected HFO at timestep 5957503 without an active GT event
# [FP] Network detected HFO at timestep 5957605 without an active GT event
# [FP] Network detected HFO at timestep 5957707 without an active GT event
# [FP] Network detected HFO at timestep 5957833 without an active GT event
# [FP] Network detected HFO at timestep 5957971 without an active GT event
# [FP] Network detected HFO at timestep 5958123 without an active GT event
# [FP] Network detected HFO at timestep 5958254 without an active GT event
# [FP] Network detected HFO at timestep 5958467 without an active GT event
# [FP] Network detected HFO at timestep 5958570 without an active GT event
# [FP] Network detected HFO at timestep 5958672 without an active GT event
# [FP] Network detected HFO at timestep 5958776 without an active GT event
# [FP] Network detected HFO at timestep 5958884 without an active GT event
# [FP] Network detected HFO at timestep 5959004 without an active GT event
# [FP] Network detected HFO at timestep 5959145 without an active GT event
# [FP] Network detected HFO at timestep 5959254 without an active GT event
# [FP] Network detected HFO at timestep 5959381 without an active GT event
# [FP] Network detected HFO at timestep 5959519 without an active GT event
# [FP] Network detected HFO at timestep 5959676 without an active GT event
# [FP] Network detected HFO at timestep 5959794 without an active GT event
# [FP] Network detected HFO at timestep 5959896 without an active GT event
# [FP] Network detected HFO at timestep 5960006 without an active GT event
# [FP] Network detected HFO at timestep 5960162 without an active GT event
# [FP] Network detected HFO at timestep 5960268 without an active GT event
# [FP] Network detected HFO at timestep 5960370 without an active GT event
# [FP] Network detected HFO at timestep 5960473 without an active GT event
# [FP] Network detected HFO at timestep 5960577 without an active GT event
# [FP] Network detected HFO at timestep 5960680 without an active GT event
# [FP] Network detected HFO at timestep 5960785 without an active GT event
# [FP] Network detected HFO at timestep 5960886 without an active GT event
# [FP] Network detected HFO at timestep 5960994 without an active GT event
# [FP] Network detected HFO at timestep 5961097 without an active GT event
# [FP] Network detected HFO at timestep 5961220 without an active GT event
# [FP] Network detected HFO at timestep 5961330 without an active GT event
# [FP] Network detected HFO at timestep 5961480 without an active GT event
# [FP] Network detected HFO at timestep 5961594 without an active GT event
# [FP] Network detected HFO at timestep 5961715 without an active GT event
# [FP] Network detected HFO at timestep 5961825 without an active GT event
# [FP] Network detected HFO at timestep 5961943 without an active GT event
# [FP] Network detected HFO at timestep 5962110 without an active GT event
# [FP] Network detected HFO at timestep 5962232 without an active GT event
# [FP] Network detected HFO at timestep 5962358 without an active GT event
# [FP] Network detected HFO at timestep 5962475 without an active GT event
# [FP] Network detected HFO at timestep 5963820 without an active GT event
# [FP] Network detected HFO at timestep 5966080 without an active GT event
# [FP] Network detected HFO at timestep 5966186 without an active GT event
# [FP] Network detected HFO at timestep 5966288 without an active GT event
# [FP] Network detected HFO at timestep 5966522 without an active GT event
# [FP] Network detected HFO at timestep 5966704 without an active GT event
# [FP] Network detected HFO at timestep 5966809 without an active GT event
# [FP] Network detected HFO at timestep 5966933 without an active GT event
# [FP] Network detected HFO at timestep 5967107 without an active GT event
# [FP] Network detected HFO at timestep 5967245 without an active GT event
# [FP] Network detected HFO at timestep 5967347 without an active GT event
# [FP] Network detected HFO at timestep 5967465 without an active GT event
# [FP] Network detected HFO at timestep 5967597 without an active GT event
# [FP] Network detected HFO at timestep 5967703 without an active GT event
# [FP] Network detected HFO at timestep 5967857 without an active GT event
# [FP] Network detected HFO at timestep 5967969 without an active GT event
# [FP] Network detected HFO at timestep 5968128 without an active GT event
# [FP] Network detected HFO at timestep 5968231 without an active GT event
# [FP] Network detected HFO at timestep 5968343 without an active GT event
# [FP] Network detected HFO at timestep 5968445 without an active GT event
# [FP] Network detected HFO at timestep 5968550 without an active GT event
# [FP] Network detected HFO at timestep 5968657 without an active GT event
# [FP] Network detected HFO at timestep 5968762 without an active GT event
# [FP] Network detected HFO at timestep 5968868 without an active GT event
# [FP] Network detected HFO at timestep 5968975 without an active GT event
# [FP] Network detected HFO at timestep 5969123 without an active GT event
# [FP] Network detected HFO at timestep 5969224 without an active GT event
# [FP] Network detected HFO at timestep 5969410 without an active GT event
# [FP] Network detected HFO at timestep 5969646 without an active GT event
# [FP] Network detected HFO at timestep 5969747 without an active GT event
# [FP] Network detected HFO at timestep 5969868 without an active GT event
# [FP] Network detected HFO at timestep 5969974 without an active GT event
# [FP] Network detected HFO at timestep 5970075 without an active GT event
# [FP] Network detected HFO at timestep 5970193 without an active GT event
# [FP] Network detected HFO at timestep 5970294 without an active GT event
# [FP] Network detected HFO at timestep 5970419 without an active GT event
# [FP] Network detected HFO at timestep 5970526 without an active GT event
# [FP] Network detected HFO at timestep 5970712 without an active GT event
# [FP] Network detected HFO at timestep 5970820 without an active GT event
# [FP] Network detected HFO at timestep 5970974 without an active GT event

# %%
# Show the Confusion Matrix
print(f"Confusion Matrix:")

# Print lines with same width
print(f"|TP: {TP} | FP: {FP}|\n|FN: {FN}  | TN: {TN}|")
if TP + FN != num_hfo_events:
    print("Mismatch in GT events")
    print(f"TP + FN: {TP + FN} | num_hfo_events: {num_hfo_events}")
# Out:
# Confusion Matrix:
# |TP: 2447 | FP: 14141|
# |FN: 1217  | TN: 8165928|

# %%
# Calculate the performance metrics
accuracy = round(((TP + TN) / (TP + TN + FP + FN)), 5)
recall = TP / (TP + FN) if (TP + FN) > 0 else 0
specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
false_positive_rate = FP / (FP + TN + 1e-10)

# %%
# Output the performance metrics
print(f"Accuracy (Right Prediction ): {accuracy:.4f}")
print(f"Recall (True Positive Rate): {recall:.4f}")
print(f"Specificity (True Negative Rate): {specificity:.4f}")
print(f"Precision (TP / (TP + FP)): {precision:.4f}")
print(f"F1 Score (Combines Precision & Recall): {f1_score:.4f}")
print(f"False Positive Rate (FP / (FP + TN)): {false_positive_rate:.4f}")
print(f"TP: {TP} | FP: {FP} | TN: {TN} | FN: {FN}")
# Out:
# Accuracy (Right Prediction ): 0.9981
# Recall (True Positive Rate): 0.6678
# Specificity (True Negative Rate): 0.9983
# Precision (TP / (TP + FP)): 0.1475
# F1 Score (Combines Precision & Recall): 0.2417
# False Positive Rate (FP / (FP + TN)): 0.0017
# TP: 2447 | FP: 14141 | TN: 8165928 | FN: 1217

# %%
total_predictions = TP + FP + TN + FN
print(f"Total Predictions: {total_predictions}")
print(f"Total Timesteps: {total_num_steps}")
# Out:
# Total Predictions: 8183733
# Total Timesteps: 8321032

# %%
import json

# Export the results to a JSON file
OUTPUT_FOLDER = f"eval/"
# create the output folder if it doesn't exist
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# Create a dictionary with the results
json_results = {
    "ripple_detection_offset": RIPPLE_DETECTION_OFFSET,
    "pred_causality_window": PRED_CAUSALITY_WINDOW,
    "max_detection_offset": MAX_DETECTION_OFFSET,
    "refractory_period_gt": refrac_period_gt,
    "refractory_period_fp": refrac_period_fp,
    "metrics": {
        "true_positive": TP,
        "false_positive": FP,
        "true_negative": TN,
        "false_negative": FN,
        "total_predictions": total_predictions,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1_score,
        "specificity": specificity
    }
}

EXPORT_JSON_FILE = True
if EXPORT_JSON_FILE:
    json_file_name = f"{OUTPUT_FOLDER}/{prefix}_results.json"
    with open(json_file_name, 'w') as f:
        json.dump(json_results, f,indent=4)

    print(f"Results exported to {json_file_name}")
else:
    print(json_results)
# Out:
# Results exported to eval//updnb4ds_100_6_results.json

# %%
out_spikes = np.array(out_spikes)
EXPORT_SPIKE_FILE = True
SPIKE_FOLDER= f"eval/spikes/"
if EXPORT_SPIKE_FILE:
    # create the output folder if it doesn't exist
    os.makedirs(SPIKE_FOLDER, exist_ok=True)
    spike_file_name = f"{SPIKE_FOLDER}/{prefix}_spikes_.npy"
    np.save(spike_file_name, out_spikes)
