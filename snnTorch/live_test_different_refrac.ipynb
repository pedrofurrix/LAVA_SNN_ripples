# %% [markdown]
# # SNN Evaluation on Real-Time Data
# In this notebook, we test the performance of trained SNNs on a real-time stream of data.
# Based (or copied) from Mesquita's [repository](https://github.com/monkin77/snn-torch/blob/master/src/hfo/5_detection/hfo_evaluation.ipynb)

# %%
# Show current directory
import os
curr_dir = os.getcwd()
print(curr_dir)

from collections import deque
# Out:
# c:\Users\NCN\Documents\PedroFelix\LAVA_SNN_ripples\snnTorch

# %% [markdown]
# ## Add Parent Directory to Path

# %%
import sys
parent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir))
# Add the grandparent directory to the system path
# grandparent_dir = os.path.abspath(os.path.join(curr_dir, os.pardir, os.pardir))
sys.path.append(parent_dir)
print(sys.path)
# Out:
# ['c:\\nrn\\lib\\python', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\python39.zip', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\DLLs', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples', '', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib\\site-packages', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib\\site-packages\\win32', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib\\site-packages\\win32\\lib', 'c:\\Users\\NCN\\Miniconda3\\envs\\lava_snn_ripples\\lib\\site-packages\\Pythonwin', 'c:\\Users\\NCN\\Documents\\PedroFelix\\LAVA_SNN_ripples']

# %% [markdown]
# ## Check if Cuda is available

# %%
import torch
import numpy as np

# Check CUDA Installation
print(torch.cuda.is_available())

# Get the number of available GPUs
num_gpus = torch.cuda.device_count()
print(f"Number of GPUs: {num_gpus}")

# Get information about each GPU
for i in range(num_gpus):
    device_props = torch.cuda.get_device_properties(i)
    print(f"\nGPU {i}:")
    print(f"  Name: {device_props.name}")
    print(f"  Total memory: {device_props.total_memory / 1024**3:.2f} GB")
    print(f"  Multiprocessor count: {device_props.multi_processor_count}")
    print(f"  Major compute capability: {device_props.major}")
    print(f"  Minor compute capability: {device_props.minor}")
# Out:
# False
# Number of GPUs: 0

# %% [markdown]
# ## Define the Device that will be used to train the SNN

# %%
# Set the device to be used
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")     # torch.device("cpu") #

print("device: ", device)
# Out:
# device:  cpu

# %% [markdown]
# ## Define Problem and Simulation Parameters

# %%
# ----- Simulation Time Parameters -----
dt = 1                         # Time between two timesteps (ms), a.k.a. virtual time step interval. (NOT ALIGNED WITH THE SAMPLING RATE OF THE INPUT DATA (2048 Hz)
init_offset = 0 # 900 # 33400      #

# %%
# unit: timesteps (ms) - The time window after the GT annotation where the network should predict the burst (GT_time, GT_time + PRED_CAUSALITY_WINDOW)
# This is needed to give the network some extra time steps to increase the membrane potential and spike
RIPPLE_DETECTION_OFFSET = [18, 45, 31, 20]
PRED_CAUSALITY_WINDOW = int(5)     # Giving PRED_CAUSALITY_WINDOW ms for the network to update its inner state and spike  
# in timesteps (ms) - Max time from the Insertion Timing to the GT annotation

MAX_DETECTION_OFFSET = int(RIPPLE_DETECTION_OFFSET[1]) * 1.5 + PRED_CAUSALITY_WINDOW   # in timesteps (ms)

print(f"PRED_CAUSALITY_WINDOW: {PRED_CAUSALITY_WINDOW}")
print(f"MAX_DETECTION_OFFSET: {MAX_DETECTION_OFFSET} ms")
# Out:
# PRED_CAUSALITY_WINDOW: 5
# MAX_DETECTION_OFFSET: 72.5 ms

# %% [markdown]
# ## Read the Input Data and the Ground Truth

# %%
downsampled_fs="30000_1000"
data_dir=os.path.join(parent_dir,"extract_Nripples","train_pedro","dataset_up_down",str(downsampled_fs))

# %%
concat_data=np.load(os.path.join(data_dir,"concat_spikes.npy"),allow_pickle=True)
ripples_GT=np.load(os.path.join(data_dir,"concat_ripples.npy"),allow_pickle=True)

# %%
print("Number of UP spikes: ", np.sum(concat_data[:, 0]))
print("Number of DN spikes: ", np.sum(concat_data[:, 1]))
# Out:
# Number of UP spikes:  275624
# Number of DN spikes:  277940

# %% [markdown]
# ## Point of Situation
#
# Right now, we have the following:
#
# -  `concat_data` of shape (num_steps, 2) containing the UP and DN spikes.
# - `ripples_GT` of shape (num_gt_events,2) containing the timestamps (beginning and end) of every ripple

# %%
# Define the number of total timesteps
total_num_steps = concat_data.shape[0]
num_hfo_events = ripples_GT.shape[0]
num_hfo_timesteps=np.sum(ripples_GT[:, 1] - ripples_GT[:, 0])
print(f"Number of HFO Events: {num_hfo_events}")
print(f"Total number of timesteps: {total_num_steps}")
print("Num of Ripple timesteps:", num_hfo_timesteps)
# Out:
# Number of HFO Events: 3664
# Total number of timesteps: 8321032
# Num of Ripple timesteps: 185776

# %%
# Transform ripples_GT into the time of onset...
ripples_start=ripples_GT[:,0]
print("Ripples start: ", ripples_start[:10])
# Out:
# Ripples start:  [ 568  969 1629 3952 5006 5225 5772 6039 6479 6869]

# %%
distance_ripples=ripples_start[1:] - ripples_start[:-1]
average_distance=np.mean(distance_ripples)
median_distance=np.median(distance_ripples)
min_distance=np.min(distance_ripples)
percentile_25=np.percentile(distance_ripples, 10)                            
print(f"Average distance between ripples: {average_distance} ms")
print(f"Median distance between ripples: {median_distance} ms")
print(f"Minimum distance between ripples: {min_distance} ms")
print(f"25th Percentile distance between ripples: {percentile_25} ms")
# Out:
# Average distance between ripples: 2271.054873054873 ms
# Median distance between ripples: 475.0 ms
# Minimum distance between ripples: 62 ms
# 25th Percentile distance between ripples: 128.0 ms

# %%
# ------------------- Network Parameters -------------------
# We know that 2 relevant events do not occur within the confidence window of an HFO event, so we set the refractory period accordingly
refrac_period_fp =100 # floor(MAX_DETECTION_OFFSET / dt)   # Number of time-steps for the refractory period
refrac_period_gt= 100
print(f"Refractory Period: {refrac_period_gt} steps")
print(f"Refractory Period: {refrac_period_fp} steps")
# Out:
# Refractory Period: 200 steps
# Refractory Period: 200 steps

# %% [markdown]
# ## Create the Dataset and Dataloader to user tensor-ready data

# %%
from torch.utils.data import TensorDataset, DataLoader

# Convert numpy arrays to PyTorch tensors and move them to the selected device
input_tensor = torch.tensor(concat_data,dtype=torch.float32).to(device)
gt_tensor=torch.tensor(ripples_start,dtype=torch.float32).to(device)
# gt_tensor = torch.from_numpy(ripples_start).to(device)
# gt_tensor = torch.from_numpy(ripples_start).to(device)

# %%
# Show the shape of the tensors
print("Input tensor shape: ", input_tensor.shape)
print("GT tensor shape: ", gt_tensor.shape)
# Out:
# Input tensor shape:  torch.Size([8321032, 2])
# GT tensor shape:  torch.Size([3664])

# %% [markdown]
# ## Define the SNN Architecture
# Similar to what we trained before

# %%
import snntorch as snn
import torch.nn as nn
from snntorch import surrogate

# Global Parameters
v_thr = 1.0
placeholder_val = 0.5

# Define the surrogate gradient function to propagate spikes through the network
spike_grad = surrogate.fast_sigmoid()   # surrogate.atan()

# %%
# Parameters for Dense Layers
inputDataDim = 2       # max_channel_idx - min_channel_idx + 1    # Number of input channels

input_to_hidden = (inputDataDim, 24) # 16 # TODO: Increase the size of this layer # (inputDataDim, 100) # (inputDataDim, 500)  # Number of neurons in the first Fully-Connected Layer

hiddenL2Dim = (input_to_hidden[1], input_to_hidden[1])  # Number of neurons in the Recurrent Fully-Connected Layer (L2)

hiddenL3Dim = (input_to_hidden[1], 16)  # Number of neurons in the Fully-Connected Layer (L3)

hiddenL4Dim = (hiddenL3Dim[1], input_to_hidden[1])  # Number of neurons in the Recurrent Fully-Connected Layer (L4)

hidden_to_out = (hiddenL3Dim[1], 1)  # Number of neurons in the Output Fully-Connected Layer
# In this case, we only need 1 output neuron -> Fires when HFO is detected

# %%
# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        
        # Create a Linear Layer to serve input to LIF1
        self.fc_in = nn.Linear(input_to_hidden[0], input_to_hidden[1],
                bias=False,
                dtype=torch.float32     # Set the data type of the weights to float32
        )

        # TODO: Should the LIF neurons be able to get a negative membrane potential? I think so?
        self.lif1 = snn.Synaptic(
            alpha=torch.full(size=(input_to_hidden[1],), fill_value=placeholder_val), 
            beta=torch.full(size=(input_to_hidden[1],), fill_value=placeholder_val),
            threshold=v_thr,
            reset_mechanism="zero", reset_delay=False,
            # TODO: How to add Refractory Period?
            # init_hidden=True,   # enables the methods in snntorch.backprop to automatically clear the hidden states and detach them from the comp. graph
            spike_grad=spike_grad,
            learn_alpha=True,   # Learn the alpha parameter
            learn_beta=True,    # Learn the beta parameter
            learn_threshold=False,   # Learn the threshold parameter
            
        )      

        """ self.fc2 = nn.Linear(
            hiddenL2Dim[0], hiddenL2Dim[1],
            bias=False,
            dtype=torch.float32     # Set the data type of the weights to float32
        ) """

        self.fc3 = nn.Linear(
            hiddenL3Dim[0], hiddenL3Dim[1],
            bias=False,
            dtype=torch.float32     # Set the data type of the weights to float32
        )

        self.lif2 = snn.Synaptic(
            alpha=torch.full(size=(hiddenL3Dim[1],), fill_value=placeholder_val), 
            beta=torch.full(size=(hiddenL3Dim[1],), fill_value=placeholder_val),
            threshold=v_thr,
            reset_mechanism="zero", reset_delay=False,
            # TODO: How to add Refractory Period?
            # init_hidden=True,   # enables the methods in snntorch.backprop to automatically clear the hidden states and detach them from the comp. graph
            spike_grad=spike_grad,
            learn_alpha=True,   # Learn the alpha parameter
            learn_beta=True,    # Learn the beta parameter
            learn_threshold=False,   # Learn the threshold parameter
        )   

        """ self.fc4 = nn.Linear(
            hiddenL4Dim[0], hiddenL4Dim[1],
            bias=False,
            dtype=torch.float32     # Set the data type of the weights to float32
        ) """

        self.fc_out = nn.Linear(
            hidden_to_out[0], hidden_to_out[1],
            bias=False,
            dtype=torch.float32     # Set the data type of the weights to float32
        )

        self.lif_out = snn.Synaptic(
            alpha=placeholder_val, 
            beta=placeholder_val,
            threshold=v_thr,
            reset_mechanism="zero", reset_delay=False,
            # init_hidden=True,   # enables the methods in snntorch.backprop to automatically clear the hidden states and detach them from the comp. graph
            spike_grad=spike_grad,
            learn_alpha=True,   # Learn the alpha parameter
            learn_beta=True,    # Learn the beta parameter
            learn_threshold=False,   # Learn the threshold parameter
        )

        # Initialize the membrane potential of each LIF neuron
        self.syn1, self.mem1, self.spk1 = None, None, None
        self.syn2, self.mem2, self.spk2 = None, None, None
        self.syn_out, self.mem_out, self.spk_out = None, None, None

    """
    Function called during the forward pass of the network
    """
    def forward(self, x: torch.Tensor) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        '''
        Forward Pass of the Network (Single Step Update)

        Parameters:
        - x: input tensor. Shape: (batch_size, num_features)

        Returns:
        - spk_vals: tuple of tensors containing the spikes of the neurons. Shape: (batch_size, num_neurons)
        - mem_vals: tuple of tensors containing the membrane potentials of the neurons. Shape: (batch_size, num_neurons)
        - syn_vals: tuple of tensors containing the currents of the neurons. Shape: (batch_size, num_neurons)
        '''
        cur_batch_size, cur_num_channels = x.shape

        # --- Lazy State Initialization
        if self.mem1 is None:
            device = x.device   # Get the device of the input tensor

            # Initialize the membrane potential of each LIF neuron
            self.syn1, self.mem1 = self.lif1.reset_mem()
            self.syn2, self.mem2 = self.lif2.reset_mem()
            self.syn_out, self.mem_out = self.lif_out.reset_mem()

            # # Define small residual for spk1
            # spk1_factor = 0.01
            # self.spk1 = torch.rand(size=(cur_batch_size, input_to_hidden[1]), dtype=torch.float32, device=device) * spk1_factor
            # self.spk2 = torch.zeros(size=(cur_batch_size, hiddenL3Dim[1]), dtype=torch.float32, device=device) * spk1_factor
            # self.spk_out = torch.zeros(size=(cur_batch_size, hidden_to_out[1]), dtype=torch.float32, device=device)

        # 
        if len(x.shape) == 1:
            # If the input is 1D, it means we have only one feature (one channel)
            # Unsqueeze the input to add the num_features dimension
            x = x.unsqueeze(1)
            
        ############# State Update #############
        # Calculate Input Current for LIF1 from the Input Layer (FC1) Input -> LIF1
        cur_fc1 = self.fc_in(x) 
    
        # Calculate Input Current from Recurrent Layer (FC2) LIF1 -> LIF1
        # cur_fc2 = self.fc2(spk1)   # Connect LIF1 to itself using FC Layer 2 (Recurrent Layer)

        # Join the input currents for LIF1 (FC1 + FC2)
        cur1 = cur_fc1 # + cur_fc2  # TODO: Not feeding Recurent Layer to LIF1 for now

        # Feed the joined input current to LIF1
        self.spk1, self.syn1, self.mem1 = self.lif1(cur1, self.syn1, self.mem1)  # Feed input to LIF1

        # Calculate Input Current for LIF2 from LIF1 (FC3) LIF1 -> LIF2
        cur2 = self.fc3(self.spk1)   # Connect LIF1 to LIF2 using FC Layer 3
        # Feed the input current to LIF2 and get the spikes, synaptic currents and membrane potentials
        self.spk2, self.syn2, self.mem2 = self.lif2(cur2, self.syn2, self.mem2)  # Feed input to LIF2

        # Calculate Input Current for LIF_OUT from LIF2 (FC4) LIF2 -> LIF_OUT
        cur_out = self.fc_out(self.spk2)
        # Feed the input current to LIF_OUT and get the spikes, synaptic currents and membrane potentials
        self.spk_out, self.syn_out, self.mem_out = self.lif_out(cur_out, self.syn_out, self.mem_out)  # Feed input to LIF_OUT

        # Return the currents, membrane potentials and spikes of the current timestep
        syn_val = (self.syn1, self.syn2, self.syn_out)
        mem_vals = (self.mem1, self.mem2, self.mem_out)
        spk_vals = (self.spk1, self.spk2, self.spk_out)

        # TODO: Check if the dimensions are correct
        return (spk_vals, mem_vals, syn_val)

# %% [markdown]
# ## Load the Trained Network

# %%
# Load the network onto CUDA if available
net = Net().to(device)
prefix="updnb4ds_100_6"
# Load the Trained Parameters from a file
net_filename = f"out/{prefix}_trained_net_loss.pth"  # trained_net_loss_penalty.pth
net.load_state_dict(torch.load(net_filename, map_location=device))

# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (fc_in): Linear(in_features=2, out_features=24, bias=False)
#   (lif1): Synaptic()
#   (fc3): Linear(in_features=24, out_features=16, bias=False)
#   (lif2): Synaptic()
#   (fc_out): Linear(in_features=16, out_features=1, bias=False)
#   (lif_out): Synaptic()
# )

# %% [markdown]
# ## Show the Network Parameters

# %%
# Display the network architecture
total_params = 0    # Accumulator for the total params in the network
# Iterate through the layers of the network
for idx, (name, param) in enumerate(net.named_parameters()):
    # print("param: ", param)
    if param.shape == torch.Size([]):
        print(f"Scalar Param ({name}) | Shape={param.shape} | Value={param} \n")
    elif len(param.shape) == 1:
        print(f"Vector Param ({name}) | Shape={param.shape} | Value={param} \n")
    else:
        print(f"Tensor Param ({name}) | Shape={param.shape}. Total={param.numel()} Preview: {param[:8, :8]}\n")

    # Add the number of parameters in the layer to the total
    total_params += param.numel()

# Print the total number of parameters in the network
print(f"Total Parameters: {total_params}")
# Out:
# Tensor Param (fc_in.weight) | Shape=torch.Size([24, 2]). Total=48 Preview: tensor([[ 0.2043, -0.1214],
#         [ 0.0436,  0.1871],
#         [ 1.4993,  0.6257],
#         [ 0.2375,  0.6981],
#         [ 0.2985,  0.1416],
#         [-1.3174, -1.8931],
#         [-4.9019, -1.5510],
#         [-2.7407, -1.1690]], grad_fn=<SliceBackward0>)
#
# Vector Param (lif1.beta) | Shape=torch.Size([24]) | Value=Parameter containing:
# tensor([0.8344, 0.0455, 0.6980, 0.5272, 0.1591, 0.5071, 0.8516, 0.8722, 0.3189,
#         0.8948, 0.7706, 0.6098, 0.2903, 0.8892, 0.3383, 0.8560, 0.5303, 0.8767,
#         0.4795, 0.9838, 0.1967, 0.9144, 0.7177, 0.6355], requires_grad=True)
#
# Vector Param (lif1.alpha) | Shape=torch.Size([24]) | Value=Parameter containing:
# tensor([0.3894, 0.0257, 0.3175, 0.5971, 0.8574, 0.6284, 0.8558, 0.8870, 0.3361,
#         0.5127, 0.7994, 0.0995, 0.2675, 0.8133, 0.2387, 0.9896, 0.5580, 0.8793,
#         0.3214, 0.9884, 0.2962, 0.9143, 0.7169, 0.5686], requires_grad=True)
#
# Tensor Param (fc3.weight) | Shape=torch.Size([16, 24]). Total=384 Preview: tensor([[-1.1689e-01,  9.7223e-01, -1.0260e-02,  7.2576e-01,  2.2429e-01,
#           6.6135e-01,  7.3596e-02, -6.7760e-01],
#         [-3.7323e-03,  4.4592e-01,  8.4536e-01, -4.2945e-01,  3.8847e-01,
#          -1.3263e-01,  5.1101e-01, -4.2648e-01],
#         [ 7.2276e-01, -3.5728e-01,  2.9701e-01, -4.3122e-02,  4.3959e-01,
#           4.5695e-01,  8.4286e-01,  7.4187e-02],
#         [ 6.0086e-01, -5.2267e-02,  9.5798e-04, -2.1532e-01, -2.3877e-01,
#           7.8331e-01, -3.2708e-01,  2.8457e-01],
#         [ 5.6857e-01, -1.3961e-01, -5.0749e-01, -2.9146e-01, -2.3364e-01,
#           4.2477e-01,  3.0973e-01,  8.1382e-02],
#         [-4.9256e-01,  8.2887e-01, -2.6903e-01,  7.1559e-01,  4.8919e-01,
#          -7.6133e-02,  4.4353e-01,  6.0765e-01],
#         [-3.6438e-01, -1.6157e-01, -9.0313e-02,  6.7516e-01, -2.5017e-01,
#          -1.2354e-02, -1.7711e-01,  5.3742e-01],
#         [ 5.8758e-01,  5.1876e-01, -4.4521e-01,  3.4893e-01,  6.7236e-01,
#           4.0676e-01, -1.1078e-01,  4.6324e-01]], grad_fn=<SliceBackward0>)
#
# Vector Param (lif2.beta) | Shape=torch.Size([16]) | Value=Parameter containing:
# tensor([0.1005, 0.6267, 0.7369, 0.6210, 0.6359, 0.4435, 0.7272, 0.2515, 0.8576,
#         0.4092, 0.9899, 0.4086, 0.9672, 0.2627, 0.4890, 0.6168],
#        requires_grad=True)
#
# Vector Param (lif2.alpha) | Shape=torch.Size([16]) | Value=Parameter containing:
# tensor([0.2623, 0.8935, 0.6147, 0.6232, 0.5083, 0.5375, 0.4817, 0.2009, 0.3919,
#         0.4189, 0.9899, 0.3591, 0.9087, 0.0842, 0.2062, 0.2271],
#        requires_grad=True)
#
# Tensor Param (fc_out.weight) | Shape=torch.Size([1, 16]). Total=16 Preview: tensor([[-0.4128, -0.4975,  0.3530,  0.0026,  0.3645,  0.3050,  0.0076,  0.0040]],
#        grad_fn=<SliceBackward0>)
#
# Scalar Param (lif_out.beta) | Shape=torch.Size([]) | Value=Parameter containing:
# tensor(0.3360, requires_grad=True)
#
# Scalar Param (lif_out.alpha) | Shape=torch.Size([]) | Value=Parameter containing:
# tensor(0.3360, requires_grad=True)
#
# Total Parameters: 530

# %% [markdown]
# ## Feed the Data in Real-Time

# %%
# Store Confusion Matrix for Predictions
TP, TN, FP, FN = 0, 0, 0, 0

# %%
"""
Tensor to store the next timestep when each output neuron may spike (after the refractory period).
When a neuron spikes, it will be set to the current timestep + refractory period.
"""
lif_out_refrac_times = torch.full(size=(hidden_to_out[1]*2,), fill_value=0.0, device=device)

print("lif_out_refrac_times: ", lif_out_refrac_times)
# Out:
# lif_out_refrac_times:  tensor([0., 0.])

# %%
curr_gt_idx = 0 # Index of the current GT event
curr_gt = None  # Stores the current GT event (GT Insertion Timing)
'''
# Active GT Time-To-Live (TTL). This is a counter that decrements every timestep until it reaches 0.
If it reaches 0, it means the Network failed to predict the HFO within the GT tolerance window.
None -> No GT Event is active
'''
active_gts = deque()  # Queue of active GT events: each item is (gt_time, remaining_ttl)
out_spikes=[]
# Disable gradient calculation for inference
with torch.no_grad():
    for step in range(total_num_steps):
        # Get the current input (UP/DN spikes)
        curr_input = input_tensor[step]

        # Unsqueeze the input to add the num_batches dimension
        curr_input = curr_input.unsqueeze(0)
        # print(f"curr_input: {curr_input}")

        ADDED_FN = False    # Tracks if a False Negative was added in this timestep

        # # Check if a GT event leaves the detection window
        # if active_gt_ttl is not None and active_gt_ttl < 0:
        #     # GT Event Expired
        #     print(f"GT Event expired at timestep {step} with GT Insertion Timing: {curr_gt}")

        #     # Add a False Negative to the Confusion Matrix
        #     FN += 1
        #     # Set the TTL to None
        #     active_gt_ttl = None
        #     # Move to the next GT event
        #     curr_gt_idx += 1
        #     # Set ADDED_FN to True
        #     ADDED_FN = True

        # Check if a GT event enters the detection window
        if curr_gt_idx < num_hfo_events :
            curr_gt = int(gt_tensor[curr_gt_idx].item())  # Get the current GT Insertion Timing
            if curr_gt == step:
                # Check if a GT event was already active
                print(f"GT Event {curr_gt_idx} Insertion Timing: {curr_gt} at timestep {step}")
                active_gts.append((curr_gt, MAX_DETECTION_OFFSET))
                # if active_gt_ttl is not None:
                #     raise ValueError("[Error] Two GT events detected inside the Detection Window!")

                # GT Event starts at this timestep
                # print(f"GT Event starts at timestep {step} with GT Insertion Timing: {curr_gt}")
                
                # Set the TTL to the Maximum Detection Offset from the GT Insertion Timing
                # active_gt_ttl = MAX_DETECTION_OFFSET
                curr_gt_idx+=1
            
        # --------   State Update   --------
        spk, mem, syn = net(curr_input)

        # Get the spikes, membrane potentials and synaptic currents of the current timestep
        spk1, spk2, spk_out = spk
        mem1, mem2, mem_out = mem
        syn1, syn2, syn_out = syn
        # print(f"spk1: {spk1.shape} | spk2: {spk2.shape} | spk_out: {spk_out.shape}")
        # print(f"mem1: {mem1.shape} | mem2: {mem2.shape} | mem_out: {mem_out.shape}")
        # print(f"syn1: {syn1.shape} | syn2: {syn2.shape} | syn_out: {syn_out.shape}")

        if ADDED_FN:
            """
            If a FN was added -> GT event was not detected -> The problem formulation does not allow
            2 HFO events to be closer together than the confidence window, so we can skip this step
            """
            continue

        """ if torch.sum(spk2) > 0:
            # TODO: Remove this print statement
            print(f"LIF2 spiked at timestep {step} with spikes: {spk2}") """
        
        # Track which GTs remain active
        new_active_gts = deque()
        for gt_time, ttl in active_gts:
            if ttl < 0:
                FN += 1
                print(f"[FN] GT event at {gt_time} expired at timestep {step}")
            else:
                new_active_gts.append((gt_time, ttl - 1))
        active_gts = new_active_gts

        if torch.sum(spk_out) > 0:
            # Convert spk_out to int for bitwise operations (Squeeze the batch dimension)
            spk_out_int = spk_out.squeeze(0).int()
            out_spikes.append(step*dt)
            # Consider the refractory period of the output neurons
            REFRAC_STATE_MASK = lif_out_refrac_times[0] > step * dt    # Check if each output neuron is in the refractory period
            # Bitwise AND between the spikes by the refractory state mask
            # Gets a mask of the neurons that spiked and are not in the refractory state
            valid_spk_out = torch.Tensor.bool(spk_out_int & (~REFRAC_STATE_MASK))
         

            # Check if any Valid Output Neuron spiked
            if torch.sum(valid_spk_out) > 0:
                # print(f"valid_spk_out: {valid_spk_out} | lif_out_refrac_times: {lif_out_refrac_times}")
                # Set the refractory period for the spiking output neurons
            
                # If an Output Neuron spiked -> Predicted an HFO
                # Let's check if the predicted HFO is within the GT tolerance window
                if active_gts:
                    # The GT event is active -> Valid Prediction
                    gt_time, _ = active_gts.popleft()
                    TP += 1
                    print(f"[TP] Spike matched GT event at timestep {step} (GT: {gt_time})")
                    lif_out_refrac_times[0] = float(step * dt + refrac_period_gt)
                else:
                    if lif_out_refrac_times[1] < step * dt:
                        # The GT event is not active -> Invalid Prediction
                        FP += 1
                        print(f"[FP] Network detected HFO at timestep {step} without an active GT event")
                        lif_out_refrac_times[1] = float(step * dt + refrac_period_fp)
            else:
                # No valid output neuron spiked -> No HFO Detected
                TN += 1     # Increment True Negatives (No HFO detected)
            
        else:
            # If the Output Neuron did not spike -> No HFO detected
            TN += 1     # Increment True Negatives (No HFO detected)


        if step % 100000 == 0:
            print(f"Processed step {step}/{total_num_steps} ({(step /total_num_steps) * 100:.2f}%)")
# Out:
# Processed step 0/8321032 (0.00%)
# [FP] Network detected HFO at timestep 368 without an active GT event
# GT Event 0 Insertion Timing: 568 at timestep 568
# [TP] Spike matched GT event at timestep 599 (GT: 568)
# [FP] Network detected HFO at timestep 801 without an active GT event
# GT Event 1 Insertion Timing: 969 at timestep 969
# [TP] Spike matched GT event at timestep 983 (GT: 969)
# [FP] Network detected HFO at timestep 1305 without an active GT event
# [FP] Network detected HFO at timestep 1529 without an active GT event
# GT Event 2 Insertion Timing: 1629 at timestep 1629
# [TP] Spike matched GT event at timestep 1643 (GT: 1629)
# [FP] Network detected HFO at timestep 1863 without an active GT event
# [FP] Network detected HFO at timestep 2066 without an active GT event
# [FP] Network detected HFO at timestep 2267 without an active GT event
# [FP] Network detected HFO at timestep 2730 without an active GT event
# [FP] Network detected HFO at timestep 3624 without an active GT event
# [FP] Network detected HFO at timestep 3829 without an active GT event
# GT Event 3 Insertion Timing: 3952 at timestep 3952
# [TP] Spike matched GT event at timestep 4003 (GT: 3952)
# [FP] Network detected HFO at timestep 4220 without an active GT event
# GT Event 4 Insertion Timing: 5006 at timestep 5006
# [FN] GT event at 5006 expired at timestep 5079
# [FP] Network detected HFO at timestep 5175 without an active GT event
# GT Event 5 Insertion Timing: 5225 at timestep 5225
# [TP] Spike matched GT event at timestep 5255 (GT: 5225)
# [FP] Network detected HFO at timestep 5514 without an active GT event
# [FP] Network detected HFO at timestep 5715 without an active GT event
# GT Event 6 Insertion Timing: 5772 at timestep 5772
# [TP] Spike matched GT event at timestep 5792 (GT: 5772)
# [FP] Network detected HFO at timestep 5997 without an active GT event
# GT Event 7 Insertion Timing: 6039 at timestep 6039
# [TP] Spike matched GT event at timestep 6088 (GT: 6039)
# [FP] Network detected HFO at timestep 6289 without an active GT event
# GT Event 8 Insertion Timing: 6479 at timestep 6479
# [TP] Spike matched GT event at timestep 6502 (GT: 6479)
# [FP] Network detected HFO at timestep 6709 without an active GT event
# GT Event 9 Insertion Timing: 6869 at timestep 6869
# [TP] Spike matched GT event at timestep 6891 (GT: 6869)
# [FP] Network detected HFO at timestep 7098 without an active GT event
# [FP] Network detected HFO at timestep 7300 without an active GT event
# [FP] Network detected HFO at timestep 7562 without an active GT event
# [FP] Network detected HFO at timestep 7933 without an active GT event
# [FP] Network detected HFO at timestep 8252 without an active GT event
# [FP] Network detected HFO at timestep 8454 without an active GT event
# [FP] Network detected HFO at timestep 8660 without an active GT event
# [FP] Network detected HFO at timestep 8934 without an active GT event
# [FP] Network detected HFO at timestep 9191 without an active GT event
# [FP] Network detected HFO at timestep 9752 without an active GT event
# [FP] Network detected HFO at timestep 9971 without an active GT event
# [FP] Network detected HFO at timestep 10691 without an active GT event
# [FP] Network detected HFO at timestep 10943 without an active GT event
# [FP] Network detected HFO at timestep 11144 without an active GT event
# [FP] Network detected HFO at timestep 11347 without an active GT event
# [FP] Network detected HFO at timestep 11637 without an active GT event
# [FP] Network detected HFO at timestep 12098 without an active GT event
# [FP] Network detected HFO at timestep 12370 without an active GT event
# [FP] Network detected HFO at timestep 12610 without an active GT event
# [FP] Network detected HFO at timestep 12815 without an active GT event
# [FP] Network detected HFO at timestep 13062 without an active GT event
# [FP] Network detected HFO at timestep 13482 without an active GT event
# [FP] Network detected HFO at timestep 13683 without an active GT event
# [FP] Network detected HFO at timestep 13949 without an active GT event
# [FP] Network detected HFO at timestep 14215 without an active GT event
# [FP] Network detected HFO at timestep 14738 without an active GT event
# [FP] Network detected HFO at timestep 14939 without an active GT event
# GT Event 10 Insertion Timing: 14958 at timestep 14958
# [TP] Spike matched GT event at timestep 14958 (GT: 14958)
# [FP] Network detected HFO at timestep 15163 without an active GT event
# GT Event 11 Insertion Timing: 15495 at timestep 15495
# [TP] Spike matched GT event at timestep 15533 (GT: 15495)
# [FP] Network detected HFO at timestep 15738 without an active GT event
# [FP] Network detected HFO at timestep 15950 without an active GT event
# [FP] Network detected HFO at timestep 16153 without an active GT event
# GT Event 12 Insertion Timing: 16177 at timestep 16177
# [TP] Spike matched GT event at timestep 16188 (GT: 16177)
# [FP] Network detected HFO at timestep 16395 without an active GT event
# [FP] Network detected HFO at timestep 16598 without an active GT event
# [FP] Network detected HFO at timestep 16865 without an active GT event
# [FP] Network detected HFO at timestep 17077 without an active GT event
# [FP] Network detected HFO at timestep 17291 without an active GT event
# [FP] Network detected HFO at timestep 17492 without an active GT event
# GT Event 13 Insertion Timing: 17645 at timestep 17645
# [TP] Spike matched GT event at timestep 17693 (GT: 17645)
# [FP] Network detected HFO at timestep 17926 without an active GT event
# GT Event 14 Insertion Timing: 18088 at timestep 18088
# [TP] Spike matched GT event at timestep 18116 (GT: 18088)
# [FP] Network detected HFO at timestep 18344 without an active GT event
# GT Event 15 Insertion Timing: 18434 at timestep 18434
# [TP] Spike matched GT event at timestep 18439 (GT: 18434)
# [FP] Network detected HFO at timestep 18641 without an active GT event
# [FP] Network detected HFO at timestep 18842 without an active GT event
# GT Event 16 Insertion Timing: 19022 at timestep 19022
# [TP] Spike matched GT event at timestep 19042 (GT: 19022)
# [FP] Network detected HFO at timestep 19243 without an active GT event
# [FP] Network detected HFO at timestep 19448 without an active GT event
# [FP] Network detected HFO at timestep 19652 without an active GT event
# [FP] Network detected HFO at timestep 19866 without an active GT event
# [FP] Network detected HFO at timestep 20067 without an active GT event
# [FP] Network detected HFO at timestep 20436 without an active GT event
# [FP] Network detected HFO at timestep 20644 without an active GT event
# [FP] Network detected HFO at timestep 21321 without an active GT event
# [FP] Network detected HFO at timestep 21525 without an active GT event
# [FP] Network detected HFO at timestep 22641 without an active GT event
# [FP] Network detected HFO at timestep 23149 without an active GT event
# [FP] Network detected HFO at timestep 23352 without an active GT event
# [FP] Network detected HFO at timestep 23553 without an active GT event
# [FP] Network detected HFO at timestep 23815 without an active GT event
# [FP] Network detected HFO at timestep 24022 without an active GT event
# [FP] Network detected HFO at timestep 24228 without an active GT event
# [FP] Network detected HFO at timestep 24438 without an active GT event
# [FP] Network detected HFO at timestep 24706 without an active GT event
# [FP] Network detected HFO at timestep 24907 without an active GT event
# [FP] Network detected HFO at timestep 25109 without an active GT event
# [FP] Network detected HFO at timestep 25333 without an active GT event
# [FP] Network detected HFO at timestep 25536 without an active GT event
# [FP] Network detected HFO at timestep 25744 without an active GT event
# [FP] Network detected HFO at timestep 25997 without an active GT event
# [FP] Network detected HFO at timestep 26208 without an active GT event
# [FP] Network detected HFO at timestep 26428 without an active GT event
# [FP] Network detected HFO at timestep 26630 without an active GT event
# [FP] Network detected HFO at timestep 26886 without an active GT event
# GT Event 17 Insertion Timing: 26891 at timestep 26891
# [TP] Spike matched GT event at timestep 26894 (GT: 26891)
# [FP] Network detected HFO at timestep 27094 without an active GT event
# [FP] Network detected HFO at timestep 27366 without an active GT event
# [FP] Network detected HFO at timestep 27568 without an active GT event
# GT Event 18 Insertion Timing: 27626 at timestep 27626
# [TP] Spike matched GT event at timestep 27662 (GT: 27626)
# [FP] Network detected HFO at timestep 27863 without an active GT event
# GT Event 19 Insertion Timing: 27887 at timestep 27887
# [TP] Spike matched GT event at timestep 27908 (GT: 27887)
# [FP] Network detected HFO at timestep 28109 without an active GT event
# [FP] Network detected HFO at timestep 28319 without an active GT event
# [FP] Network detected HFO at timestep 28542 without an active GT event
# [FP] Network detected HFO at timestep 28951 without an active GT event
# [FP] Network detected HFO at timestep 29337 without an active GT event
# [FP] Network detected HFO at timestep 29737 without an active GT event
# [FP] Network detected HFO at timestep 29966 without an active GT event
# [FP] Network detected HFO at timestep 30175 without an active GT event
# GT Event 20 Insertion Timing: 30375 at timestep 30375
# [TP] Spike matched GT event at timestep 30375 (GT: 30375)
# [FP] Network detected HFO at timestep 30604 without an active GT event
# GT Event 21 Insertion Timing: 30697 at timestep 30697
# [TP] Spike matched GT event at timestep 30715 (GT: 30697)
# [FP] Network detected HFO at timestep 30926 without an active GT event
# [FP] Network detected HFO at timestep 31129 without an active GT event
# [FP] Network detected HFO at timestep 31407 without an active GT event
# [FP] Network detected HFO at timestep 31609 without an active GT event
# [FP] Network detected HFO at timestep 31943 without an active GT event
# GT Event 22 Insertion Timing: 32162 at timestep 32162
# [TP] Spike matched GT event at timestep 32167 (GT: 32162)
# [FP] Network detected HFO at timestep 32381 without an active GT event
# [FP] Network detected HFO at timestep 32604 without an active GT event
# [FP] Network detected HFO at timestep 32808 without an active GT event
# [FP] Network detected HFO at timestep 33014 without an active GT event
# GT Event 23 Insertion Timing: 33044 at timestep 33044
# [TP] Spike matched GT event at timestep 33047 (GT: 33044)
# [FP] Network detected HFO at timestep 33254 without an active GT event
# [FP] Network detected HFO at timestep 33653 without an active GT event
# [FP] Network detected HFO at timestep 33856 without an active GT event
# [FP] Network detected HFO at timestep 34076 without an active GT event
# [FP] Network detected HFO at timestep 34405 without an active GT event
# [FP] Network detected HFO at timestep 34658 without an active GT event
# [FP] Network detected HFO at timestep 35367 without an active GT event
# [FP] Network detected HFO at timestep 35690 without an active GT event
# [FP] Network detected HFO at timestep 36104 without an active GT event
# [FP] Network detected HFO at timestep 36315 without an active GT event
# [FP] Network detected HFO at timestep 36584 without an active GT event
# [FP] Network detected HFO at timestep 36811 without an active GT event
# [FP] Network detected HFO at timestep 37042 without an active GT event
# [FP] Network detected HFO at timestep 37442 without an active GT event
# [FP] Network detected HFO at timestep 37741 without an active GT event
# [FP] Network detected HFO at timestep 37946 without an active GT event
# [FP] Network detected HFO at timestep 38173 without an active GT event
# [FP] Network detected HFO at timestep 38745 without an active GT event
# [FP] Network detected HFO at timestep 39174 without an active GT event
# [FP] Network detected HFO at timestep 39376 without an active GT event
# GT Event 24 Insertion Timing: 39752 at timestep 39752
# [TP] Spike matched GT event at timestep 39804 (GT: 39752)
# [FP] Network detected HFO at timestep 40004 without an active GT event
# [FP] Network detected HFO at timestep 40207 without an active GT event
# GT Event 25 Insertion Timing: 40388 at timestep 40388
# [TP] Spike matched GT event at timestep 40406 (GT: 40388)
# [FP] Network detected HFO at timestep 40617 without an active GT event
# [FP] Network detected HFO at timestep 40819 without an active GT event
# [FP] Network detected HFO at timestep 41032 without an active GT event
# [FP] Network detected HFO at timestep 41234 without an active GT event
# [FP] Network detected HFO at timestep 41436 without an active GT event
# [FP] Network detected HFO at timestep 41643 without an active GT event
# [FP] Network detected HFO at timestep 41848 without an active GT event
# [FP] Network detected HFO at timestep 42542 without an active GT event
# [FP] Network detected HFO at timestep 42801 without an active GT event
# GT Event 26 Insertion Timing: 42876 at timestep 42876
# [TP] Spike matched GT event at timestep 42887 (GT: 42876)
# GT Event 27 Insertion Timing: 42980 at timestep 42980
# [FN] GT event at 42980 expired at timestep 43053
# [FP] Network detected HFO at timestep 43090 without an active GT event
# [FP] Network detected HFO at timestep 43362 without an active GT event
# [FP] Network detected HFO at timestep 43570 without an active GT event
# [FP] Network detected HFO at timestep 43782 without an active GT event
# [FP] Network detected HFO at timestep 44012 without an active GT event
# [FP] Network detected HFO at timestep 44250 without an active GT event
# [FP] Network detected HFO at timestep 44472 without an active GT event
# [FP] Network detected HFO at timestep 44767 without an active GT event
# [FP] Network detected HFO at timestep 44972 without an active GT event
# [FP] Network detected HFO at timestep 45178 without an active GT event
# [FP] Network detected HFO at timestep 45390 without an active GT event
# GT Event 28 Insertion Timing: 45485 at timestep 45485
# [TP] Spike matched GT event at timestep 45508 (GT: 45485)
# [FP] Network detected HFO at timestep 45716 without an active GT event
# [FP] Network detected HFO at timestep 45921 without an active GT event
# [FP] Network detected HFO at timestep 46126 without an active GT event
# GT Event 29 Insertion Timing: 46310 at timestep 46310
# [TP] Spike matched GT event at timestep 46326 (GT: 46310)
# [FP] Network detected HFO at timestep 46526 without an active GT event
# GT Event 30 Insertion Timing: 46689 at timestep 46689
# [TP] Spike matched GT event at timestep 46691 (GT: 46689)
# [FP] Network detected HFO at timestep 46892 without an active GT event
# [FP] Network detected HFO at timestep 47118 without an active GT event
# [FP] Network detected HFO at timestep 47450 without an active GT event
# [FP] Network detected HFO at timestep 47675 without an active GT event
# GT Event 31 Insertion Timing: 47806 at timestep 47806
# [TP] Spike matched GT event at timestep 47831 (GT: 47806)
# GT Event 32 Insertion Timing: 48011 at timestep 48011
# [TP] Spike matched GT event at timestep 48034 (GT: 48011)
# [FP] Network detected HFO at timestep 48240 without an active GT event
# [FP] Network detected HFO at timestep 48441 without an active GT event
# [FP] Network detected HFO at timestep 48642 without an active GT event
# GT Event 33 Insertion Timing: 48802 at timestep 48802
# [TP] Spike matched GT event at timestep 48802 (GT: 48802)
# [FP] Network detected HFO at timestep 49020 without an active GT event
# [FP] Network detected HFO at timestep 49222 without an active GT event
# [FP] Network detected HFO at timestep 49424 without an active GT event
# [FP] Network detected HFO at timestep 49684 without an active GT event
# [FP] Network detected HFO at timestep 49910 without an active GT event
# [FP] Network detected HFO at timestep 50532 without an active GT event
# [FP] Network detected HFO at timestep 51060 without an active GT event
# [FP] Network detected HFO at timestep 51556 without an active GT event
# [FP] Network detected HFO at timestep 51764 without an active GT event
# [FP] Network detected HFO at timestep 51967 without an active GT event
# GT Event 34 Insertion Timing: 52116 at timestep 52116
# [TP] Spike matched GT event at timestep 52116 (GT: 52116)
# GT Event 35 Insertion Timing: 52261 at timestep 52261
# [TP] Spike matched GT event at timestep 52317 (GT: 52261)
# [FP] Network detected HFO at timestep 52520 without an active GT event
# [FP] Network detected HFO at timestep 52722 without an active GT event
# [FP] Network detected HFO at timestep 52923 without an active GT event
# [FP] Network detected HFO at timestep 53131 without an active GT event
# [FP] Network detected HFO at timestep 54344 without an active GT event
# [FP] Network detected HFO at timestep 54742 without an active GT event
# GT Event 36 Insertion Timing: 55114 at timestep 55114
# [TP] Spike matched GT event at timestep 55119 (GT: 55114)
# [FP] Network detected HFO at timestep 55327 without an active GT event
# [FP] Network detected HFO at timestep 55531 without an active GT event
# [FP] Network detected HFO at timestep 55736 without an active GT event
# GT Event 37 Insertion Timing: 55823 at timestep 55823
# [TP] Spike matched GT event at timestep 55853 (GT: 55823)
# [FP] Network detected HFO at timestep 56053 without an active GT event
# [FP] Network detected HFO at timestep 56684 without an active GT event
# [FP] Network detected HFO at timestep 56892 without an active GT event
# [FP] Network detected HFO at timestep 57115 without an active GT event
# GT Event 38 Insertion Timing: 57268 at timestep 57268
# [TP] Spike matched GT event at timestep 57269 (GT: 57268)
# [FP] Network detected HFO at timestep 57470 without an active GT event
# [FP] Network detected HFO at timestep 57686 without an active GT event
# GT Event 39 Insertion Timing: 57820 at timestep 57820
# [TP] Spike matched GT event at timestep 57872 (GT: 57820)
# [FP] Network detected HFO at timestep 58085 without an active GT event
# GT Event 40 Insertion Timing: 58098 at timestep 58098
# [TP] Spike matched GT event at timestep 58104 (GT: 58098)
# [FP] Network detected HFO at timestep 58327 without an active GT event
# GT Event 41 Insertion Timing: 58489 at timestep 58489
# [TP] Spike matched GT event at timestep 58496 (GT: 58489)
# GT Event 42 Insertion Timing: 58624 at timestep 58624
# [FN] GT event at 58624 expired at timestep 58697
# [FP] Network detected HFO at timestep 58697 without an active GT event
# GT Event 43 Insertion Timing: 58844 at timestep 58844
# [TP] Spike matched GT event at timestep 58886 (GT: 58844)
# [FP] Network detected HFO at timestep 59087 without an active GT event
# [FP] Network detected HFO at timestep 59446 without an active GT event
# [FP] Network detected HFO at timestep 59647 without an active GT event
# [FP] Network detected HFO at timestep 59851 without an active GT event
# [FP] Network detected HFO at timestep 60078 without an active GT event
# [FP] Network detected HFO at timestep 60290 without an active GT event
# [FP] Network detected HFO at timestep 60535 without an active GT event
# [FP] Network detected HFO at timestep 60739 without an active GT event
# [FP] Network detected HFO at timestep 61117 without an active GT event
# [FP] Network detected HFO at timestep 61327 without an active GT event
# [FP] Network detected HFO at timestep 61849 without an active GT event
# [FP] Network detected HFO at timestep 62055 without an active GT event
# [FP] Network detected HFO at timestep 62301 without an active GT event
# [FP] Network detected HFO at timestep 62503 without an active GT event
# [FP] Network detected HFO at timestep 62758 without an active GT event
# GT Event 44 Insertion Timing: 62952 at timestep 62952
# [TP] Spike matched GT event at timestep 62952 (GT: 62952)
# [FP] Network detected HFO at timestep 63154 without an active GT event
# GT Event 45 Insertion Timing: 63243 at timestep 63243
# [TP] Spike matched GT event at timestep 63264 (GT: 63243)
# [FP] Network detected HFO at timestep 63464 without an active GT event
# [FP] Network detected HFO at timestep 63683 without an active GT event
# [FP] Network detected HFO at timestep 63885 without an active GT event
# GT Event 46 Insertion Timing: 64006 at timestep 64006
# [TP] Spike matched GT event at timestep 64027 (GT: 64006)
# GT Event 47 Insertion Timing: 64212 at timestep 64212
# [TP] Spike matched GT event at timestep 64240 (GT: 64212)
# [FP] Network detected HFO at timestep 64454 without an active GT event
# [FP] Network detected HFO at timestep 64657 without an active GT event
# [FP] Network detected HFO at timestep 64861 without an active GT event
# [FP] Network detected HFO at timestep 65074 without an active GT event
# [FP] Network detected HFO at timestep 65283 without an active GT event
# [FP] Network detected HFO at timestep 65486 without an active GT event
# [FP] Network detected HFO at timestep 65689 without an active GT event
# [FP] Network detected HFO at timestep 65916 without an active GT event
# [FP] Network detected HFO at timestep 66402 without an active GT event
# [FP] Network detected HFO at timestep 66780 without an active GT event
# [FP] Network detected HFO at timestep 67110 without an active GT event
# [FP] Network detected HFO at timestep 68028 without an active GT event
# [FP] Network detected HFO at timestep 68239 without an active GT event
# [FP] Network detected HFO at timestep 68440 without an active GT event
# [FP] Network detected HFO at timestep 68816 without an active GT event
# [FP] Network detected HFO at timestep 69019 without an active GT event
# [FP] Network detected HFO at timestep 69258 without an active GT event
# [FP] Network detected HFO at timestep 69494 without an active GT event
# [FP] Network detected HFO at timestep 69717 without an active GT event
# [FP] Network detected HFO at timestep 69929 without an active GT event
# [FP] Network detected HFO at timestep 70424 without an active GT event
# [FP] Network detected HFO at timestep 70827 without an active GT event
# [FP] Network detected HFO at timestep 71031 without an active GT event
# [FP] Network detected HFO at timestep 71731 without an active GT event
# [FP] Network detected HFO at timestep 71971 without an active GT event
# [FP] Network detected HFO at timestep 72260 without an active GT event
# [FP] Network detected HFO at timestep 72592 without an active GT event
# [FP] Network detected HFO at timestep 72894 without an active GT event
# GT Event 48 Insertion Timing: 72965 at timestep 72965
# [TP] Spike matched GT event at timestep 72992 (GT: 72965)
# [FP] Network detected HFO at timestep 73267 without an active GT event
# [FP] Network detected HFO at timestep 73470 without an active GT event
# [FP] Network detected HFO at timestep 73870 without an active GT event
# [FP] Network detected HFO at timestep 74072 without an active GT event
# [FP] Network detected HFO at timestep 74393 without an active GT event
# [FP] Network detected HFO at timestep 74847 without an active GT event
# [FP] Network detected HFO at timestep 75081 without an active GT event
# [FP] Network detected HFO at timestep 75284 without an active GT event
# [FP] Network detected HFO at timestep 75485 without an active GT event
# [FP] Network detected HFO at timestep 75730 without an active GT event
# [FP] Network detected HFO at timestep 75935 without an active GT event
# [FP] Network detected HFO at timestep 76138 without an active GT event
# [FP] Network detected HFO at timestep 77294 without an active GT event
# GT Event 49 Insertion Timing: 78570 at timestep 78570
# [TP] Spike matched GT event at timestep 78574 (GT: 78570)
# [FP] Network detected HFO at timestep 78776 without an active GT event
# [FP] Network detected HFO at timestep 78979 without an active GT event
# [FP] Network detected HFO at timestep 79390 without an active GT event
# [FP] Network detected HFO at timestep 79670 without an active GT event
# [FP] Network detected HFO at timestep 79872 without an active GT event
# GT Event 50 Insertion Timing: 80076 at timestep 80076
# [TP] Spike matched GT event at timestep 80095 (GT: 80076)
# [FP] Network detected HFO at timestep 80371 without an active GT event
# [FP] Network detected HFO at timestep 80662 without an active GT event
# [FP] Network detected HFO at timestep 81188 without an active GT event
# GT Event 51 Insertion Timing: 82355 at timestep 82355
# [TP] Spike matched GT event at timestep 82380 (GT: 82355)
# [FP] Network detected HFO at timestep 82589 without an active GT event
# [FP] Network detected HFO at timestep 82791 without an active GT event
# [FP] Network detected HFO at timestep 82993 without an active GT event
# [FP] Network detected HFO at timestep 83450 without an active GT event
# [FP] Network detected HFO at timestep 83700 without an active GT event
# [FP] Network detected HFO at timestep 83912 without an active GT event
# [FP] Network detected HFO at timestep 84688 without an active GT event
# [FP] Network detected HFO at timestep 85038 without an active GT event
# [FP] Network detected HFO at timestep 85240 without an active GT event
# [FP] Network detected HFO at timestep 85724 without an active GT event
# [FP] Network detected HFO at timestep 86255 without an active GT event
# [FP] Network detected HFO at timestep 86973 without an active GT event
# [FP] Network detected HFO at timestep 87184 without an active GT event
# [FP] Network detected HFO at timestep 87520 without an active GT event
# [FP] Network detected HFO at timestep 88383 without an active GT event
# [FP] Network detected HFO at timestep 88722 without an active GT event
# GT Event 52 Insertion Timing: 88752 at timestep 88752
# [TP] Spike matched GT event at timestep 88788 (GT: 88752)
# [FP] Network detected HFO at timestep 89001 without an active GT event
# [FP] Network detected HFO at timestep 89373 without an active GT event
# [FP] Network detected HFO at timestep 89576 without an active GT event
# [FP] Network detected HFO at timestep 89789 without an active GT event
# [FP] Network detected HFO at timestep 89996 without an active GT event
# [FP] Network detected HFO at timestep 90214 without an active GT event
# [FP] Network detected HFO at timestep 90422 without an active GT event
# [FP] Network detected HFO at timestep 90625 without an active GT event
# [FP] Network detected HFO at timestep 90826 without an active GT event
# [FP] Network detected HFO at timestep 91027 without an active GT event
# [FP] Network detected HFO at timestep 91233 without an active GT event
# [FP] Network detected HFO at timestep 91596 without an active GT event
# [FP] Network detected HFO at timestep 91806 without an active GT event
# [FP] Network detected HFO at timestep 92088 without an active GT event
# [FP] Network detected HFO at timestep 92289 without an active GT event
# [FP] Network detected HFO at timestep 92492 without an active GT event
# [FP] Network detected HFO at timestep 92763 without an active GT event
# [FP] Network detected HFO at timestep 92969 without an active GT event
# [FP] Network detected HFO at timestep 93171 without an active GT event
# [FP] Network detected HFO at timestep 93373 without an active GT event
# [FP] Network detected HFO at timestep 93575 without an active GT event
# [FP] Network detected HFO at timestep 93777 without an active GT event
# [FP] Network detected HFO at timestep 93980 without an active GT event
# [FP] Network detected HFO at timestep 94183 without an active GT event
# [FP] Network detected HFO at timestep 94614 without an active GT event
# [FP] Network detected HFO at timestep 94855 without an active GT event
# [FP] Network detected HFO at timestep 95243 without an active GT event
# [FP] Network detected HFO at timestep 95506 without an active GT event
# [FP] Network detected HFO at timestep 95726 without an active GT event
# [FP] Network detected HFO at timestep 96360 without an active GT event
# [FP] Network detected HFO at timestep 96566 without an active GT event
# [FP] Network detected HFO at timestep 96803 without an active GT event
# [FP] Network detected HFO at timestep 97004 without an active GT event
# GT Event 53 Insertion Timing: 97053 at timestep 97053
# [TP] Spike matched GT event at timestep 97088 (GT: 97053)
# [FP] Network detected HFO at timestep 97303 without an active GT event
# [FP] Network detected HFO at timestep 97601 without an active GT event
# GT Event 54 Insertion Timing: 97709 at timestep 97709
# [TP] Spike matched GT event at timestep 97742 (GT: 97709)
# GT Event 55 Insertion Timing: 97919 at timestep 97919
# [TP] Spike matched GT event at timestep 97957 (GT: 97919)
# [FP] Network detected HFO at timestep 98165 without an active GT event
# GT Event 56 Insertion Timing: 98166 at timestep 98166
# [TP] Spike matched GT event at timestep 98193 (GT: 98166)
# GT Event 57 Insertion Timing: 98235 at timestep 98235
# [FN] GT event at 98235 expired at timestep 98308
# [FP] Network detected HFO at timestep 98408 without an active GT event
# [FP] Network detected HFO at timestep 98693 without an active GT event
# [FP] Network detected HFO at timestep 99227 without an active GT event
# [FP] Network detected HFO at timestep 99431 without an active GT event
# [FP] Network detected HFO at timestep 99814 without an active GT event
# Processed step 100000/8321032 (1.20%)
# [FP] Network detected HFO at timestep 100020 without an active GT event
# [FP] Network detected HFO at timestep 100254 without an active GT event
# [FP] Network detected HFO at timestep 100601 without an active GT event
# [FP] Network detected HFO at timestep 100804 without an active GT event
# [FP] Network detected HFO at timestep 101012 without an active GT event
# [FP] Network detected HFO at timestep 101237 without an active GT event
# GT Event 58 Insertion Timing: 101330 at timestep 101330
# [TP] Spike matched GT event at timestep 101337 (GT: 101330)
# GT Event 59 Insertion Timing: 101602 at timestep 101602
# [TP] Spike matched GT event at timestep 101645 (GT: 101602)
# [FP] Network detected HFO at timestep 101845 without an active GT event
# [FP] Network detected HFO at timestep 102053 without an active GT event
# [FP] Network detected HFO at timestep 102270 without an active GT event
# GT Event 60 Insertion Timing: 102475 at timestep 102475
# [TP] Spike matched GT event at timestep 102490 (GT: 102475)
# GT Event 61 Insertion Timing: 102634 at timestep 102634
# [TP] Spike matched GT event at timestep 102700 (GT: 102634)
# [FP] Network detected HFO at timestep 102905 without an active GT event
# [FP] Network detected HFO at timestep 103106 without an active GT event
# GT Event 62 Insertion Timing: 103306 at timestep 103306
# [TP] Spike matched GT event at timestep 103340 (GT: 103306)
# [FP] Network detected HFO at timestep 103579 without an active GT event
# GT Event 63 Insertion Timing: 103593 at timestep 103593
# [TP] Spike matched GT event at timestep 103619 (GT: 103593)
# [FP] Network detected HFO at timestep 103821 without an active GT event
# [FP] Network detected HFO at timestep 104030 without an active GT event
# [FP] Network detected HFO at timestep 104232 without an active GT event
# [FP] Network detected HFO at timestep 104433 without an active GT event
# [FP] Network detected HFO at timestep 104638 without an active GT event
# GT Event 64 Insertion Timing: 104657 at timestep 104657
# [TP] Spike matched GT event at timestep 104674 (GT: 104657)
# [FP] Network detected HFO at timestep 104889 without an active GT event
# GT Event 65 Insertion Timing: 104969 at timestep 104969
# [TP] Spike matched GT event at timestep 104979 (GT: 104969)
# [FP] Network detected HFO at timestep 105196 without an active GT event
# GT Event 66 Insertion Timing: 105281 at timestep 105281
# [TP] Spike matched GT event at timestep 105285 (GT: 105281)
# [FP] Network detected HFO at timestep 105500 without an active GT event
# [FP] Network detected HFO at timestep 105707 without an active GT event
# GT Event 67 Insertion Timing: 105708 at timestep 105708
# [TP] Spike matched GT event at timestep 105709 (GT: 105708)
# [FP] Network detected HFO at timestep 105911 without an active GT event
# [FP] Network detected HFO at timestep 106183 without an active GT event
# [FP] Network detected HFO at timestep 106394 without an active GT event
# [FP] Network detected HFO at timestep 106814 without an active GT event
# [FP] Network detected HFO at timestep 107016 without an active GT event
# GT Event 68 Insertion Timing: 107033 at timestep 107033
# [TP] Spike matched GT event at timestep 107047 (GT: 107033)
# [FP] Network detected HFO at timestep 107297 without an active GT event
# GT Event 69 Insertion Timing: 107387 at timestep 107387
# [TP] Spike matched GT event at timestep 107393 (GT: 107387)
# [FP] Network detected HFO at timestep 107596 without an active GT event
# GT Event 70 Insertion Timing: 107683 at timestep 107683
# [TP] Spike matched GT event at timestep 107693 (GT: 107683)
# [FP] Network detected HFO at timestep 107894 without an active GT event
# GT Event 71 Insertion Timing: 108023 at timestep 108023
# [TP] Spike matched GT event at timestep 108053 (GT: 108023)
# [FP] Network detected HFO at timestep 108253 without an active GT event
# GT Event 72 Insertion Timing: 108319 at timestep 108319
# [TP] Spike matched GT event at timestep 108331 (GT: 108319)
# [FP] Network detected HFO at timestep 108534 without an active GT event
# [FP] Network detected HFO at timestep 108755 without an active GT event
# [FP] Network detected HFO at timestep 109542 without an active GT event
# [FP] Network detected HFO at timestep 110293 without an active GT event
# [FP] Network detected HFO at timestep 110829 without an active GT event
# [FP] Network detected HFO at timestep 111037 without an active GT event
# [FP] Network detected HFO at timestep 111249 without an active GT event
# [FP] Network detected HFO at timestep 111601 without an active GT event
# GT Event 73 Insertion Timing: 111748 at timestep 111748
# [TP] Spike matched GT event at timestep 111750 (GT: 111748)
# GT Event 74 Insertion Timing: 112055 at timestep 112055
# [TP] Spike matched GT event at timestep 112086 (GT: 112055)
# [FP] Network detected HFO at timestep 112296 without an active GT event
# [FP] Network detected HFO at timestep 112498 without an active GT event
# [FP] Network detected HFO at timestep 113355 without an active GT event
# [FP] Network detected HFO at timestep 113693 without an active GT event
# [FP] Network detected HFO at timestep 113975 without an active GT event
# [FP] Network detected HFO at timestep 114211 without an active GT event
# [FP] Network detected HFO at timestep 114412 without an active GT event
# [FP] Network detected HFO at timestep 114619 without an active GT event
# [FP] Network detected HFO at timestep 115054 without an active GT event
# [FP] Network detected HFO at timestep 115275 without an active GT event
# [FP] Network detected HFO at timestep 115532 without an active GT event
# [FP] Network detected HFO at timestep 115733 without an active GT event
# GT Event 75 Insertion Timing: 115845 at timestep 115845
# [TP] Spike matched GT event at timestep 115847 (GT: 115845)
# [FP] Network detected HFO at timestep 116058 without an active GT event
# GT Event 76 Insertion Timing: 116109 at timestep 116109
# [TP] Spike matched GT event at timestep 116110 (GT: 116109)
# [FP] Network detected HFO at timestep 116326 without an active GT event
# [FP] Network detected HFO at timestep 116584 without an active GT event
# [FP] Network detected HFO at timestep 116801 without an active GT event
# GT Event 77 Insertion Timing: 116811 at timestep 116811
# [TP] Spike matched GT event at timestep 116829 (GT: 116811)
# GT Event 78 Insertion Timing: 116927 at timestep 116927
# [FN] GT event at 116927 expired at timestep 117000
# GT Event 79 Insertion Timing: 117030 at timestep 117030
# [TP] Spike matched GT event at timestep 117039 (GT: 117030)
# GT Event 80 Insertion Timing: 117152 at timestep 117152
# [FN] GT event at 117152 expired at timestep 117225
# [FP] Network detected HFO at timestep 117244 without an active GT event
# GT Event 81 Insertion Timing: 117581 at timestep 117581
# [TP] Spike matched GT event at timestep 117589 (GT: 117581)
# [FP] Network detected HFO at timestep 117790 without an active GT event
# [FP] Network detected HFO at timestep 118016 without an active GT event
# [FP] Network detected HFO at timestep 118253 without an active GT event
# [FP] Network detected HFO at timestep 118458 without an active GT event
# GT Event 82 Insertion Timing: 118736 at timestep 118736
# [TP] Spike matched GT event at timestep 118759 (GT: 118736)
# [FP] Network detected HFO at timestep 118966 without an active GT event
# GT Event 83 Insertion Timing: 119150 at timestep 119150
# [TP] Spike matched GT event at timestep 119150 (GT: 119150)
# GT Event 84 Insertion Timing: 119276 at timestep 119276
# [FN] GT event at 119276 expired at timestep 119349
# [FP] Network detected HFO at timestep 119350 without an active GT event
# GT Event 85 Insertion Timing: 119563 at timestep 119563
# [TP] Spike matched GT event at timestep 119610 (GT: 119563)
# GT Event 86 Insertion Timing: 119710 at timestep 119710
# [FN] GT event at 119710 expired at timestep 119783
# [FP] Network detected HFO at timestep 119810 without an active GT event
# [FP] Network detected HFO at timestep 120015 without an active GT event
# [FP] Network detected HFO at timestep 120217 without an active GT event
# [FP] Network detected HFO at timestep 120441 without an active GT event
# [FP] Network detected HFO at timestep 120653 without an active GT event
# GT Event 87 Insertion Timing: 120921 at timestep 120921
# [TP] Spike matched GT event at timestep 120935 (GT: 120921)
# GT Event 88 Insertion Timing: 121122 at timestep 121122
# [TP] Spike matched GT event at timestep 121140 (GT: 121122)
# [FP] Network detected HFO at timestep 121365 without an active GT event
# [FP] Network detected HFO at timestep 121578 without an active GT event
# GT Event 89 Insertion Timing: 121653 at timestep 121653
# [TP] Spike matched GT event at timestep 121654 (GT: 121653)
# [FP] Network detected HFO at timestep 121854 without an active GT event
# [FP] Network detected HFO at timestep 122069 without an active GT event
# GT Event 90 Insertion Timing: 122082 at timestep 122082
# [TP] Spike matched GT event at timestep 122104 (GT: 122082)
# [FP] Network detected HFO at timestep 122305 without an active GT event
# [FP] Network detected HFO at timestep 122562 without an active GT event
# [FP] Network detected HFO at timestep 123581 without an active GT event
# [FP] Network detected HFO at timestep 124841 without an active GT event
# [FP] Network detected HFO at timestep 125465 without an active GT event
# [FP] Network detected HFO at timestep 125681 without an active GT event
# [FP] Network detected HFO at timestep 126397 without an active GT event
# [FP] Network detected HFO at timestep 126640 without an active GT event
# [FP] Network detected HFO at timestep 126861 without an active GT event
# [FP] Network detected HFO at timestep 127063 without an active GT event
# [FP] Network detected HFO at timestep 127305 without an active GT event
# GT Event 91 Insertion Timing: 127390 at timestep 127390
# [TP] Spike matched GT event at timestep 127390 (GT: 127390)
# [FP] Network detected HFO at timestep 127600 without an active GT event
# GT Event 92 Insertion Timing: 127661 at timestep 127661
# [TP] Spike matched GT event at timestep 127662 (GT: 127661)
# GT Event 93 Insertion Timing: 127754 at timestep 127754
# [FN] GT event at 127754 expired at timestep 127827
# GT Event 94 Insertion Timing: 127862 at timestep 127862
# [TP] Spike matched GT event at timestep 127884 (GT: 127862)
# [FP] Network detected HFO at timestep 128113 without an active GT event
# [FP] Network detected HFO at timestep 128318 without an active GT event
# [FP] Network detected HFO at timestep 128533 without an active GT event
# [FP] Network detected HFO at timestep 128789 without an active GT event
# [FP] Network detected HFO at timestep 129014 without an active GT event
# [FP] Network detected HFO at timestep 129536 without an active GT event
# [FP] Network detected HFO at timestep 130230 without an active GT event
# [FP] Network detected HFO at timestep 130693 without an active GT event
# [FP] Network detected HFO at timestep 130911 without an active GT event
# [FP] Network detected HFO at timestep 131301 without an active GT event
# [FP] Network detected HFO at timestep 131528 without an active GT event
# [FP] Network detected HFO at timestep 131730 without an active GT event
# [FP] Network detected HFO at timestep 132898 without an active GT event
# [FP] Network detected HFO at timestep 133100 without an active GT event
# [FP] Network detected HFO at timestep 133308 without an active GT event
# [FP] Network detected HFO at timestep 133641 without an active GT event
# [FP] Network detected HFO at timestep 133851 without an active GT event
# [FP] Network detected HFO at timestep 134061 without an active GT event
# [FP] Network detected HFO at timestep 134417 without an active GT event
# [FP] Network detected HFO at timestep 134622 without an active GT event
# [FP] Network detected HFO at timestep 134826 without an active GT event
# GT Event 95 Insertion Timing: 134924 at timestep 134924
# [TP] Spike matched GT event at timestep 134935 (GT: 134924)
# [FP] Network detected HFO at timestep 135135 without an active GT event
# [FP] Network detected HFO at timestep 135373 without an active GT event
# GT Event 96 Insertion Timing: 135472 at timestep 135472
# [TP] Spike matched GT event at timestep 135482 (GT: 135472)
# GT Event 97 Insertion Timing: 135649 at timestep 135649
# [TP] Spike matched GT event at timestep 135682 (GT: 135649)
# GT Event 98 Insertion Timing: 135768 at timestep 135768
# [FN] GT event at 135768 expired at timestep 135841
# [FP] Network detected HFO at timestep 135882 without an active GT event
# [FP] Network detected HFO at timestep 136607 without an active GT event
# [FP] Network detected HFO at timestep 138492 without an active GT event
# [FP] Network detected HFO at timestep 138746 without an active GT event
# [FP] Network detected HFO at timestep 138990 without an active GT event
# [FP] Network detected HFO at timestep 139191 without an active GT event
# [FP] Network detected HFO at timestep 140171 without an active GT event
# [FP] Network detected HFO at timestep 140402 without an active GT event
# [FP] Network detected HFO at timestep 140607 without an active GT event
# [FP] Network detected HFO at timestep 140809 without an active GT event
# [FP] Network detected HFO at timestep 141120 without an active GT event
# [FP] Network detected HFO at timestep 141340 without an active GT event
# [FP] Network detected HFO at timestep 141706 without an active GT event
# [FP] Network detected HFO at timestep 141976 without an active GT event
# [FP] Network detected HFO at timestep 142725 without an active GT event
# [FP] Network detected HFO at timestep 142939 without an active GT event
# GT Event 99 Insertion Timing: 143574 at timestep 143574
# [TP] Spike matched GT event at timestep 143637 (GT: 143574)
# [FP] Network detected HFO at timestep 143838 without an active GT event
# [FP] Network detected HFO at timestep 144286 without an active GT event
# [FP] Network detected HFO at timestep 144497 without an active GT event
# [FP] Network detected HFO at timestep 144704 without an active GT event
# [FP] Network detected HFO at timestep 144905 without an active GT event
# [FP] Network detected HFO at timestep 145107 without an active GT event
# [FP] Network detected HFO at timestep 145313 without an active GT event
# [FP] Network detected HFO at timestep 145514 without an active GT event
# [FP] Network detected HFO at timestep 145801 without an active GT event
# [FP] Network detected HFO at timestep 146416 without an active GT event
# [FP] Network detected HFO at timestep 146754 without an active GT event
# [FP] Network detected HFO at timestep 147273 without an active GT event
# [FP] Network detected HFO at timestep 147504 without an active GT event
# [FP] Network detected HFO at timestep 147745 without an active GT event
# [FP] Network detected HFO at timestep 148055 without an active GT event
# [FP] Network detected HFO at timestep 149370 without an active GT event
# [FP] Network detected HFO at timestep 149597 without an active GT event
# [FP] Network detected HFO at timestep 149854 without an active GT event
# [FP] Network detected HFO at timestep 150085 without an active GT event
# [FP] Network detected HFO at timestep 150324 without an active GT event
# [FP] Network detected HFO at timestep 150533 without an active GT event
# [FP] Network detected HFO at timestep 150734 without an active GT event
# [FP] Network detected HFO at timestep 151939 without an active GT event
# [FP] Network detected HFO at timestep 152526 without an active GT event
# [FP] Network detected HFO at timestep 153545 without an active GT event
# [FP] Network detected HFO at timestep 154006 without an active GT event
# [FP] Network detected HFO at timestep 154220 without an active GT event
# [FP] Network detected HFO at timestep 155303 without an active GT event
# [FP] Network detected HFO at timestep 155562 without an active GT event
# [FP] Network detected HFO at timestep 155828 without an active GT event
# [FP] Network detected HFO at timestep 156227 without an active GT event
# [FP] Network detected HFO at timestep 156678 without an active GT event
# [FP] Network detected HFO at timestep 156880 without an active GT event
# [FP] Network detected HFO at timestep 157093 without an active GT event
# [FP] Network detected HFO at timestep 157331 without an active GT event
# [FP] Network detected HFO at timestep 157534 without an active GT event
# GT Event 100 Insertion Timing: 157609 at timestep 157609
# [TP] Spike matched GT event at timestep 157619 (GT: 157609)
# GT Event 101 Insertion Timing: 157712 at timestep 157712
# [FN] GT event at 157712 expired at timestep 157785
# [FP] Network detected HFO at timestep 157819 without an active GT event
# [FP] Network detected HFO at timestep 158030 without an active GT event
# [FP] Network detected HFO at timestep 158232 without an active GT event
# GT Event 102 Insertion Timing: 158355 at timestep 158355
# [TP] Spike matched GT event at timestep 158383 (GT: 158355)
# GT Event 103 Insertion Timing: 158578 at timestep 158578
# [TP] Spike matched GT event at timestep 158588 (GT: 158578)
# GT Event 104 Insertion Timing: 158724 at timestep 158724
# [TP] Spike matched GT event at timestep 158794 (GT: 158724)
# GT Event 105 Insertion Timing: 158820 at timestep 158820
# [FN] GT event at 158820 expired at timestep 158893
# [FP] Network detected HFO at timestep 159017 without an active GT event
# [FP] Network detected HFO at timestep 159220 without an active GT event
# [FP] Network detected HFO at timestep 159470 without an active GT event
# [FP] Network detected HFO at timestep 159698 without an active GT event
# [FP] Network detected HFO at timestep 160057 without an active GT event
# [FP] Network detected HFO at timestep 160667 without an active GT event
# [FP] Network detected HFO at timestep 160886 without an active GT event
# [FP] Network detected HFO at timestep 161273 without an active GT event
# [FP] Network detected HFO at timestep 161475 without an active GT event
# [FP] Network detected HFO at timestep 161678 without an active GT event
# [FP] Network detected HFO at timestep 161880 without an active GT event
# [FP] Network detected HFO at timestep 162112 without an active GT event
# [FP] Network detected HFO at timestep 162348 without an active GT event
# [FP] Network detected HFO at timestep 162553 without an active GT event
# [FP] Network detected HFO at timestep 162758 without an active GT event
# [FP] Network detected HFO at timestep 162978 without an active GT event
# GT Event 106 Insertion Timing: 163066 at timestep 163066
# [TP] Spike matched GT event at timestep 163066 (GT: 163066)
# [FP] Network detected HFO at timestep 163271 without an active GT event
# GT Event 107 Insertion Timing: 163343 at timestep 163343
# [TP] Spike matched GT event at timestep 163344 (GT: 163343)
# [FP] Network detected HFO at timestep 163549 without an active GT event
# [FP] Network detected HFO at timestep 163776 without an active GT event
# GT Event 108 Insertion Timing: 163900 at timestep 163900
# [TP] Spike matched GT event at timestep 163914 (GT: 163900)
# [FP] Network detected HFO at timestep 164114 without an active GT event
# GT Event 109 Insertion Timing: 164264 at timestep 164264
# [TP] Spike matched GT event at timestep 164282 (GT: 164264)
# [FP] Network detected HFO at timestep 164486 without an active GT event
# [FP] Network detected HFO at timestep 164688 without an active GT event
# [FP] Network detected HFO at timestep 165243 without an active GT event
# [FP] Network detected HFO at timestep 165859 without an active GT event
# ...
# [TP] Spike matched GT event at timestep 8254417 (GT: 8254361)
# [FP] Network detected HFO at timestep 8254637 without an active GT event
# [FP] Network detected HFO at timestep 8254846 without an active GT event
# [FP] Network detected HFO at timestep 8255082 without an active GT event
# [FP] Network detected HFO at timestep 8255627 without an active GT event
# [FP] Network detected HFO at timestep 8257620 without an active GT event
# GT Event 3590 Insertion Timing: 8258899 at timestep 8258899
# [FN] GT event at 8258899 expired at timestep 8258972
# [FP] Network detected HFO at timestep 8259004 without an active GT event
# GT Event 3591 Insertion Timing: 8259068 at timestep 8259068
# [TP] Spike matched GT event at timestep 8259115 (GT: 8259068)
# GT Event 3592 Insertion Timing: 8259680 at timestep 8259680
# [TP] Spike matched GT event at timestep 8259713 (GT: 8259680)
# GT Event 3593 Insertion Timing: 8259857 at timestep 8259857
# [FN] GT event at 8259857 expired at timestep 8259930
# GT Event 3594 Insertion Timing: 8260248 at timestep 8260248
# [FN] GT event at 8260248 expired at timestep 8260321
# [FP] Network detected HFO at timestep 8260327 without an active GT event
# GT Event 3595 Insertion Timing: 8260595 at timestep 8260595
# [TP] Spike matched GT event at timestep 8260663 (GT: 8260595)
# GT Event 3596 Insertion Timing: 8262541 at timestep 8262541
# [TP] Spike matched GT event at timestep 8262573 (GT: 8262541)
# GT Event 3597 Insertion Timing: 8262689 at timestep 8262689
# [FN] GT event at 8262689 expired at timestep 8262762
# [FP] Network detected HFO at timestep 8263241 without an active GT event
# [FP] Network detected HFO at timestep 8264821 without an active GT event
# [FP] Network detected HFO at timestep 8265252 without an active GT event
# [FP] Network detected HFO at timestep 8266712 without an active GT event
# [FP] Network detected HFO at timestep 8267930 without an active GT event
# [FP] Network detected HFO at timestep 8268304 without an active GT event
# GT Event 3598 Insertion Timing: 8270552 at timestep 8270552
# [TP] Spike matched GT event at timestep 8270599 (GT: 8270552)
# [FP] Network detected HFO at timestep 8271061 without an active GT event
# GT Event 3599 Insertion Timing: 8271809 at timestep 8271809
# [FN] GT event at 8271809 expired at timestep 8271882
# GT Event 3600 Insertion Timing: 8271927 at timestep 8271927
# [TP] Spike matched GT event at timestep 8271987 (GT: 8271927)
# GT Event 3601 Insertion Timing: 8272081 at timestep 8272081
# [FN] GT event at 8272081 expired at timestep 8272154
# GT Event 3602 Insertion Timing: 8272251 at timestep 8272251
# [FN] GT event at 8272251 expired at timestep 8272324
# [FP] Network detected HFO at timestep 8272361 without an active GT event
# GT Event 3603 Insertion Timing: 8272767 at timestep 8272767
# GT Event 3604 Insertion Timing: 8272829 at timestep 8272829
# [FN] GT event at 8272767 expired at timestep 8272840
# [TP] Spike matched GT event at timestep 8272876 (GT: 8272829)
# [FP] Network detected HFO at timestep 8273335 without an active GT event
# [FP] Network detected HFO at timestep 8273581 without an active GT event
# [FP] Network detected HFO at timestep 8275400 without an active GT event
# [FP] Network detected HFO at timestep 8275602 without an active GT event
# GT Event 3605 Insertion Timing: 8275920 at timestep 8275920
# [TP] Spike matched GT event at timestep 8275981 (GT: 8275920)
# GT Event 3606 Insertion Timing: 8276132 at timestep 8276132
# [TP] Spike matched GT event at timestep 8276196 (GT: 8276132)
# [FP] Network detected HFO at timestep 8276401 without an active GT event
# GT Event 3607 Insertion Timing: 8276503 at timestep 8276503
# [FN] GT event at 8276503 expired at timestep 8276576
# [FP] Network detected HFO at timestep 8276610 without an active GT event
# [FP] Network detected HFO at timestep 8276875 without an active GT event
# GT Event 3608 Insertion Timing: 8276902 at timestep 8276902
# [FN] GT event at 8276902 expired at timestep 8276975
# [FP] Network detected HFO at timestep 8277081 without an active GT event
# GT Event 3609 Insertion Timing: 8277185 at timestep 8277185
# [FN] GT event at 8277185 expired at timestep 8277258
# [FP] Network detected HFO at timestep 8277334 without an active GT event
# GT Event 3610 Insertion Timing: 8277366 at timestep 8277366
# [FN] GT event at 8277366 expired at timestep 8277439
# [FP] Network detected HFO at timestep 8277574 without an active GT event
# [FP] Network detected HFO at timestep 8277784 without an active GT event
# [FP] Network detected HFO at timestep 8278055 without an active GT event
# [FP] Network detected HFO at timestep 8278256 without an active GT event
# [FP] Network detected HFO at timestep 8278457 without an active GT event
# [FP] Network detected HFO at timestep 8278710 without an active GT event
# GT Event 3611 Insertion Timing: 8278738 at timestep 8278738
# [TP] Spike matched GT event at timestep 8278788 (GT: 8278738)
# [FP] Network detected HFO at timestep 8278989 without an active GT event
# [FP] Network detected HFO at timestep 8279786 without an active GT event
# [FP] Network detected HFO at timestep 8282030 without an active GT event
# GT Event 3612 Insertion Timing: 8282287 at timestep 8282287
# [TP] Spike matched GT event at timestep 8282345 (GT: 8282287)
# GT Event 3613 Insertion Timing: 8282458 at timestep 8282458
# [FN] GT event at 8282458 expired at timestep 8282531
# [FP] Network detected HFO at timestep 8282794 without an active GT event
# GT Event 3614 Insertion Timing: 8282847 at timestep 8282847
# [FN] GT event at 8282847 expired at timestep 8282920
# [FP] Network detected HFO at timestep 8283001 without an active GT event
# [FP] Network detected HFO at timestep 8285149 without an active GT event
# [FP] Network detected HFO at timestep 8285369 without an active GT event
# [FP] Network detected HFO at timestep 8285863 without an active GT event
# GT Event 3615 Insertion Timing: 8287593 at timestep 8287593
# [TP] Spike matched GT event at timestep 8287624 (GT: 8287593)
# GT Event 3616 Insertion Timing: 8287736 at timestep 8287736
# [FN] GT event at 8287736 expired at timestep 8287809
# [FP] Network detected HFO at timestep 8287836 without an active GT event
# GT Event 3617 Insertion Timing: 8288042 at timestep 8288042
# [TP] Spike matched GT event at timestep 8288053 (GT: 8288042)
# GT Event 3618 Insertion Timing: 8288196 at timestep 8288196
# [TP] Spike matched GT event at timestep 8288257 (GT: 8288196)
# GT Event 3619 Insertion Timing: 8288405 at timestep 8288405
# [FN] GT event at 8288405 expired at timestep 8288478
# [FP] Network detected HFO at timestep 8288478 without an active GT event
# GT Event 3620 Insertion Timing: 8288612 at timestep 8288612
# [FN] GT event at 8288612 expired at timestep 8288685
# [FP] Network detected HFO at timestep 8288743 without an active GT event
# [FP] Network detected HFO at timestep 8288949 without an active GT event
# GT Event 3621 Insertion Timing: 8289468 at timestep 8289468
# [TP] Spike matched GT event at timestep 8289498 (GT: 8289468)
# GT Event 3622 Insertion Timing: 8289621 at timestep 8289621
# [FN] GT event at 8289621 expired at timestep 8289694
# [FP] Network detected HFO at timestep 8289707 without an active GT event
# [FP] Network detected HFO at timestep 8289935 without an active GT event
# [FP] Network detected HFO at timestep 8290144 without an active GT event
# [FP] Network detected HFO at timestep 8290396 without an active GT event
# GT Event 3623 Insertion Timing: 8290533 at timestep 8290533
# [TP] Spike matched GT event at timestep 8290596 (GT: 8290533)
# GT Event 3624 Insertion Timing: 8291010 at timestep 8291010
# [TP] Spike matched GT event at timestep 8291068 (GT: 8291010)
# GT Event 3625 Insertion Timing: 8291073 at timestep 8291073
# [FN] GT event at 8291073 expired at timestep 8291146
# [FP] Network detected HFO at timestep 8291292 without an active GT event
# [FP] Network detected HFO at timestep 8291494 without an active GT event
# GT Event 3626 Insertion Timing: 8291528 at timestep 8291528
# [TP] Spike matched GT event at timestep 8291575 (GT: 8291528)
# [FP] Network detected HFO at timestep 8291942 without an active GT event
# [FP] Network detected HFO at timestep 8293745 without an active GT event
# GT Event 3627 Insertion Timing: 8294327 at timestep 8294327
# [FN] GT event at 8294327 expired at timestep 8294400
# GT Event 3628 Insertion Timing: 8294495 at timestep 8294495
# [FN] GT event at 8294495 expired at timestep 8294568
# [FP] Network detected HFO at timestep 8294652 without an active GT event
# GT Event 3629 Insertion Timing: 8294783 at timestep 8294783
# [FN] GT event at 8294783 expired at timestep 8294856
# [FP] Network detected HFO at timestep 8294868 without an active GT event
# GT Event 3630 Insertion Timing: 8295035 at timestep 8295035
# [FN] GT event at 8295035 expired at timestep 8295108
# [FP] Network detected HFO at timestep 8295114 without an active GT event
# GT Event 3631 Insertion Timing: 8295481 at timestep 8295481
# [FN] GT event at 8295481 expired at timestep 8295554
# [FP] Network detected HFO at timestep 8295615 without an active GT event
# GT Event 3632 Insertion Timing: 8296078 at timestep 8296078
# [FN] GT event at 8296078 expired at timestep 8296151
# [FP] Network detected HFO at timestep 8297737 without an active GT event
# [FP] Network detected HFO at timestep 8298415 without an active GT event
# [FP] Network detected HFO at timestep 8298692 without an active GT event
# [FP] Network detected HFO at timestep 8299046 without an active GT event
# GT Event 3633 Insertion Timing: 8299136 at timestep 8299136
# [TP] Spike matched GT event at timestep 8299146 (GT: 8299136)
# [FP] Network detected HFO at timestep 8299370 without an active GT event
# GT Event 3634 Insertion Timing: 8299556 at timestep 8299556
# [FN] GT event at 8299556 expired at timestep 8299629
# GT Event 3635 Insertion Timing: 8299843 at timestep 8299843
# [FN] GT event at 8299843 expired at timestep 8299916
# Processed step 8300000/8321032 (99.75%)
# [FP] Network detected HFO at timestep 8300162 without an active GT event
# GT Event 3636 Insertion Timing: 8300328 at timestep 8300328
# [TP] Spike matched GT event at timestep 8300391 (GT: 8300328)
# [FP] Network detected HFO at timestep 8300600 without an active GT event
# GT Event 3637 Insertion Timing: 8300607 at timestep 8300607
# [TP] Spike matched GT event at timestep 8300608 (GT: 8300607)
# GT Event 3638 Insertion Timing: 8300774 at timestep 8300774
# [FN] GT event at 8300774 expired at timestep 8300847
# [FP] Network detected HFO at timestep 8300883 without an active GT event
# [FP] Network detected HFO at timestep 8301087 without an active GT event
# [FP] Network detected HFO at timestep 8301291 without an active GT event
# GT Event 3639 Insertion Timing: 8301399 at timestep 8301399
# [FN] GT event at 8301399 expired at timestep 8301472
# GT Event 3640 Insertion Timing: 8301569 at timestep 8301569
# [FN] GT event at 8301569 expired at timestep 8301642
# [FP] Network detected HFO at timestep 8301786 without an active GT event
# [FP] Network detected HFO at timestep 8302166 without an active GT event
# GT Event 3641 Insertion Timing: 8302433 at timestep 8302433
# [FN] GT event at 8302433 expired at timestep 8302506
# [FP] Network detected HFO at timestep 8302547 without an active GT event
# [FP] Network detected HFO at timestep 8302769 without an active GT event
# GT Event 3642 Insertion Timing: 8302890 at timestep 8302890
# [TP] Spike matched GT event at timestep 8302936 (GT: 8302890)
# GT Event 3643 Insertion Timing: 8303074 at timestep 8303074
# [FN] GT event at 8303074 expired at timestep 8303147
# [FP] Network detected HFO at timestep 8303213 without an active GT event
# GT Event 3644 Insertion Timing: 8303270 at timestep 8303270
# [TP] Spike matched GT event at timestep 8303306 (GT: 8303270)
# [FP] Network detected HFO at timestep 8303535 without an active GT event
# [FP] Network detected HFO at timestep 8303744 without an active GT event
# [FP] Network detected HFO at timestep 8303956 without an active GT event
# [FP] Network detected HFO at timestep 8304173 without an active GT event
# [FP] Network detected HFO at timestep 8304384 without an active GT event
# GT Event 3645 Insertion Timing: 8306596 at timestep 8306596
# [FN] GT event at 8306596 expired at timestep 8306669
# [FP] Network detected HFO at timestep 8306699 without an active GT event
# [FP] Network detected HFO at timestep 8307059 without an active GT event
# [FP] Network detected HFO at timestep 8307271 without an active GT event
# GT Event 3646 Insertion Timing: 8307837 at timestep 8307837
# [TP] Spike matched GT event at timestep 8307903 (GT: 8307837)
# GT Event 3647 Insertion Timing: 8307957 at timestep 8307957
# [FN] GT event at 8307957 expired at timestep 8308030
# [FP] Network detected HFO at timestep 8308105 without an active GT event
# GT Event 3648 Insertion Timing: 8308125 at timestep 8308125
# [FN] GT event at 8308125 expired at timestep 8308198
# [FP] Network detected HFO at timestep 8308337 without an active GT event
# GT Event 3649 Insertion Timing: 8308410 at timestep 8308410
# [FN] GT event at 8308410 expired at timestep 8308483
# [FP] Network detected HFO at timestep 8308539 without an active GT event
# GT Event 3650 Insertion Timing: 8308833 at timestep 8308833
# [FN] GT event at 8308833 expired at timestep 8308906
# [FP] Network detected HFO at timestep 8308944 without an active GT event
# GT Event 3651 Insertion Timing: 8309106 at timestep 8309106
# [FN] GT event at 8309106 expired at timestep 8309179
# [FP] Network detected HFO at timestep 8309182 without an active GT event
# GT Event 3652 Insertion Timing: 8309236 at timestep 8309236
# [FN] GT event at 8309236 expired at timestep 8309309
# GT Event 3653 Insertion Timing: 8309410 at timestep 8309410
# [FN] GT event at 8309410 expired at timestep 8309483
# GT Event 3654 Insertion Timing: 8309664 at timestep 8309664
# [FN] GT event at 8309664 expired at timestep 8309737
# [FP] Network detected HFO at timestep 8311696 without an active GT event
# [FP] Network detected HFO at timestep 8312224 without an active GT event
# [FP] Network detected HFO at timestep 8313420 without an active GT event
# [FP] Network detected HFO at timestep 8314512 without an active GT event
# GT Event 3655 Insertion Timing: 8314634 at timestep 8314634
# [FN] GT event at 8314634 expired at timestep 8314707
# [FP] Network detected HFO at timestep 8314715 without an active GT event
# [FP] Network detected HFO at timestep 8314922 without an active GT event
# [FP] Network detected HFO at timestep 8315325 without an active GT event
# GT Event 3656 Insertion Timing: 8315656 at timestep 8315656
# [TP] Spike matched GT event at timestep 8315684 (GT: 8315656)
# [FP] Network detected HFO at timestep 8315941 without an active GT event
# [FP] Network detected HFO at timestep 8316166 without an active GT event
# GT Event 3657 Insertion Timing: 8316373 at timestep 8316373
# [TP] Spike matched GT event at timestep 8316436 (GT: 8316373)
# GT Event 3658 Insertion Timing: 8316530 at timestep 8316530
# [FN] GT event at 8316530 expired at timestep 8316603
# [FP] Network detected HFO at timestep 8316668 without an active GT event
# GT Event 3659 Insertion Timing: 8316876 at timestep 8316876
# [FN] GT event at 8316876 expired at timestep 8316949
# [FP] Network detected HFO at timestep 8316951 without an active GT event
# GT Event 3660 Insertion Timing: 8317026 at timestep 8317026
# [TP] Spike matched GT event at timestep 8317087 (GT: 8317026)
# [FP] Network detected HFO at timestep 8317452 without an active GT event
# GT Event 3661 Insertion Timing: 8317517 at timestep 8317517
# [FN] GT event at 8317517 expired at timestep 8317590
# GT Event 3662 Insertion Timing: 8317645 at timestep 8317645
# [FN] GT event at 8317645 expired at timestep 8317718
# [FP] Network detected HFO at timestep 8317721 without an active GT event
# [FP] Network detected HFO at timestep 8317964 without an active GT event
# [FP] Network detected HFO at timestep 8318384 without an active GT event
# [FP] Network detected HFO at timestep 8319342 without an active GT event
# GT Event 3663 Insertion Timing: 8319442 at timestep 8319442
# [TP] Spike matched GT event at timestep 8319497 (GT: 8319442)
# [FP] Network detected HFO at timestep 8319825 without an active GT event

# %%
# Show the Confusion Matrix
print(f"Confusion Matrix:")

# Print lines with same width
print(f"|TP: {TP} | FP: {FP}|\n|FN: {FN}  | TN: {TN}|")
if TP + FN != num_hfo_events:
    print("Mismatch in GT events")
    print(f"TP + FN: {TP + FN} | num_hfo_events: {num_hfo_events}")
# Out:
# Confusion Matrix:
# |TP: 2447 | FP: 14141|
# |FN: 1217  | TN: 8165928|

# %%
# Calculate the performance metrics
accuracy = round(((TP + TN) / (TP + TN + FP + FN)), 5)
recall = TP / (TP + FN) if (TP + FN) > 0 else 0
specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
false_positive_rate = FP / (FP + TN + 1e-10)

# %%
# Output the performance metrics
print(f"Accuracy (Right Prediction ): {accuracy:.4f}")
print(f"Recall (True Positive Rate): {recall:.4f}")
print(f"Specificity (True Negative Rate): {specificity:.4f}")
print(f"Precision (TP / (TP + FP)): {precision:.4f}")
print(f"F1 Score (Combines Precision & Recall): {f1_score:.4f}")
print(f"False Positive Rate (FP / (FP + TN)): {false_positive_rate:.4f}")
print(f"TP: {TP} | FP: {FP} | TN: {TN} | FN: {FN}")
# Out:
# Accuracy (Right Prediction ): 0.9981
# Recall (True Positive Rate): 0.6678
# Specificity (True Negative Rate): 0.9983
# Precision (TP / (TP + FP)): 0.1475
# F1 Score (Combines Precision & Recall): 0.2417
# False Positive Rate (FP / (FP + TN)): 0.0017
# TP: 2447 | FP: 14141 | TN: 8165928 | FN: 1217

# %%
total_predictions = TP + FP + TN + FN
print(f"Total Predictions: {total_predictions}")
print(f"Total Timesteps: {total_num_steps}")
# Out:
# Total Predictions: 8183733
# Total Timesteps: 8321032

# %%
import json

# Export the results to a JSON file
OUTPUT_FOLDER = f"eval/"
# create the output folder if it doesn't exist
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# Create a dictionary with the results
json_results = {
    "ripple_detection_offset": RIPPLE_DETECTION_OFFSET,
    "pred_causality_window": PRED_CAUSALITY_WINDOW,
    "max_detection_offset": MAX_DETECTION_OFFSET,
    "refractory_period_gt": refrac_period_gt,
    "refractory_period_fp": refrac_period_fp,
    "metrics": {
        "true_positive": TP,
        "false_positive": FP,
        "true_negative": TN,
        "false_negative": FN,
        "total_predictions": total_predictions,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1_score,
        "specificity": specificity
    }
}

EXPORT_JSON_FILE = True
if EXPORT_JSON_FILE:
    json_file_name = f"{OUTPUT_FOLDER}/{prefix}_results.json"
    with open(json_file_name, 'w') as f:
        json.dump(json_results, f,indent=4)

    print(f"Results exported to {json_file_name}")
else:
    print(json_results)
# Out:
# Results exported to eval//updnb4ds_100_6_results.json

# %%
out_spikes = np.array(out_spikes)
EXPORT_SPIKE_FILE = True
SPIKE_FOLDER= f"eval/spikes/"
if EXPORT_SPIKE_FILE:
    # create the output folder if it doesn't exist
    os.makedirs(SPIKE_FOLDER, exist_ok=True)
    spike_file_name = f"{SPIKE_FOLDER}/{prefix}_spikes_.npy"
    np.save(spike_file_name, out_spikes)
