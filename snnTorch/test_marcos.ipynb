# %%
# imports
import snntorch as snn
from snntorch import surrogate
from snntorch import backprop
from snntorch import functional as SF
from snntorch import utils
from snntorch import spikeplot as splt

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.nn.functional as F

import matplotlib.pyplot as plt
import numpy as np
import itertools
import os
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_35552\1700648380.py:4: DeprecationWarning: The module snntorch.backprop will be deprecated in  a future release. Writing out your own training loop will lead to substantially faster performance.
#   from snntorch import backprop

# %%
# dataloader arguments
batch_size = 32

data_path=r"C:\Users\Pc\Documents\Tese\LAVA_SNN_ripples\extract_Nripples\train_pedro\n_dataset\marcos\20"
bandpass=[100,250]
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
positives = np.load(os.path.join(data_path,f"ntrue_positives_{bandpass[0]}_{bandpass[1]}Hz.npy"))
negatives = np.load(os.path.join(data_path,f"ntrue_negatives_{bandpass[0]}_{bandpass[1]}Hz.npy"))

# %%
positives_tensor = torch.tensor(positives, dtype=torch.float32)
negatives_tensor = torch.tensor(negatives, dtype=torch.float32)
print(positives_tensor.shape, negatives_tensor.shape)
# Out:
# torch.Size([1794, 20, 246]) torch.Size([1800, 20, 246])

# %%
from torch.utils.data import DataLoader, TensorDataset,random_split

# Combine the data (positive and negative) into one dataset
X = torch.cat((positives_tensor, negatives_tensor), dim=0)

# for two classes (positive and negative), we need to create labels
# Create labels: 1 for positives and 0 for negatives
# Fixed version:
# y = torch.cat((torch.ones(positives_tensor.shape[0], dtype=torch.long),  # Note dtype
#                torch.zeros(negatives_tensor.shape[0], dtype=torch.long)), dim=0)

# For one class (ripples), we need to create labels
# First: stack the labels for each sample
y = torch.cat([
    torch.ones(len(positives_tensor)),    # shape: [1794]
    torch.zeros(len(negatives_tensor))    # shape: [1800]
])  # shape: [3594]


# Create a TensorDataset
dataset = TensorDataset(X, y)

# Define split ratios
test_ratio = 0.2  # 10% for testing
train_ratio = 1 - test_ratio

# Calculate split sizes
num_samples = len(dataset)
train_size = int(train_ratio * num_samples)
test_size = num_samples - train_size

# Split the dataset
train_dataset, test_dataset = random_split(
    dataset, 
    [train_size, test_size],
    generator=torch.Generator().manual_seed(42)  # for reproducibility
)

# Create DataLoaders
train_loader = DataLoader(
    train_dataset, 
    batch_size=batch_size, 
    shuffle=True,  # important for training
    drop_last=True  # drops last incomplete batch
)

test_loader = DataLoader(
    test_dataset, 
    batch_size=batch_size, 
    shuffle=False,  # no need to shuffle test data
    drop_last=False  # we want all test samples
)

# %% [markdown]
#  # Define the Network

# %%
# neuron and simulation parameters
spike_grad = surrogate.fast_sigmoid(slope=25)
beta = 0.5
num_steps = positives.shape[2]

# %%
#  Initialize Network
# Note: the following code-block simulates over one single time-step, and requires a separate for-loop over time.
input_size=20
num_classes=1
net = nn.Sequential(nn.Linear(input_size, 256),
                    snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True),
                    nn.Linear(256, 64),
                    snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True),
                    nn.Linear(64, num_classes),
                    snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True, output=True)
                    ).to(device)

# %%
data, targets = next(iter(train_loader))
data = data.to(device)
targets = targets.to(device)

for step in range(num_steps):
    current_data = data[:, :, step]
    spk_out, mem_out = net(current_data)

# %%
def forward_pass(net, num_steps, data):
  mem_rec = []
  spk_rec = []
  utils.reset(net)  # resets hidden states for all LIF neurons in net

  for step in range(num_steps):
      curr = data[:, :, step]
      spk_out, mem_out = net(curr)
      spk_rec.append(spk_out)
      mem_rec.append(mem_out)
  
  return torch.stack(spk_rec, dim=0), torch.stack(mem_rec,dim=0)

# %%
spk_rec, mem_rec = forward_pass(net, num_steps, data)
t,b,c=spk_rec.shape
targets=torch.zeros((t,b,c),device=spk_rec.device)

print("spk_rec shape:", spk_rec.shape)
print("targets shape:", targets.shape)
print("target unique values:", targets.unique())
for item in targets.unique():
    print(f"Number of samples with target {item.item()}: {torch.sum(targets == item).item()}")
# Out:
# spk_rec shape: torch.Size([246, 32, 1])
# targets shape: torch.Size([246, 32, 1])
# target unique values: tensor([0.])
# Number of samples with target 0.0: 7872

# %%
# already imported snntorch.functional as SF 
# loss_fn = SF.ce_rate_loss()
loss_fn=SF.mse_temporal_loss(tolerance=10)

loss_val = loss_fn(spk_rec, targets)

print(f"The loss from an untrained network is {loss_val.item():.3f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 5
#       1 # already imported snntorch.functional as SF
#       2 # loss_fn = SF.ce_rate_loss()
#       3 loss_fn=SF.mse_temporal_loss(tolerance=10)
# ----> 5 loss_val = loss_fn(spk_rec, targets)
#       7 print(f"The loss from an untrained network is {loss_val.item():.3f}")
#
# File c:\Users\Pc\anaconda3\envs\lava_snn_ripples\lib\site-packages\snntorch\functional\loss.py:801, in mse_temporal_loss.__call__(self, spk_rec, targets)
#     800 def __call__(self, spk_rec, targets):
# --> 801     spk_time, target_time = self.spk_time_fn(
#     802         spk_rec, targets
#     803     )  # return encoded targets
#     804     loss = self.loss_fn(
#     805         spk_time / spk_rec.size(0), target_time / spk_rec.size(0)
#     806     )  # spk_time_final: num_spikes x B x Nc. # Same with targets.
#     808     if self.weight is not None:
#
# File c:\Users\Pc\anaconda3\envs\lava_snn_ripples\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Pc\anaconda3\envs\lava_snn_ripples\lib\site-packages\snntorch\functional\loss.py:465, in SpikeTime.forward(self, spk_out, targets)
#     463 # convert labels to spike times
#     464 if not self.target_is_time:
# --> 465     targets = self.labels_to_spike_times(targets, num_outputs)
#     467 # convert negative spike times to time steps: -1 -->
#     468 # ( num_steps+ (-1) )
#     469 targets[targets < 0] = spk_out.size(0) + targets[targets < 0]
#
# File c:\Users\Pc\anaconda3\envs\lava_snn_ripples\lib\site-packages\snntorch\functional\loss.py:643, in SpikeTime.labels_to_spike_times(self, targets, num_outputs)
#     640 """Convert index labels [B] into spike times."""
#     642 if not self.multi_spike:
# --> 643     targets = self.label_to_single_spike(targets, num_outputs)
#     645 # pass in labels --> output multiple spikes
#     646 # assumes on_target & off_target are iterable
#     647 else:
#     648     targets = self.label_to_multi_spike(targets, num_outputs)
#
# File c:\Users\Pc\anaconda3\envs\lava_snn_ripples\lib\site-packages\snntorch\functional\loss.py:657, in SpikeTime.label_to_single_spike(self, targets, num_outputs)
#     653 """Convert labels from neuron index (dim: B) to first spike time
#     654 (dim: B x N)."""
#     656 # guess: i designed this code with on_target >> off_target in mind
# --> 657 targets = spikegen.targets_convert(
#     658     targets,
#     659     num_classes=num_outputs,
#     660     on_target=self.on_target,
#     661     off_target=self.off_target,
#     662 )
#     664 return targets
#
# File c:\Users\Pc\anaconda3\envs\lava_snn_ripples\lib\site-packages\snntorch\spikegen.py:842, in targets_convert(targets, num_classes, code, num_steps, first_spike_time, correct_rate, incorrect_rate, on_target, off_target, firing_pattern, interpolate, epsilon, threshold, tau, clip, normalize, linear, bypass)
#     838 # raise exceptions if num_steps is not supplied, and rates have
#     839 # been specified, or if latency is specified.
#     841 if code == "rate":
# --> 842     return targets_rate(
#     843         targets=targets,
#     844         num_classes=num_classes,
#     845         num_steps=num_steps,
#     846         first_spike_time=first_spike_time,
#     847         correct_rate=correct_rate,
#     848         incorrect_rate=incorrect_rate,
#     849         on_target=on_target,
#     850         off_target=off_target,
#     851         firing_pattern=firing_pattern,
#     852         interpolate=interpolate,
#     853         epsilon=epsilon,
#     854     )
#     856 # do we need num_steps
#     857 elif code == "latency":
#
# File c:\Users\Pc\anaconda3\envs\lava_snn_ripples\lib\site-packages\snntorch\spikegen.py:1024, in targets_rate(targets, num_classes, num_steps, first_spike_time, correct_rate, incorrect_rate, on_target, off_target, firing_pattern, interpolate, epsilon)
#    1021 if first_spike_time == 0:
#    1022     if on_target > off_target:
#    1023         return torch.clamp(
# -> 1024             to_one_hot(targets, num_classes) * on_target, off_target
#    1025         )
#    1026     else:
#    1027         return (
#    1028             to_one_hot(targets, num_classes) * on_target
#    1029             + ~(to_one_hot(targets, num_classes)).bool() * off_target
#    1030         )
#
# File c:\Users\Pc\anaconda3\envs\lava_snn_ripples\lib\site-packages\snntorch\spikegen.py:1589, in to_one_hot(targets, num_classes)
#    1584 one_hot = torch.zeros(
#    1585     [len(targets), num_classes], device=device, dtype=dtype
#    1586 )
#    1588 # Unsqueeze converts dims of [100] to [100, 1]
# -> 1589 one_hot = one_hot.scatter(1, targets.type(torch.int64).unsqueeze(-1), 1)
#    1591 return one_hot
#
# RuntimeError: Index tensor must have the same number of dimensions as self tensor

# %%
# acc = SF.accuracy_rate(spk_rec, targets)
acc= SF.accuracy_temporal(spk_rec, targets)
print(f"The accuracy of a single batch using an untrained network is {acc*100:.3f}%")
# Out:
# The accuracy of a single batch using an untrained network is 48.438%

# %%
def batch_accuracy(train_loader, net, num_steps):
  with torch.no_grad():
    total = 0
    acc = 0
    net.eval()
    
    train_loader = iter(train_loader)
    for data, targets in train_loader:
      data = data.to(device)
      targets = targets.to(device)
      spk_rec, _ = forward_pass(net, num_steps, data)

      acc += SF.accuracy_rate(spk_rec, targets) * spk_rec.size(1)
      total += spk_rec.size(1)

  return acc/total

# %% [markdown]
# # Training Loop

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=1e-2, betas=(0.9, 0.999))
num_epochs = 50
loss_hist = []
test_acc_hist = []
counter = 0

# Outer training loop
for epoch in range(num_epochs):

    # Training loop
    for data, targets in iter(train_loader):
        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        spk_rec, _ = forward_pass(net, num_steps, data)

        # initialize the loss & sum over time
        loss_val = loss_fn(spk_rec, targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        if counter % 50 == 0:
          with torch.no_grad():
              net.eval()
              # Test set forward pass
              test_acc = batch_accuracy(test_loader, net, num_steps)
              print(f"Iteration {counter}, Test Acc: {test_acc * 100:.2f}%\n")
              test_acc_hist.append(test_acc.item())

        counter += 1
# Out:
# Iteration 0, Test Acc: 46.94%
#
# Iteration 50, Test Acc: 89.17%
#
# Iteration 100, Test Acc: 87.22%
#
# Iteration 150, Test Acc: 82.22%
#
# Iteration 200, Test Acc: 81.94%
#
# Iteration 250, Test Acc: 81.94%
#
# Iteration 300, Test Acc: 83.06%
#
# Iteration 350, Test Acc: 85.00%
#
# Iteration 400, Test Acc: 85.28%
#
# Iteration 450, Test Acc: 85.56%
#
# Iteration 500, Test Acc: 85.00%
#
# Iteration 550, Test Acc: 85.00%
#
# Iteration 600, Test Acc: 85.83%
#
# Iteration 650, Test Acc: 85.56%
#
# Iteration 700, Test Acc: 86.11%
#
# Iteration 750, Test Acc: 85.56%
#
# Iteration 800, Test Acc: 85.56%
#
# Iteration 850, Test Acc: 85.56%
#
# Iteration 900, Test Acc: 85.56%
#
# Iteration 950, Test Acc: 85.56%
#
# Iteration 1000, Test Acc: 85.56%
#
# Iteration 1050, Test Acc: 85.56%
#
# Iteration 1100, Test Acc: 85.56%
#
# Iteration 1150, Test Acc: 85.56%
#
# Iteration 1200, Test Acc: 85.56%

# %%
# Plot Loss
fig = plt.figure(facecolor="w")
plt.plot(test_acc_hist)
plt.title("Test Set Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
# plt.plot(test_loss_hist)
plt.title("Loss Curves")
plt.legend(["Train Loss", "Test Loss"])
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
def evaluate_acc(model, test_loader, num_steps):
    model.eval()
    total_correct = 0
    total_samples = 0
    
    with torch.no_grad():
        for data, targets in test_loader:
            data, targets = data.to(device), targets.to(device)
            
            # Forward pass
            spk_rec, _ = forward_pass(model, num_steps, data)
            
            # Calculate accuracy
            acc = SF.accuracy_rate(spk_rec, targets)
            total_correct += acc * targets.size(0)
            total_samples += targets.size(0)
    
    final_acc = total_correct / total_samples
    print(f"Final Test Accuracy: {final_acc*100:.2f}%")
    return final_acc

# Run evaluation
final_accuracy = evaluate_acc(net, test_loader, num_steps)
# Out:
# Final Test Accuracy: 85.56%

# %%
def evaluate_model(model, loader, num_steps):
    model.eval()
    all_preds = []
    all_targets = []
    
    with torch.no_grad():
        for data, targets in loader:
            data, targets = data.to(device), targets.to(device)
            
            # Forward pass
            spk_rec, _ = forward_pass(model, num_steps, data)
            
            # Sum spikes over time and get predictions
            preds = spk_rec.sum(dim=0).argmax(dim=1)  # shape: [batch_size]
            
            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(targets.cpu().numpy())
    
    return np.array(all_preds), np.array(all_targets)

# Get predictions for entire test set
y_pred, y_true = evaluate_model(net, test_loader, num_steps)
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Precision: 0.9664
# Recall: 0.7539
# F1 Score: 0.8471

# %%
def plot_sample_spikes(model, sample_data, true_label, num_steps, id=0):
    model.eval()
    
    # Select specific sample
    sample_data = sample_data[id]
    true_label = true_label[id]
    
    with torch.no_grad():
        spk_rec, mem_rec = forward_pass(model, num_steps, sample_data.unsqueeze(0))  # Add batch dim

    # Convert true_label to Python scalar
    true_label = true_label.item() if torch.is_tensor(true_label) else true_label
    
    # Get predictions
    total_spikes = spk_rec.sum(dim=0)  # shape: [1, 2]
    neg_spikes = total_spikes[0, 0].item()  # Negative class
    pos_spikes = total_spikes[0, 1].item()  # Positive class
    
    predicted_class = 1 if pos_spikes > neg_spikes else 0
    true_label_str = "Positive" if true_label else "Negative"
    pred_label_str = "Positive" if predicted_class else "Negative"
    correct_str = "✓ CORRECT" if predicted_class == true_label else "✗ WRONG"

    # Create figure with 3 subplots
    fig,axes=plt.subplots(3,1,figsize=(14, 10),sharex=True)
    
    # 1. Input Spikes (assuming 2 input channels)
    ax=axes[0]
    for i in range(2):  # For each input channel
        spikes = sample_data[i].cpu().nonzero()[:, 0].numpy()
        ax.eventplot(spikes, lineoffsets=i, colors=['b', 'm'][i], 
                     linewidths=2, label=f"Input Channel {i}")
    ax.set_yticks([0, 1], ["Channel 0", "Channel 1"])
    ax.set_title(f"Input Spikes | Sample ID: {id}")
    ax.set_ylabel("Input Neurons")
    ax.legend()

    # 2. Membrane Potentials
    ax=axes[1]
    ax.plot(mem_rec[:, 0, 0].cpu(), 'r', label="Negative Output Neuron")
    ax.plot(mem_rec[:, 0, 1].cpu(), 'g', label="Positive Output Neuron")
    ax.set_title(f"Membrane Potentials | True: {true_label_str} | Pred: {pred_label_str} | {correct_str}")
    ax.set_ylabel("Potential")
    ax.legend()

    # 3. Output Spikes
    ax=axes[2]
    ax.eventplot(spk_rec[:, 0, 0].cpu().nonzero()[:, 0].numpy(), 
                 lineoffsets=0, colors='r', label="Negative")
    ax.eventplot(spk_rec[:, 0, 1].cpu().nonzero()[:, 0].numpy(),
                 lineoffsets=1, colors='g', label="Positive")
    ax.yticks([0, 1], ["Negative", "Positive"])
    ax.xlabel("Time Step")
    ax.ylabel("Output Spikes")
    ax.legend()
    
    plt.tight_layout()
    plt.show()

    print(f"Sample {id} | True: {true_label_str} | Predicted: {pred_label_str}")
    print(f"Spike counts - Negative: {neg_spikes:.1f}, Positive: {pos_spikes:.1f}")
    print(f"Classification: {correct_str}")

# Usage
sample_data, true_label = next(iter(test_loader))
plot_sample_spikes(net, sample_data, true_label, num_steps, id=3)  # Visualize sample 1
# Out:
# Sample 3 | True: Negative | Predicted: Negative
# Spike counts - Negative: 209.0, Positive: 20.0
# Classification: ✓ CORRECT

# %%
# def plot_sample_spikes(model, test_loader, num_steps, sample_idx=None):
#     """Visualize spikes and membrane potentials with class-specific outputs."""
#     # Get sample
#     test_data = test_loader.dataset
#     if sample_idx is None:
#         sample_idx = torch.randint(0, len(test_data), (1,)).item()
    
#     sample_data, true_label = test_data[sample_idx]
#     sample_data = sample_data.to(device).unsqueeze(0)  # add batch dim

#     # Forward pass
#     model.eval()
#     with torch.no_grad():
#         spk_rec, mem_rec = forward_pass(model, num_steps, sample_data)
    
#     # Prediction (which neuron spiked more)
#     spike_counts = spk_rec.sum(0).squeeze()  # sum over time [2]
#     predicted_label = spike_counts.argmax().item()
#     confidence = spike_counts / spike_counts.sum()  # normalized firing rates

#     # Create figure
#     fig = plt.figure(figsize=(16, 10))
#     gs = fig.add_gridspec(3, 2)
    
#     # Membrane potentials (one subplot per output neuron)
#     ax1 = fig.add_subplot(gs[0, 0])
#     ax1.plot(mem_rec[:, 0, 0].cpu(), 'r', label="Negative Class Neuron")
#     ax1.set_title(f"Negative Class Output (True: {'Positive' if true_label else 'Negative'})")
#     ax1.set_ylabel("Membrane Potential")
#     ax1.legend()
    
#     ax2 = fig.add_subplot(gs[0, 1])
#     ax2.plot(mem_rec[:, 0, 1].cpu(), 'g', label="Positive Class Neuron")
#     ax2.set_title(f"Positive Class Output (Predicted: {'Positive' if predicted_label else 'Negative'})")
#     ax2.legend()

#     # Output spikes (raster plot)
#     ax3 = fig.add_subplot(gs[1, :])
#     for i in range(2):  # for each output neuron
#         spikes = spk_rec[:, 0, i].cpu().nonzero()[:, 0].numpy()
#         ax3.eventplot(spikes, lineoffsets=i+1, colors=['r', 'g'][i], linewidths=2)
#     ax3.set_yticks([1, 2], ["Negative Neuron", "Positive Neuron"])
#     ax3.set_title(f"Output Spikes | Confidence: {confidence[0]:.2f}/{confidence[1]:.2f}")
#     ax3.set_ylabel("Output Neurons")

#     # Input spikes
#     ax4 = fig.add_subplot(gs[2, :])
#     for i in range(2):  # up/down channels
#         spikes = sample_data[0, i].cpu().nonzero()[:, 0].numpy()
#         ax4.eventplot(spikes, lineoffsets=i+1, colors=['b', 'm'][i], linewidths=1)
#     ax4.set_yticks([1, 2], ["Input Down", "Input Up"])
#     ax4.set_xlabel("Time Step")
#     ax4.set_ylabel("Input Spikes")

#     plt.suptitle(f"Sample {sample_idx} | "
#                 f"True: {'Positive' if true_label else 'Negative'} | "
#                 f"Predicted: {'Positive' if predicted_label else 'Negative'} | "
#                 f"{'CORRECT' if true_label == predicted_label else 'WRONG'}", 
#                 fontsize=14, y=1.02)
#     plt.tight_layout()
#     plt.show()

#     return sample_idx

# # Interactive usage:
# def explore_samples(model, test_loader, num_steps):
#     """Interactive sample explorer."""
#     current_idx = 0
#     total_samples = len(test_loader.dataset)
    
#     while True:
#         print(f"\nSample {current_idx}/{total_samples-1}")
#         current_idx = plot_sample_spikes(model, test_loader, num_steps, current_idx)
        
#         user_input = input("Next [n], Previous [p], Jump to index [0-9], Quit [q]: ")
#         if user_input.lower() == 'n':
#             current_idx = (current_idx + 1) % total_samples
#         elif user_input.lower() == 'p':
#             current_idx = (current_idx - 1) % total_samples
#         elif user_input.isdigit():
#             new_idx = int(user_input)
#             if 0 <= new_idx < total_samples:
#                 current_idx = new_idx
#         elif user_input.lower() == 'q':
#             break

# # Usage:
# explore_samples(net, test_loader, num_steps)

# %%
# Saving
# def save_model(model, optimizer, path, extra_info=None):
#     save_dict = {
#         'model_state_dict': model.state_dict(),
#         'optimizer_state_dict': optimizer.state_dict(),
#         'model_params': {
#             'input_size': 2,
#             'num_classes': 2,
#             'beta': beta,
#         }
#     }
#     if extra_info:
#         save_dict.update(extra_info)
#     torch.save(save_dict, path)

# # Example usage
# save_model(net, optimizer, 'snn_checkpoint.pth', 
#           {'loss_hist': loss_hist, 'test_acc': test_acc_hist})
