# %%
import matplotlib.pyplot as plt
import json
import pickle as pkl
import os
import numpy as np
from collections import defaultdict
from scipy.stats import pearsonr

# %%
# parent = r"C:\__NeuroSpark_Liset_Dataset__\neurospark_mat\CNN_TRAINING_SESSIONS" # Modify this to your data path folder
parent = r"C:\__NeuroSpark_Liset_Dataset__\neurospark_mat\Download_from_paper" # Modify this to your data path folder
# parent=r"E:\neurospark_mat\CNN_TRAINING_SESSIONS"
# parent=r"E:\neurospark_mat\Download_from_paper"

bandpass=[100,250]
downsampled_fs = 30000 # Downsampled frequency
factor=downsampled_fs//1000
time_max=20
window_size=0.1
sample_ratio=0.25
scaling_factor=1
refractory=0.0003
percentile=False
fraction=(0,1)
downsample_factor=30000//downsampled_fs
overlap=int(time_max/2)

# %%
adaptive_thresholds=False
load_path = os.path.join(os.getcwd())
filename = f"thresholds_and_spikerates_adapt{time_max}.pkl" if adaptive_thresholds else f"thresholds_and_spikerates_fixed{time_max}.pkl"
file_path = os.path.join(load_path, filename)
with open(file_path, "rb") as f:
    data = pkl.load(f)
    thresholds = data["thresholds"]
    spike_rates = data["spike_rates"]

# %%
# Example: extract X% of precomputed thresholds
fraction_start =  0.8 
fraction_end = 1.0

extracted_thresholds = {}
extracted_spike_rates = {}
for dataset in thresholds:
    dataset_thresholds = thresholds[dataset]
    dataset_spikerates = spike_rates[dataset]
    extracted_dataset_thresholds = {}
    extracted_dataset_spikerates = {}

    for channel in dataset_thresholds:
        channel_thresholds = dataset_thresholds[channel]
        channel_spikerates = dataset_spikerates[channel]
        total_windows = len(channel_thresholds)

        start_idx = int(fraction_start * total_windows)
        end_idx = int(fraction_end * total_windows)

        extracted_dataset_thresholds[channel] = channel_thresholds[start_idx:end_idx]
        extracted_dataset_spikerates[channel] = channel_spikerates[start_idx:end_idx]

    extracted_spike_rates[dataset] = extracted_dataset_spikerates
    extracted_thresholds[dataset] = extracted_dataset_thresholds

# %%
# Evolution of thresholds with time

# Loop through each dataset
for dataset_name, channel_dict in extracted_thresholds.items():
    
    plt.figure(figsize=(12, 6))
    plt.title(f"Baseline Threshold Progression - {dataset_name}")
    
    # Loop through each channel
    for channel, threshold_list in channel_dict.items():
        time_axis = [i * overlap for i in range(len(threshold_list))]
        plt.plot(time_axis,threshold_list, label=f"Channel {channel}")
        if channel=="0":
            print()
    
    plt.xlabel("Time (s)")
    plt.ylabel("Baseline Threshold")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
from scipy.stats import pearsonr

colors = plt.cm.tab10.colors  # color palette

# Store for overall plot
threshold_all = []
spike_all = []
dataset_labels = []

for i, dataset_name in enumerate(thresholds.keys()):
    thresholds_dataset = []
    spikerates_dataset = []
    print(f"Processing dataset: {dataset_name}")
    for channel in thresholds[dataset_name].keys():
        channel_rates = spike_rates[dataset_name][channel]
        channel_thresholds = thresholds[dataset_name][channel]
        if len(channel_rates) != len(channel_thresholds):
            print(f"Length mismatch for dataset {dataset_name}, channel {channel}: {len(channel_rates)} vs {len(channel_thresholds)}")
        thresholds_dataset.extend(channel_thresholds)
        spikerates_dataset.extend(channel_rates)

    # Switched axis in correlation
    r_val, p_val = pearsonr(thresholds_dataset, spikerates_dataset)

    threshold_all.extend(thresholds_dataset)
    spike_all.extend(spikerates_dataset)
    dataset_labels.extend([dataset_name] * len(spikerates_dataset))

    print(f"Dataset: {dataset_name}, Pearson r = {r_val:.3f}, p = {p_val:.3e}")
    plt.figure(figsize=(8, 6))

    # Switched axis in plot
    plt.scatter(thresholds_dataset, spikerates_dataset, alpha=0.6, s=30,
                c=colors[i % len(colors)], edgecolors='k')

    # Switched x and y for trendline
    slope, intercept = np.polyfit(thresholds_dataset, spikerates_dataset, 1)
    x_vals = np.array([min(thresholds_dataset), max(thresholds_dataset)])
    y_vals = slope * x_vals + intercept
    plt.plot(x_vals, y_vals, color='red', linestyle='--', label='Trendline')

    plt.title(f"Threshold vs Spike Rate - {dataset_name}\nPearson r = {r_val:.3f}, p = {p_val:.3e}")
    plt.xlabel("Threshold")
    plt.ylabel("Spike Rate (Hz)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Processing dataset: Amigo2_2019-07-11_11-57-07
# Dataset: Amigo2_2019-07-11_11-57-07, Pearson r = 0.425, p = 1.840e-84
# C:\Users\NCN\AppData\Local\Temp\ipykernel_25964\600674820.py:33: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(thresholds_dataset, spikerates_dataset, alpha=0.6, s=30,
# Processing dataset: Dlx1_2021-02-12_12-46-54
# Dataset: Dlx1_2021-02-12_12-46-54, Pearson r = 0.351, p = 7.864e-25
# Processing dataset: Som2_2019-07-24_12-01-49
# Dataset: Som2_2019-07-24_12-01-49, Pearson r = 0.282, p = 2.175e-16
# Processing dataset: Thy7_2020-11-11_16-05-00
# Dataset: Thy7_2020-11-11_16-05-00, Pearson r = 0.344, p = 1.237e-17

# %%
# 2. Combined plot with color-coded datasets
plt.figure(figsize=(10, 7))
unique_datasets = list(thresholds.keys())

for i, dataset_name in enumerate(unique_datasets):
    # Mask for current dataset
    mask = [label == dataset_name for label in dataset_labels]
    plt.scatter(
        [threshold_all[j] for j in range(len(threshold_all)) if mask[j]],  # now x-axis
        [spike_all[j] for j in range(len(spike_all)) if mask[j]],          # now y-axis
        alpha=0.6, s=30, c=[colors[i % len(colors)]], edgecolors='k', label=dataset_name
    )

# Overall correlation (flipped args)
r_all, p_all = pearsonr(threshold_all, spike_all)
print(f"Overall Pearson r = {r_all:.3f}, p = {p_all:.2e}")

# Fit and plot overall trendline (flipped)
slope, intercept = np.polyfit(threshold_all, spike_all, 1)
x_vals = np.array([min(threshold_all), max(threshold_all)])
y_vals = slope * x_vals + intercept
plt.plot(x_vals, y_vals, color='red', linestyle='--', label='Overall Trendline')

plt.title(f"Overall Baseline Threshold vs Spike Rate\nPearson r = {r_all:.3f}, p = {p_all:.2e}")
plt.xlabel("Baseline Threshold")
plt.ylabel("Spike Rate (Hz)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Overall Pearson r = 0.377, p = 9.34e-139

# %% [markdown]
# ## Evaluate Results

# %%
adapt=20
identifier="30000_1000_100"
identifier=f"{identifier}_adaptable{adapt}" if adapt>0 else f"{identifier}"
# identifier="1000_200_median"
dataset_path=os.path.join(os.getcwd(),os.pardir,"train_pedro","dataset_up_down",identifier)
datasets=os.listdir(dataset_path)
if "config.json" in datasets:
    datasets.remove("config.json")

results_path=os.path.join(os.getcwd(),os.pardir,os.pardir,"snnTorch","eval","live_results")
filename=f"all_network_results_{identifier}.pkl"
path_file=os.path.join(results_path, filename)
with open(path_file, "rb") as f:
    all_networks_info = pkl.load(f)

# %%
# # Load results
# with open(results_json, 'r') as f:
#     results = json.load(f)
# # Load spikes
# spikes = np.load(spikes, allow_pickle=True)

# %%
# # Get some parameters
# parameters=results["parameters"]
# ripple_detection_offset=parameters["ripple_detection_offset"]

# refractory_period=parameters["refractory_period_gt"]
refractory_period=0 # in ms

# max_detection_offset=parameters["max_detection_offset"]

# tolerance=parameters["tolerance"]
tolerance=20 # in ms
padding=100 # in ms
max_detection_offset=80 # in ms
jitter=100

# %%
# Read the datasets and evaluate the results
information_dataset={}
for dataset_id,dataset in enumerate(datasets):

    data_path= os.path.join(dataset_path, dataset)
    print(f"Processing dataset: {data_path}")
    data=np.load(os.path.join(data_path, "spike_data.npy"))  # Load the input data (UP/DN spikes)
    ripples=np.load(os.path.join(data_path, "ripples.npy"))  # Load the GT data (HFO Insertion Timing)
    dataset_results = results[dataset]  # Get the results for the current dataset

    # ripples_start = ripples[:, 0]  # Get the GT Insertion Timing (first column of the ripples array)
    if SEEDED:
        # If the data is seeded, we need to slice the data to the desired time window
        data = data[window,:]
        ripples_window = []
        for ripple in ripples:
            if ripple[1] >= window[0] and ripple[0] <= window[-1]:
                    ripples_window.append(ripple)
        ripples=np.array(ripples_window)-window[0]-tolerance  # Adjust the GT Insertion Timing to the new window
    else:
        ripples=ripples-tolerance
    
    num_hfo_events = len(ripples)
    dataset_spikes= spikes[dataset_id*8:(dataset_id+1)*8,:]

    ripple_hits = {}  # List of sets: which channels hit each ripple
    undetected_ripples = []  # Indices of ripples missed by all channels
    num_channels = dataset_spikes.shape[0]
    filtered_spikes = []  # List of filtered spikes for each channel
    
    # GET VALID SPIKES by REMOVING REFRACTORY PERIOD VIOLATIONS
    for ch_spikes in dataset_spikes:
        # Sort spikes just in case (important)
        sorted_spikes = np.sort(ch_spikes)
        
        if len(sorted_spikes) == 0:
            filtered_spikes.append(np.array([]))
            continue

        valid = [sorted_spikes[0]]
        for spike in sorted_spikes[1:]:
            if spike - valid[-1] >= refractory_period:
                valid.append(spike)
        filtered_spikes.append(np.array(valid))

    ripples_start = ripples[:, 0]  # Get the GT Insertion Timing (first column of the ripples array)
    # DETECT RIPPLE HITS
    for idx, ripple_time in enumerate(ripples_start):
        detected_channels = set()

        for ch in range(num_channels):
            valid_window_start= ripple_time - tolerance
            valid_window_end = ripple_time + max_detection_offset + tolerance
            ch_spikes = filtered_spikes[ch]
            in_window = np.any((ch_spikes >= valid_window_start) & 
                            (ch_spikes <= valid_window_end))
            if in_window:
                detected_channels.add(ch)

        ripple_hits[idx] = detected_channels  # store in dict by ripple index

        if not detected_channels:
            undetected_ripples.append(idx)

    # COLLECT FALSE POSITIVE SPIKES
    valid_detection_ranges = []

    for ripple_time in ripples:
        start = ripple_time[0] - tolerance
        end = ripple_time[0] + max_detection_offset + tolerance + padding
        # end=max(end,ripple_time[1] + padding)  # Ensure end is at least ripple_time[1] + padding
        valid_detection_ranges.append((start, end))

    # STEP 2: Function to check if a spike is inside any ripple detection window
    def is_tp(spike_time, valid_ranges):
        for start, end in valid_ranges:
            if start <= spike_time <= end:
                return True
        return False
    
    fp_spikes_by_channel = defaultdict(list)
    for ch in range(num_channels):
        # STEP 1: Create set of all valid detection time ranges
        for spike_time in filtered_spikes[ch]:
            if not is_tp(spike_time, valid_detection_ranges):
                fp_spikes_by_channel[ch].append(spike_time)
    
    # Group by time with jitter
    overlap_counts = defaultdict(set)  # spike_time -> set of channels that had an FP there
    fp_timing_to_channels = defaultdict(set)
    jitter= np.round(max_detection_offset) # half of the max detection offset
    for ch, spike_list in fp_spikes_by_channel.items():
        for spike_time in spike_list:
            matched_time = None

            # Try to match this spike to an existing FP group (within jitter)
            for t in range(int(spike_time - jitter),int( spike_time + jitter + 1)):
                if t in fp_timing_to_channels:
                    matched_time = t
                    break
            if matched_time is not None:
                fp_timing_to_channels[matched_time].add(ch)
            else:
                fp_timing_to_channels[spike_time].add(ch)

    information_dataset[dataset] = {
    "ripple_hits": ripple_hits,  # now a dict: ripple_idx -> set of channels
    "undetected_ripples": undetected_ripples,  # list of ints
    "filtered_spikes": filtered_spikes,  # list of arrays
    "fp_spikes_by_channel": fp_spikes_by_channel,  # dict: ch -> [spike times]
    "fp_timing_to_channels": dict(fp_timing_to_channels),  # dict: time -> set(channels)
    }
# Out:
# Processing dataset: c:\Users\NCN\Documents\PedroFelix\LAVA_SNN_ripples\extract_Nripples\thresholds_and_spikerates\..\train_pedro\dataset_up_down\30000_1000_100_adaptable2\Amigo2_2019-07-11_11-57-07
# Processing dataset: c:\Users\NCN\Documents\PedroFelix\LAVA_SNN_ripples\extract_Nripples\thresholds_and_spikerates\..\train_pedro\dataset_up_down\30000_1000_100_adaptable2\Dlx1_2021-02-12_12-46-54
# Processing dataset: c:\Users\NCN\Documents\PedroFelix\LAVA_SNN_ripples\extract_Nripples\thresholds_and_spikerates\..\train_pedro\dataset_up_down\30000_1000_100_adaptable2\Som2_2019-07-24_12-01-49
# Processing dataset: c:\Users\NCN\Documents\PedroFelix\LAVA_SNN_ripples\extract_Nripples\thresholds_and_spikerates\..\train_pedro\dataset_up_down\30000_1000_100_adaptable2\Thy7_2020-11-11_16-05-00

# %%
threshold_tp_fp_fn_by_window = defaultdict(lambda: defaultdict(dict))  # {dataset: {channel: {window_idx: {...}}}}
window_metrics_by_dataset = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

for dataset_name, info in information_dataset.items():
    data_path = os.path.join(dataset_path, dataset_name)
    ripple_hits = info["ripple_hits"]  # dict: ripple_idx -> set of channels
    ripples=np.load(os.path.join(data_path, "ripples.npy"))  # Load the GT data (HFO Insertion Timing)
    data=np.load(os.path.join(data_path, "spike_data.npy"))  # Load the input data (UP/DN spikes)

    filtered_spikes = info["filtered_spikes"]
    
    for ch, ch_spikes in enumerate(filtered_spikes):
        ch_thresholds = extracted_thresholds[dataset_name][str(ch)]
        ch_rates = extracted_spike_rates[dataset_name][str(ch)]

        max_time = int(data.shape[0])
        n_windows = int(np.ceil(max_time /(overlap*1000)))

        for window_idx in range(n_windows):
            start_time = window_idx * overlap*1000
            end_time = start_time + overlap*1000
            spikes_in_window = ch_spikes[(ch_spikes >= start_time) & (ch_spikes < end_time)]

            # Ripples overlapping this window
            ripples_in_window = []
            ripple_ids_in_window=[]
            for i,ripple in enumerate(ripples):
                ripple_start = ripple[0] - tolerance
                ripple_end = ripple[0] + max_detection_offset + tolerance
                if not (ripple_end < start_time or ripple_start > end_time):
                    ripples_in_window.append((ripple_start, ripple_end))
                    ripple_ids_in_window.append(i)

            TP = 0
            FP = 0
            FN = 0
            matched_spikes = set()
            matched_ripples = set()
            for ripple_idx in ripple_ids_in_window:
                if ripple_idx in ripple_hits.keys():
                    if ch in ripple_hits[ripple_idx]:
                        TP += 1
                    else:
                        FN += 1

         
            # Match spikes to ripples with jitter
            for spike_time in spikes_in_window:
                matched = False
                for idx, (r_start, r_end) in enumerate(ripples_in_window):
                    if (r_start) <= spike_time <= (r_end + padding):
                            matched = True
                            matched_spikes.add(spike_time)
                            break
                    
            last_fp_time = -np.inf  # reset per window

            for spike_time in spikes_in_window:
                if spike_time in matched_spikes:
                    continue

                near_ripple = any(spike_time <= r_end + padding for (_, r_end) in ripples_in_window)
                if near_ripple:
                    continue

                if spike_time - last_fp_time > jitter:
                    FP += 1
                    last_fp_time = spike_time


            # Fetch threshold
            if window_idx < len(ch_thresholds):
                threshold = ch_thresholds[window_idx]
                rate= ch_rates[window_idx]
            else:
                threshold = None
                rate=None

            # Store
            threshold_tp_fp_fn_by_window[dataset_name][ch][window_idx] = {
                "TP": TP,
                "FP": FP,
                "FN": FN,
                "threshold": threshold,
                "rate":rate ,
            }
            # Save to plotting dictionary
            window_metrics_by_dataset[dataset_name][ch]["TP"].append(TP)
            window_metrics_by_dataset[dataset_name][ch]["FP"].append(FP)
            window_metrics_by_dataset[dataset_name][ch]["FN"].append(FN)
            window_metrics_by_dataset[dataset_name][ch]["threshold"].append(threshold)
            window_metrics_by_dataset[dataset_name][ch]["rate"].append(rate)
            print(f"Dataset: {dataset_name}, Channel: {ch}, Window: {window_idx}, TP: {TP}, FP: {FP}, FN: {FN}, Threshold: {threshold}, Rate: {rate}")
# Out:
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 0, TP: 6, FP: 3, FN: 4, Threshold: 0.4317, Rate: 120.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 1, TP: 5, FP: 0, FN: 2, Threshold: 0.4495, Rate: 129.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 2, TP: 3, FP: 1, FN: 0, Threshold: 0.4692, Rate: 131.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 3, TP: 4, FP: 0, FN: 1, Threshold: 0.4286, Rate: 137.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 4, TP: 8, FP: 0, FN: 1, Threshold: 0.457, Rate: 118.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 5, TP: 10, FP: 1, FN: 0, Threshold: 0.4576, Rate: 147.60000000000002
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 6, TP: 4, FP: 10, FN: 0, Threshold: 0.4189, Rate: 157.20000000000002
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 7, TP: 2, FP: 0, FN: 0, Threshold: 0.4634, Rate: 138.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 8, TP: 3, FP: 2, FN: 0, Threshold: 0.464, Rate: 105.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 9, TP: 5, FP: 1, FN: 0, Threshold: 0.4024, Rate: 89.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 10, TP: 11, FP: 1, FN: 4, Threshold: 0.3754, Rate: 107.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 11, TP: 13, FP: 0, FN: 1, Threshold: 0.4008, Rate: 146.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 12, TP: 7, FP: 1, FN: 1, Threshold: 0.4266, Rate: 162.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 13, TP: 4, FP: 2, FN: 0, Threshold: 0.4225, Rate: 143.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 14, TP: 1, FP: 4, FN: 0, Threshold: 0.4255, Rate: 107.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 15, TP: 3, FP: 0, FN: 3, Threshold: 0.3967, Rate: 83.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 16, TP: 4, FP: 2, FN: 0, Threshold: 0.3852, Rate: 89.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 17, TP: 0, FP: 1, FN: 0, Threshold: 0.3956, Rate: 108.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 18, TP: 1, FP: 3, FN: 0, Threshold: 0.425, Rate: 103.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 19, TP: 6, FP: 0, FN: 1, Threshold: 0.4083, Rate: 98.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 20, TP: 14, FP: 0, FN: 3, Threshold: 0.3928, Rate: 115.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 21, TP: 7, FP: 0, FN: 0, Threshold: 0.427, Rate: 163.95000000000002
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 22, TP: 9, FP: 1, FN: 7, Threshold: 0.4081, Rate: 167.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 23, TP: 0, FP: 3, FN: 1, Threshold: 0.4427, Rate: 152.79999999999998
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 24, TP: 0, FP: 10, FN: 1, Threshold: 0.4096, Rate: 118.45
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 25, TP: 3, FP: 0, FN: 3, Threshold: 0.3706, Rate: 70.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 26, TP: 0, FP: 8, FN: 0, Threshold: 0.3528, Rate: 81.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 27, TP: 0, FP: 3, FN: 0, Threshold: 0.3436, Rate: 85.45
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 28, TP: 0, FP: 8, FN: 0, Threshold: 0.3673, Rate: 107.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 29, TP: 3, FP: 4, FN: 0, Threshold: 0.3987, Rate: 97.69999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 30, TP: 3, FP: 1, FN: 1, Threshold: 0.4336, Rate: 83.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 31, TP: 1, FP: 4, FN: 0, Threshold: 0.4013, Rate: 103.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 32, TP: 5, FP: 4, FN: 0, Threshold: 0.3804, Rate: 113.85000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 33, TP: 6, FP: 3, FN: 0, Threshold: 0.3878, Rate: 109.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 34, TP: 5, FP: 0, FN: 1, Threshold: 0.4246, Rate: 97.94999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 35, TP: 3, FP: 2, FN: 2, Threshold: 0.4102, Rate: 96.19999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 36, TP: 5, FP: 0, FN: 2, Threshold: 0.3912, Rate: 94.85000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 37, TP: 3, FP: 6, FN: 1, Threshold: 0.3935, Rate: 104.45
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 38, TP: 6, FP: 0, FN: 0, Threshold: 0.3784, Rate: 99.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 39, TP: 4, FP: 1, FN: 2, Threshold: 0.383, Rate: 100.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 40, TP: 2, FP: 2, FN: 1, Threshold: 0.3762, Rate: 118.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 41, TP: 0, FP: 6, FN: 0, Threshold: 0.3763, Rate: 89.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 42, TP: 0, FP: 1, FN: 0, Threshold: 0.3978, Rate: 95.10000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 43, TP: 0, FP: 0, FN: 0, Threshold: 0.3775, Rate: 147.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 44, TP: 0, FP: 1, FN: 0, Threshold: 0.4043, Rate: 188.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 45, TP: 0, FP: 2, FN: 0, Threshold: 0.5124, Rate: 159.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 46, TP: 0, FP: 0, FN: 1, Threshold: 0.6872, Rate: 111.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 0, Window: 47, TP: 2, FP: 2, FN: 0, Threshold: 0.5836, Rate: 66.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 0, TP: 7, FP: 4, FN: 3, Threshold: 0.3782, Rate: 96.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 1, TP: 6, FP: 0, FN: 1, Threshold: 0.4038, Rate: 88.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 2, TP: 3, FP: 2, FN: 0, Threshold: 0.4305, Rate: 89.55000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 3, TP: 4, FP: 0, FN: 1, Threshold: 0.3944, Rate: 92.85000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 4, TP: 7, FP: 0, FN: 2, Threshold: 0.4015, Rate: 91.64999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 5, TP: 9, FP: 0, FN: 1, Threshold: 0.4094, Rate: 110.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 6, TP: 4, FP: 6, FN: 0, Threshold: 0.3873, Rate: 113.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 7, TP: 2, FP: 2, FN: 0, Threshold: 0.4258, Rate: 90.14999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 8, TP: 3, FP: 0, FN: 0, Threshold: 0.4095, Rate: 65.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 9, TP: 5, FP: 1, FN: 0, Threshold: 0.3798, Rate: 72.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 10, TP: 9, FP: 0, FN: 6, Threshold: 0.3608, Rate: 76.14999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 11, TP: 13, FP: 0, FN: 1, Threshold: 0.3676, Rate: 106.64999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 12, TP: 7, FP: 0, FN: 1, Threshold: 0.4043, Rate: 130.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 13, TP: 4, FP: 1, FN: 0, Threshold: 0.4023, Rate: 113.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 14, TP: 1, FP: 2, FN: 0, Threshold: 0.4039, Rate: 84.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 15, TP: 3, FP: 0, FN: 3, Threshold: 0.3925, Rate: 77.85000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 16, TP: 3, FP: 4, FN: 1, Threshold: 0.3772, Rate: 79.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 17, TP: 0, FP: 4, FN: 0, Threshold: 0.3818, Rate: 86.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 18, TP: 1, FP: 2, FN: 0, Threshold: 0.3985, Rate: 65.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 19, TP: 5, FP: 0, FN: 2, Threshold: 0.3905, Rate: 46.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 20, TP: 15, FP: 0, FN: 2, Threshold: 0.379, Rate: 92.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 21, TP: 6, FP: 0, FN: 1, Threshold: 0.3946, Rate: 132.14999999999998
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 22, TP: 11, FP: 0, FN: 5, Threshold: 0.3852, Rate: 131.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 23, TP: 0, FP: 1, FN: 1, Threshold: 0.4125, Rate: 126.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 24, TP: 0, FP: 4, FN: 1, Threshold: 0.3951, Rate: 88.45
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 25, TP: 5, FP: 0, FN: 1, Threshold: 0.3668, Rate: 66.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 26, TP: 0, FP: 8, FN: 0, Threshold: 0.3581, Rate: 70.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 27, TP: 0, FP: 5, FN: 0, Threshold: 0.35, Rate: 79.14999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 28, TP: 0, FP: 3, FN: 0, Threshold: 0.3658, Rate: 78.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 29, TP: 2, FP: 2, FN: 1, Threshold: 0.3936, Rate: 67.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 30, TP: 3, FP: 0, FN: 1, Threshold: 0.431, Rate: 60.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 31, TP: 1, FP: 3, FN: 0, Threshold: 0.4168, Rate: 88.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 32, TP: 5, FP: 1, FN: 0, Threshold: 0.392, Rate: 90.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 33, TP: 5, FP: 3, FN: 1, Threshold: 0.4024, Rate: 85.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 34, TP: 3, FP: 0, FN: 3, Threshold: 0.4316, Rate: 85.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 35, TP: 3, FP: 0, FN: 2, Threshold: 0.4118, Rate: 71.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 36, TP: 6, FP: 0, FN: 1, Threshold: 0.4041, Rate: 78.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 37, TP: 3, FP: 0, FN: 1, Threshold: 0.4068, Rate: 70.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 38, TP: 6, FP: 0, FN: 0, Threshold: 0.3972, Rate: 63.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 39, TP: 4, FP: 1, FN: 2, Threshold: 0.4046, Rate: 89.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 40, TP: 2, FP: 2, FN: 1, Threshold: 0.4045, Rate: 83.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 41, TP: 0, FP: 5, FN: 0, Threshold: 0.4186, Rate: 64.94999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 42, TP: 0, FP: 2, FN: 0, Threshold: 0.4264, Rate: 69.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 43, TP: 0, FP: 0, FN: 0, Threshold: 0.3986, Rate: 110.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 44, TP: 0, FP: 0, FN: 0, Threshold: 0.4141, Rate: 116.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 45, TP: 0, FP: 0, FN: 0, Threshold: 0.5008, Rate: 105.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 46, TP: 0, FP: 0, FN: 1, Threshold: 0.6088, Rate: 79.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 1, Window: 47, TP: 2, FP: 2, FN: 0, Threshold: 0.494, Rate: 63.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 0, TP: 6, FP: 1, FN: 4, Threshold: 0.3701, Rate: 88.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 1, TP: 5, FP: 0, FN: 2, Threshold: 0.4042, Rate: 68.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 2, TP: 2, FP: 0, FN: 1, Threshold: 0.4121, Rate: 65.69999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 3, TP: 3, FP: 0, FN: 2, Threshold: 0.3795, Rate: 79.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 4, TP: 7, FP: 0, FN: 2, Threshold: 0.3978, Rate: 59.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 5, TP: 8, FP: 0, FN: 2, Threshold: 0.3945, Rate: 65.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 6, TP: 4, FP: 4, FN: 0, Threshold: 0.3608, Rate: 85.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 7, TP: 2, FP: 0, FN: 0, Threshold: 0.4014, Rate: 84.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 8, TP: 1, FP: 0, FN: 2, Threshold: 0.4126, Rate: 75.45
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 9, TP: 5, FP: 1, FN: 0, Threshold: 0.3883, Rate: 62.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 10, TP: 8, FP: 0, FN: 7, Threshold: 0.3623, Rate: 54.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 11, TP: 12, FP: 0, FN: 2, Threshold: 0.3599, Rate: 88.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 12, TP: 6, FP: 1, FN: 2, Threshold: 0.3869, Rate: 96.35000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 13, TP: 4, FP: 1, FN: 0, Threshold: 0.3969, Rate: 89.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 14, TP: 0, FP: 1, FN: 1, Threshold: 0.4023, Rate: 58.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 15, TP: 4, FP: 0, FN: 2, Threshold: 0.3797, Rate: 52.900000000000006
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 16, TP: 4, FP: 1, FN: 0, Threshold: 0.3632, Rate: 58.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 17, TP: 0, FP: 0, FN: 0, Threshold: 0.3624, Rate: 67.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 18, TP: 1, FP: 1, FN: 0, Threshold: 0.3738, Rate: 60.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 19, TP: 5, FP: 0, FN: 2, Threshold: 0.3802, Rate: 59.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 20, TP: 13, FP: 0, FN: 4, Threshold: 0.3798, Rate: 74.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 21, TP: 6, FP: 0, FN: 1, Threshold: 0.3826, Rate: 100.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 22, TP: 9, FP: 0, FN: 7, Threshold: 0.3753, Rate: 102.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 23, TP: 0, FP: 1, FN: 1, Threshold: 0.4028, Rate: 116.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 24, TP: 0, FP: 2, FN: 1, Threshold: 0.4012, Rate: 84.45
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 25, TP: 3, FP: 0, FN: 3, Threshold: 0.3813, Rate: 40.349999999999994
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 26, TP: 0, FP: 6, FN: 0, Threshold: 0.3604, Rate: 59.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 27, TP: 0, FP: 1, FN: 0, Threshold: 0.3403, Rate: 66.19999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 28, TP: 0, FP: 2, FN: 0, Threshold: 0.3468, Rate: 77.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 29, TP: 2, FP: 0, FN: 1, Threshold: 0.3729, Rate: 55.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 30, TP: 3, FP: 0, FN: 1, Threshold: 0.4136, Rate: 56.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 31, TP: 1, FP: 2, FN: 0, Threshold: 0.3997, Rate: 56.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 32, TP: 3, FP: 1, FN: 2, Threshold: 0.3827, Rate: 60.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 33, TP: 5, FP: 3, FN: 1, Threshold: 0.3835, Rate: 58.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 34, TP: 3, FP: 0, FN: 3, Threshold: 0.3999, Rate: 60.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 35, TP: 3, FP: 0, FN: 2, Threshold: 0.3881, Rate: 66.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 36, TP: 3, FP: 0, FN: 4, Threshold: 0.3804, Rate: 55.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 37, TP: 2, FP: 0, FN: 2, Threshold: 0.3781, Rate: 64.35000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 38, TP: 5, FP: 0, FN: 1, Threshold: 0.3757, Rate: 59.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 39, TP: 4, FP: 0, FN: 2, Threshold: 0.3895, Rate: 56.800000000000004
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 40, TP: 1, FP: 2, FN: 2, Threshold: 0.3785, Rate: 58.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 41, TP: 0, FP: 2, FN: 0, Threshold: 0.3867, Rate: 42.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 42, TP: 0, FP: 0, FN: 0, Threshold: 0.4069, Rate: 67.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 43, TP: 0, FP: 0, FN: 0, Threshold: 0.3746, Rate: 114.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 44, TP: 0, FP: 0, FN: 0, Threshold: 0.3904, Rate: 123.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 45, TP: 0, FP: 1, FN: 0, Threshold: 0.4999, Rate: 75.64999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 46, TP: 0, FP: 0, FN: 1, Threshold: 0.6202, Rate: 77.10000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 2, Window: 47, TP: 2, FP: 0, FN: 0, Threshold: 0.4986, Rate: 57.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 0, TP: 3, FP: 0, FN: 7, Threshold: 0.3772, Rate: 49.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 1, TP: 5, FP: 0, FN: 2, Threshold: 0.3979, Rate: 41.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 2, TP: 2, FP: 1, FN: 1, Threshold: 0.4132, Rate: 32.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 3, TP: 4, FP: 0, FN: 1, Threshold: 0.3974, Rate: 39.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 4, TP: 5, FP: 0, FN: 4, Threshold: 0.4029, Rate: 32.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 5, TP: 9, FP: 0, FN: 1, Threshold: 0.3846, Rate: 49.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 6, TP: 4, FP: 1, FN: 0, Threshold: 0.3643, Rate: 56.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 7, TP: 2, FP: 0, FN: 0, Threshold: 0.4094, Rate: 55.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 8, TP: 1, FP: 1, FN: 2, Threshold: 0.4224, Rate: 45.650000000000006
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 9, TP: 4, FP: 0, FN: 1, Threshold: 0.4003, Rate: 27.349999999999998
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 10, TP: 7, FP: 0, FN: 8, Threshold: 0.3716, Rate: 44.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 11, TP: 11, FP: 0, FN: 3, Threshold: 0.3707, Rate: 64.69999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 12, TP: 6, FP: 1, FN: 2, Threshold: 0.4022, Rate: 72.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 13, TP: 4, FP: 1, FN: 0, Threshold: 0.398, Rate: 54.949999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 14, TP: 1, FP: 1, FN: 0, Threshold: 0.3918, Rate: 44.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 15, TP: 4, FP: 0, FN: 2, Threshold: 0.3894, Rate: 34.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 16, TP: 4, FP: 1, FN: 0, Threshold: 0.3738, Rate: 13.45
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 17, TP: 0, FP: 2, FN: 0, Threshold: 0.3701, Rate: 35.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 18, TP: 1, FP: 1, FN: 0, Threshold: 0.3717, Rate: 35.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 19, TP: 5, FP: 0, FN: 2, Threshold: 0.3736, Rate: 18.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 20, TP: 8, FP: 0, FN: 9, Threshold: 0.3816, Rate: 29.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 21, TP: 5, FP: 0, FN: 2, Threshold: 0.371, Rate: 62.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 22, TP: 7, FP: 0, FN: 9, Threshold: 0.3656, Rate: 59.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 23, TP: 0, FP: 1, FN: 1, Threshold: 0.4107, Rate: 70.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 24, TP: 0, FP: 3, FN: 1, Threshold: 0.4037, Rate: 53.150000000000006
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 25, TP: 4, FP: 0, FN: 2, Threshold: 0.3874, Rate: 25.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 26, TP: 0, FP: 6, FN: 0, Threshold: 0.3579, Rate: 40.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 27, TP: 0, FP: 3, FN: 0, Threshold: 0.3461, Rate: 22.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 28, TP: 0, FP: 3, FN: 0, Threshold: 0.3527, Rate: 39.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 29, TP: 2, FP: 1, FN: 1, Threshold: 0.375, Rate: 17.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 30, TP: 3, FP: 0, FN: 1, Threshold: 0.4127, Rate: 34.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 31, TP: 0, FP: 2, FN: 1, Threshold: 0.4062, Rate: 47.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 32, TP: 4, FP: 4, FN: 1, Threshold: 0.395, Rate: 52.449999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 33, TP: 5, FP: 3, FN: 1, Threshold: 0.4068, Rate: 36.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 34, TP: 3, FP: 0, FN: 3, Threshold: 0.4118, Rate: 40.300000000000004
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 35, TP: 2, FP: 0, FN: 3, Threshold: 0.393, Rate: 27.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 36, TP: 3, FP: 0, FN: 4, Threshold: 0.3941, Rate: 37.699999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 37, TP: 1, FP: 0, FN: 3, Threshold: 0.3923, Rate: 49.099999999999994
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 38, TP: 2, FP: 0, FN: 4, Threshold: 0.3844, Rate: 20.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 39, TP: 2, FP: 0, FN: 4, Threshold: 0.3947, Rate: 41.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 40, TP: 1, FP: 3, FN: 2, Threshold: 0.4031, Rate: 56.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 41, TP: 0, FP: 3, FN: 0, Threshold: 0.4126, Rate: 47.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 42, TP: 0, FP: 0, FN: 0, Threshold: 0.4193, Rate: 24.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 43, TP: 0, FP: 0, FN: 0, Threshold: 0.3955, Rate: 73.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 44, TP: 0, FP: 0, FN: 0, Threshold: 0.411, Rate: 87.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 45, TP: 0, FP: 0, FN: 0, Threshold: 0.5086, Rate: 63.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 46, TP: 0, FP: 0, FN: 1, Threshold: 0.6142, Rate: 42.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 3, Window: 47, TP: 1, FP: 0, FN: 1, Threshold: 0.4936, Rate: 22.450000000000003
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 0, TP: 2, FP: 1, FN: 8, Threshold: 0.3397, Rate: 72.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 1, TP: 2, FP: 0, FN: 5, Threshold: 0.3692, Rate: 51.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 2, TP: 2, FP: 0, FN: 1, Threshold: 0.3776, Rate: 73.89999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 3, TP: 2, FP: 0, FN: 3, Threshold: 0.3516, Rate: 71.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 4, TP: 3, FP: 0, FN: 6, Threshold: 0.3553, Rate: 41.050000000000004
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 5, TP: 7, FP: 0, FN: 3, Threshold: 0.3433, Rate: 66.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 6, TP: 4, FP: 1, FN: 0, Threshold: 0.3248, Rate: 85.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 7, TP: 2, FP: 0, FN: 0, Threshold: 0.3701, Rate: 85.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 8, TP: 1, FP: 0, FN: 2, Threshold: 0.389, Rate: 67.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 9, TP: 3, FP: 0, FN: 2, Threshold: 0.3735, Rate: 27.650000000000002
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 10, TP: 6, FP: 1, FN: 9, Threshold: 0.3403, Rate: 34.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 11, TP: 11, FP: 0, FN: 3, Threshold: 0.3369, Rate: 63.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 12, TP: 5, FP: 0, FN: 3, Threshold: 0.3747, Rate: 91.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 13, TP: 4, FP: 0, FN: 0, Threshold: 0.3766, Rate: 69.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 14, TP: 0, FP: 1, FN: 1, Threshold: 0.3702, Rate: 59.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 15, TP: 4, FP: 0, FN: 2, Threshold: 0.3536, Rate: 60.699999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 16, TP: 3, FP: 0, FN: 1, Threshold: 0.3414, Rate: 52.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 17, TP: 0, FP: 0, FN: 0, Threshold: 0.3392, Rate: 56.849999999999994
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 18, TP: 1, FP: 1, FN: 0, Threshold: 0.3391, Rate: 35.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 19, TP: 5, FP: 0, FN: 2, Threshold: 0.3428, Rate: 44.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 20, TP: 8, FP: 0, FN: 9, Threshold: 0.3451, Rate: 53.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 21, TP: 3, FP: 0, FN: 4, Threshold: 0.3428, Rate: 82.60000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 22, TP: 6, FP: 0, FN: 10, Threshold: 0.3429, Rate: 83.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 23, TP: 1, FP: 0, FN: 0, Threshold: 0.3747, Rate: 81.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 24, TP: 0, FP: 1, FN: 1, Threshold: 0.379, Rate: 79.60000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 25, TP: 1, FP: 0, FN: 5, Threshold: 0.3661, Rate: 44.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 26, TP: 0, FP: 4, FN: 0, Threshold: 0.3254, Rate: 56.550000000000004
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 27, TP: 0, FP: 0, FN: 0, Threshold: 0.3052, Rate: 49.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 28, TP: 0, FP: 2, FN: 0, Threshold: 0.3197, Rate: 59.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 29, TP: 1, FP: 0, FN: 2, Threshold: 0.3401, Rate: 66.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 30, TP: 2, FP: 1, FN: 2, Threshold: 0.3686, Rate: 22.599999999999998
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 31, TP: 0, FP: 0, FN: 1, Threshold: 0.3681, Rate: 66.19999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 32, TP: 4, FP: 1, FN: 1, Threshold: 0.3662, Rate: 75.39999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 33, TP: 4, FP: 1, FN: 2, Threshold: 0.3692, Rate: 50.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 34, TP: 0, FP: 0, FN: 6, Threshold: 0.3728, Rate: 58.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 35, TP: 2, FP: 0, FN: 3, Threshold: 0.3578, Rate: 75.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 36, TP: 3, FP: 0, FN: 4, Threshold: 0.3637, Rate: 59.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 37, TP: 1, FP: 0, FN: 3, Threshold: 0.361, Rate: 49.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 38, TP: 3, FP: 0, FN: 3, Threshold: 0.3633, Rate: 48.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 39, TP: 2, FP: 0, FN: 4, Threshold: 0.373, Rate: 57.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 40, TP: 0, FP: 1, FN: 3, Threshold: 0.3572, Rate: 78.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 41, TP: 0, FP: 1, FN: 0, Threshold: 0.3698, Rate: 66.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 42, TP: 0, FP: 1, FN: 0, Threshold: 0.3918, Rate: 53.449999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 43, TP: 0, FP: 0, FN: 0, Threshold: 0.3568, Rate: 108.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 44, TP: 0, FP: 0, FN: 0, Threshold: 0.3598, Rate: 125.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 45, TP: 0, FP: 0, FN: 0, Threshold: 0.4536, Rate: 79.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 46, TP: 0, FP: 0, FN: 1, Threshold: 0.557, Rate: 73.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 4, Window: 47, TP: 2, FP: 0, FN: 0, Threshold: 0.46, Rate: 64.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 0, TP: 3, FP: 0, FN: 7, Threshold: 0.3403, Rate: 66.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 1, TP: 2, FP: 0, FN: 5, Threshold: 0.3623, Rate: 50.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 2, TP: 1, FP: 0, FN: 2, Threshold: 0.3786, Rate: 64.94999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 3, TP: 3, FP: 0, FN: 2, Threshold: 0.3644, Rate: 39.800000000000004
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 4, TP: 5, FP: 0, FN: 4, Threshold: 0.3637, Rate: 42.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 5, TP: 7, FP: 0, FN: 3, Threshold: 0.3584, Rate: 36.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 6, TP: 3, FP: 1, FN: 1, Threshold: 0.3393, Rate: 49.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 7, TP: 1, FP: 0, FN: 1, Threshold: 0.3565, Rate: 56.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 8, TP: 0, FP: 0, FN: 3, Threshold: 0.3688, Rate: 55.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 9, TP: 3, FP: 0, FN: 2, Threshold: 0.3684, Rate: 18.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 10, TP: 4, FP: 0, FN: 11, Threshold: 0.3431, Rate: 54.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 11, TP: 9, FP: 0, FN: 5, Threshold: 0.3401, Rate: 61.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 12, TP: 4, FP: 0, FN: 4, Threshold: 0.3713, Rate: 76.64999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 13, TP: 3, FP: 0, FN: 1, Threshold: 0.367, Rate: 49.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 14, TP: 0, FP: 1, FN: 1, Threshold: 0.3588, Rate: 28.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 15, TP: 3, FP: 0, FN: 3, Threshold: 0.3517, Rate: 44.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 16, TP: 2, FP: 1, FN: 2, Threshold: 0.3393, Rate: 26.200000000000003
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 17, TP: 0, FP: 0, FN: 0, Threshold: 0.3383, Rate: 44.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 18, TP: 1, FP: 0, FN: 0, Threshold: 0.3432, Rate: 40.300000000000004
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 19, TP: 5, FP: 1, FN: 2, Threshold: 0.3415, Rate: 27.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 20, TP: 6, FP: 0, FN: 11, Threshold: 0.3466, Rate: 31.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 21, TP: 2, FP: 0, FN: 5, Threshold: 0.3439, Rate: 57.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 22, TP: 4, FP: 0, FN: 12, Threshold: 0.3392, Rate: 54.199999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 23, TP: 0, FP: 0, FN: 1, Threshold: 0.3694, Rate: 65.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 24, TP: 1, FP: 0, FN: 0, Threshold: 0.3668, Rate: 60.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 25, TP: 2, FP: 0, FN: 4, Threshold: 0.3577, Rate: 33.349999999999994
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 26, TP: 0, FP: 6, FN: 0, Threshold: 0.3313, Rate: 37.650000000000006
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 27, TP: 0, FP: 1, FN: 0, Threshold: 0.3188, Rate: 18.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 28, TP: 0, FP: 3, FN: 0, Threshold: 0.322, Rate: 44.699999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 29, TP: 0, FP: 0, FN: 3, Threshold: 0.3388, Rate: 13.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 30, TP: 3, FP: 1, FN: 1, Threshold: 0.374, Rate: 21.45
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 31, TP: 0, FP: 2, FN: 1, Threshold: 0.3661, Rate: 51.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 32, TP: 3, FP: 2, FN: 2, Threshold: 0.3574, Rate: 51.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 33, TP: 4, FP: 0, FN: 2, Threshold: 0.3643, Rate: 42.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 34, TP: 2, FP: 0, FN: 4, Threshold: 0.3644, Rate: 60.650000000000006
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 35, TP: 1, FP: 0, FN: 4, Threshold: 0.3583, Rate: 50.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 36, TP: 3, FP: 0, FN: 4, Threshold: 0.3711, Rate: 37.449999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 37, TP: 1, FP: 0, FN: 3, Threshold: 0.3683, Rate: 47.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 38, TP: 2, FP: 0, FN: 4, Threshold: 0.3529, Rate: 49.2
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 39, TP: 0, FP: 0, FN: 6, Threshold: 0.3525, Rate: 48.550000000000004
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 40, TP: 0, FP: 2, FN: 3, Threshold: 0.3511, Rate: 61.699999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 41, TP: 0, FP: 4, FN: 0, Threshold: 0.3588, Rate: 46.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 42, TP: 0, FP: 1, FN: 0, Threshold: 0.377, Rate: 53.150000000000006
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 43, TP: 0, FP: 0, FN: 0, Threshold: 0.3633, Rate: 78.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 44, TP: 0, FP: 0, FN: 0, Threshold: 0.3687, Rate: 116.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 45, TP: 0, FP: 0, FN: 0, Threshold: 0.4443, Rate: 62.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 46, TP: 0, FP: 0, FN: 1, Threshold: 0.5668, Rate: 63.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 5, Window: 47, TP: 1, FP: 1, FN: 1, Threshold: 0.4631, Rate: 48.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 0, TP: 1, FP: 0, FN: 9, Threshold: 0.3047, Rate: 77.10000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 1, TP: 3, FP: 0, FN: 4, Threshold: 0.3302, Rate: 64.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 2, TP: 1, FP: 0, FN: 2, Threshold: 0.3404, Rate: 70.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 3, TP: 1, FP: 0, FN: 4, Threshold: 0.3218, Rate: 42.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 4, TP: 1, FP: 0, FN: 8, Threshold: 0.3254, Rate: 40.849999999999994
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 5, TP: 6, FP: 0, FN: 4, Threshold: 0.3103, Rate: 57.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 6, TP: 3, FP: 3, FN: 1, Threshold: 0.3025, Rate: 64.44999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 7, TP: 0, FP: 0, FN: 2, Threshold: 0.3295, Rate: 58.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 8, TP: 2, FP: 0, FN: 1, Threshold: 0.3419, Rate: 50.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 9, TP: 0, FP: 0, FN: 5, Threshold: 0.3297, Rate: 35.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 10, TP: 3, FP: 0, FN: 12, Threshold: 0.3072, Rate: 60.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 11, TP: 8, FP: 0, FN: 6, Threshold: 0.309, Rate: 69.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 12, TP: 3, FP: 0, FN: 5, Threshold: 0.3353, Rate: 87.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 13, TP: 3, FP: 0, FN: 1, Threshold: 0.3401, Rate: 67.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 14, TP: 0, FP: 1, FN: 1, Threshold: 0.3329, Rate: 46.199999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 15, TP: 3, FP: 0, FN: 3, Threshold: 0.324, Rate: 42.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 16, TP: 2, FP: 1, FN: 2, Threshold: 0.3072, Rate: 16.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 17, TP: 0, FP: 1, FN: 0, Threshold: 0.3068, Rate: 60.949999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 18, TP: 0, FP: 0, FN: 1, Threshold: 0.3077, Rate: 17.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 19, TP: 3, FP: 0, FN: 4, Threshold: 0.3104, Rate: 45.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 20, TP: 5, FP: 0, FN: 12, Threshold: 0.3187, Rate: 44.35
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 21, TP: 2, FP: 0, FN: 5, Threshold: 0.3163, Rate: 83.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 22, TP: 4, FP: 0, FN: 12, Threshold: 0.3084, Rate: 73.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 23, TP: 1, FP: 0, FN: 0, Threshold: 0.3298, Rate: 92.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 24, TP: 1, FP: 0, FN: 0, Threshold: 0.3309, Rate: 78.10000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 25, TP: 1, FP: 0, FN: 5, Threshold: 0.3262, Rate: 45.199999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 26, TP: 0, FP: 3, FN: 0, Threshold: 0.2953, Rate: 43.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 27, TP: 0, FP: 0, FN: 0, Threshold: 0.2792, Rate: 45.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 28, TP: 0, FP: 0, FN: 0, Threshold: 0.2937, Rate: 52.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 29, TP: 0, FP: 0, FN: 3, Threshold: 0.3118, Rate: 62.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 30, TP: 2, FP: 1, FN: 2, Threshold: 0.3353, Rate: 36.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 31, TP: 0, FP: 1, FN: 1, Threshold: 0.3324, Rate: 58.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 32, TP: 3, FP: 1, FN: 2, Threshold: 0.3259, Rate: 60.900000000000006
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 33, TP: 3, FP: 0, FN: 3, Threshold: 0.3303, Rate: 47.849999999999994
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 34, TP: 1, FP: 0, FN: 5, Threshold: 0.338, Rate: 46.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 35, TP: 0, FP: 0, FN: 5, Threshold: 0.3294, Rate: 66.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 36, TP: 1, FP: 0, FN: 6, Threshold: 0.3433, Rate: 47.050000000000004
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 37, TP: 1, FP: 0, FN: 3, Threshold: 0.3458, Rate: 51.6
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 38, TP: 3, FP: 0, FN: 3, Threshold: 0.3261, Rate: 57.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 39, TP: 1, FP: 0, FN: 5, Threshold: 0.3221, Rate: 34.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 40, TP: 0, FP: 1, FN: 3, Threshold: 0.319, Rate: 67.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 41, TP: 0, FP: 2, FN: 0, Threshold: 0.3274, Rate: 62.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 42, TP: 0, FP: 1, FN: 0, Threshold: 0.3521, Rate: 70.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 43, TP: 0, FP: 0, FN: 0, Threshold: 0.3303, Rate: 89.39999999999999
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 44, TP: 0, FP: 0, FN: 0, Threshold: 0.3319, Rate: 127.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 45, TP: 0, FP: 0, FN: 0, Threshold: 0.407, Rate: 94.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 46, TP: 0, FP: 0, FN: 1, Threshold: 0.5097, Rate: 69.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 6, Window: 47, TP: 1, FP: 0, FN: 1, Threshold: 0.4197, Rate: 59.05
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 0, TP: 3, FP: 0, FN: 7, Threshold: 0.2947, Rate: 74.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 1, TP: 3, FP: 0, FN: 4, Threshold: 0.3178, Rate: 36.949999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 2, TP: 1, FP: 0, FN: 2, Threshold: 0.3305, Rate: 73.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 3, TP: 1, FP: 0, FN: 4, Threshold: 0.314, Rate: 55.75
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 4, TP: 1, FP: 0, FN: 8, Threshold: 0.3178, Rate: 52.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 5, TP: 5, FP: 0, FN: 5, Threshold: 0.3027, Rate: 62.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 6, TP: 4, FP: 1, FN: 0, Threshold: 0.2909, Rate: 67.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 7, TP: 1, FP: 0, FN: 1, Threshold: 0.3113, Rate: 68.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 8, TP: 0, FP: 0, FN: 3, Threshold: 0.3173, Rate: 58.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 9, TP: 1, FP: 0, FN: 4, Threshold: 0.3129, Rate: 37.85
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 10, TP: 2, FP: 0, FN: 13, Threshold: 0.2944, Rate: 49.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 11, TP: 9, FP: 0, FN: 5, Threshold: 0.2894, Rate: 76.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 12, TP: 3, FP: 0, FN: 5, Threshold: 0.3189, Rate: 95.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 13, TP: 1, FP: 0, FN: 3, Threshold: 0.3269, Rate: 74.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 14, TP: 0, FP: 1, FN: 1, Threshold: 0.3332, Rate: 41.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 15, TP: 1, FP: 0, FN: 5, Threshold: 0.3175, Rate: 52.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 16, TP: 1, FP: 0, FN: 3, Threshold: 0.299, Rate: 39.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 17, TP: 0, FP: 0, FN: 0, Threshold: 0.2967, Rate: 60.949999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 18, TP: 0, FP: 0, FN: 1, Threshold: 0.2962, Rate: 31.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 19, TP: 2, FP: 0, FN: 5, Threshold: 0.3001, Rate: 42.55
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 20, TP: 2, FP: 0, FN: 15, Threshold: 0.2995, Rate: 38.25
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 21, TP: 1, FP: 0, FN: 6, Threshold: 0.2927, Rate: 74.05000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 22, TP: 5, FP: 0, FN: 11, Threshold: 0.2952, Rate: 79.60000000000001
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 23, TP: 1, FP: 0, FN: 0, Threshold: 0.3255, Rate: 92.8
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 24, TP: 1, FP: 2, FN: 0, Threshold: 0.3253, Rate: 82.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 25, TP: 1, FP: 0, FN: 5, Threshold: 0.3194, Rate: 43.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 26, TP: 0, FP: 5, FN: 0, Threshold: 0.286, Rate: 44.0
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 27, TP: 0, FP: 2, FN: 0, Threshold: 0.2692, Rate: 48.599999999999994
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 28, TP: 0, FP: 1, FN: 0, Threshold: 0.28, Rate: 56.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 29, TP: 0, FP: 0, FN: 3, Threshold: 0.2979, Rate: 38.449999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 30, TP: 1, FP: 3, FN: 3, Threshold: 0.3195, Rate: 46.699999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 31, TP: 0, FP: 1, FN: 1, Threshold: 0.316, Rate: 26.849999999999998
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 32, TP: 3, FP: 0, FN: 2, Threshold: 0.3098, Rate: 53.199999999999996
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 33, TP: 3, FP: 0, FN: 3, Threshold: 0.313, Rate: 35.4
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 34, TP: 0, FP: 0, FN: 6, Threshold: 0.3207, Rate: 63.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 35, TP: 1, FP: 0, FN: 4, Threshold: 0.3135, Rate: 51.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 36, TP: 1, FP: 1, FN: 6, Threshold: 0.3199, Rate: 41.7
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 37, TP: 0, FP: 0, FN: 4, Threshold: 0.3246, Rate: 30.849999999999998
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 38, TP: 3, FP: 0, FN: 3, Threshold: 0.3157, Rate: 45.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 39, TP: 1, FP: 0, FN: 5, Threshold: 0.309, Rate: 49.9
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 40, TP: 0, FP: 0, FN: 3, Threshold: 0.3009, Rate: 68.15
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 41, TP: 0, FP: 1, FN: 0, Threshold: 0.3076, Rate: 60.5
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 42, TP: 0, FP: 2, FN: 0, Threshold: 0.3284, Rate: 62.95
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 43, TP: 0, FP: 0, FN: 0, Threshold: 0.3065, Rate: 100.1
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 44, TP: 0, FP: 0, FN: 0, Threshold: 0.3109, Rate: 129.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 45, TP: 0, FP: 2, FN: 0, Threshold: 0.3868, Rate: 100.65
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 46, TP: 0, FP: 0, FN: 1, Threshold: 0.4985, Rate: 64.3
# Dataset: Amigo2_2019-07-11_11-57-07, Channel: 7, Window: 47, TP: 0, FP: 1, FN: 2, Threshold: 0.4015, Rate: 60.55
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 0, TP: 1, FP: 0, FN: 1, Threshold: 0.3537, Rate: 46.0
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 1, TP: 2, FP: 0, FN: 1, Threshold: 0.3755, Rate: 21.15
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 2, TP: 1, FP: 0, FN: 1, Threshold: 0.343, Rate: 38.699999999999996
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 3, TP: 0, FP: 1, FN: 1, Threshold: 0.3313, Rate: 43.1
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 4, TP: 2, FP: 0, FN: 0, Threshold: 0.3391, Rate: 34.5
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 5, TP: 3, FP: 0, FN: 2, Threshold: 0.3341, Rate: 25.05
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 6, TP: 2, FP: 1, FN: 1, Threshold: 0.3245, Rate: 23.2
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 7, TP: 2, FP: 0, FN: 0, Threshold: 0.3187, Rate: 32.25
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 8, TP: 3, FP: 0, FN: 0, Threshold: 0.333, Rate: 38.0
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 9, TP: 0, FP: 1, FN: 1, Threshold: 0.3436, Rate: 34.4
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 10, TP: 1, FP: 1, FN: 1, Threshold: 0.3366, Rate: 39.15
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 11, TP: 4, FP: 0, FN: 0, Threshold: 0.3408, Rate: 37.5
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 12, TP: 0, FP: 2, FN: 0, Threshold: 0.3311, Rate: 23.150000000000002
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 13, TP: 0, FP: 0, FN: 0, Threshold: 0.3328, Rate: 71.0
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 14, TP: 0, FP: 0, FN: 0, Threshold: 0.3371, Rate: 98.55
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 15, TP: 0, FP: 0, FN: 0, Threshold: 0.3749, Rate: 96.44999999999999
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 16, TP: 0, FP: 0, FN: 0, Threshold: 0.5365, Rate: 85.85
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 17, TP: 0, FP: 1, FN: 0, Threshold: 0.4957, Rate: 62.300000000000004
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 18, TP: 0, FP: 0, FN: 0, Threshold: 0.4733, Rate: 64.05
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 19, TP: 1, FP: 0, FN: 1, Threshold: 0.4362, Rate: 57.15
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 0, Window: 20, TP: 0, FP: 1, FN: 0, Threshold: 0.4262, Rate: 47.7
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 0, TP: 1, FP: 2, FN: 1, Threshold: 0.4086, Rate: 30.099999999999998
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 1, TP: 2, FP: 0, FN: 1, Threshold: 0.4272, Rate: 49.0
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 2, TP: 1, FP: 0, FN: 1, Threshold: 0.3842, Rate: 28.85
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 3, TP: 0, FP: 1, FN: 1, Threshold: 0.365, Rate: 33.75
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 4, TP: 2, FP: 0, FN: 0, Threshold: 0.38, Rate: 30.8
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 5, TP: 4, FP: 0, FN: 1, Threshold: 0.3942, Rate: 34.55
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 6, TP: 3, FP: 0, FN: 0, Threshold: 0.3886, Rate: 42.7
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 7, TP: 2, FP: 0, FN: 0, Threshold: 0.3705, Rate: 35.0
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 8, TP: 3, FP: 0, FN: 0, Threshold: 0.3739, Rate: 36.75
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 9, TP: 1, FP: 1, FN: 0, Threshold: 0.3834, Rate: 45.6
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 10, TP: 1, FP: 1, FN: 1, Threshold: 0.3893, Rate: 37.1
# Dataset: Dlx1_2021-02-12_12-46-54, Channel: 1, Window: 11, TP: 4, FP: 1, FN: 0, Threshold: 0.3981, Rate: 34.95
# ...
# Dataset: Som2_2019-07-24_12-01-49, Channel: 6, Window: 20, TP: 0, FP: 0, FN: 0, Threshold: 0.3835, Rate: 100.6
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 0, TP: 6, FP: 0, FN: 5, Threshold: 0.326, Rate: 77.39999999999999
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 1, TP: 3, FP: 0, FN: 9, Threshold: 0.3139, Rate: 66.4
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 2, TP: 8, FP: 0, FN: 4, Threshold: 0.3227, Rate: 51.6
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 3, TP: 2, FP: 0, FN: 0, Threshold: 0.3136, Rate: 35.05
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 4, TP: 3, FP: 0, FN: 1, Threshold: 0.3099, Rate: 53.650000000000006
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 5, TP: 5, FP: 0, FN: 0, Threshold: 0.3139, Rate: 54.25
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 6, TP: 2, FP: 0, FN: 2, Threshold: 0.315, Rate: 52.55
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 7, TP: 0, FP: 2, FN: 0, Threshold: 0.3094, Rate: 43.9
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 8, TP: 0, FP: 1, FN: 0, Threshold: 0.3096, Rate: 70.15
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 9, TP: 2, FP: 0, FN: 2, Threshold: 0.3075, Rate: 58.4
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 10, TP: 3, FP: 0, FN: 0, Threshold: 0.3224, Rate: 77.2
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 11, TP: 0, FP: 0, FN: 1, Threshold: 0.3626, Rate: 66.15
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 12, TP: 0, FP: 0, FN: 0, Threshold: 0.3373, Rate: 52.400000000000006
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 13, TP: 2, FP: 0, FN: 0, Threshold: 0.3277, Rate: 44.15
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 14, TP: 0, FP: 3, FN: 0, Threshold: 0.3317, Rate: 72.2
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 15, TP: 0, FP: 0, FN: 0, Threshold: 0.3198, Rate: 111.25
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 16, TP: 3, FP: 0, FN: 1, Threshold: 0.3331, Rate: 110.85000000000001
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 17, TP: 0, FP: 0, FN: 1, Threshold: 0.3846, Rate: 68.8
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 18, TP: 0, FP: 0, FN: 0, Threshold: 0.4106, Rate: 44.55
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 19, TP: 0, FP: 1, FN: 0, Threshold: 0.3764, Rate: 108.64999999999999
# Dataset: Som2_2019-07-24_12-01-49, Channel: 7, Window: 20, TP: 0, FP: 0, FN: 0, Threshold: 0.3599, Rate: 75.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 0, TP: 2, FP: 0, FN: 0, Threshold: 0.3465, Rate: 67.45
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 1, TP: 5, FP: 0, FN: 3, Threshold: 0.3346, Rate: 56.15
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 2, TP: 1, FP: 1, FN: 0, Threshold: 0.3471, Rate: 71.65
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 3, TP: 0, FP: 1, FN: 4, Threshold: 0.3419, Rate: 63.35
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 4, TP: 2, FP: 1, FN: 0, Threshold: 0.3596, Rate: 64.10000000000001
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 5, TP: 11, FP: 0, FN: 6, Threshold: 0.3754, Rate: 60.650000000000006
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 6, TP: 6, FP: 0, FN: 1, Threshold: 0.3507, Rate: 49.4
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 7, TP: 16, FP: 0, FN: 2, Threshold: 0.3437, Rate: 67.2
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 8, TP: 11, FP: 0, FN: 2, Threshold: 0.3409, Rate: 76.2
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 9, TP: 4, FP: 0, FN: 2, Threshold: 0.3344, Rate: 60.199999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 10, TP: 8, FP: 1, FN: 2, Threshold: 0.3176, Rate: 44.4
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 11, TP: 10, FP: 0, FN: 5, Threshold: 0.3176, Rate: 58.55
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 12, TP: 8, FP: 0, FN: 6, Threshold: 0.3301, Rate: 69.25
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 13, TP: 10, FP: 0, FN: 4, Threshold: 0.3313, Rate: 85.7
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 0, Window: 14, TP: 5, FP: 0, FN: 4, Threshold: 0.3301, Rate: 75.05000000000001
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 0, TP: 2, FP: 0, FN: 0, Threshold: 0.3171, Rate: 51.0
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 1, TP: 4, FP: 0, FN: 4, Threshold: 0.3082, Rate: 31.2
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 2, TP: 1, FP: 1, FN: 0, Threshold: 0.3194, Rate: 49.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 3, TP: 0, FP: 0, FN: 4, Threshold: 0.3139, Rate: 44.15
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 4, TP: 2, FP: 3, FN: 0, Threshold: 0.3259, Rate: 57.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 5, TP: 10, FP: 0, FN: 7, Threshold: 0.3393, Rate: 49.7
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 6, TP: 6, FP: 0, FN: 1, Threshold: 0.3233, Rate: 38.1
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 7, TP: 14, FP: 0, FN: 4, Threshold: 0.3225, Rate: 47.199999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 8, TP: 11, FP: 0, FN: 2, Threshold: 0.3286, Rate: 57.1
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 9, TP: 4, FP: 0, FN: 2, Threshold: 0.3253, Rate: 42.0
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 10, TP: 5, FP: 1, FN: 5, Threshold: 0.3015, Rate: 61.3
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 11, TP: 11, FP: 0, FN: 4, Threshold: 0.2969, Rate: 56.7
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 12, TP: 9, FP: 0, FN: 5, Threshold: 0.3126, Rate: 73.1
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 13, TP: 11, FP: 0, FN: 3, Threshold: 0.3172, Rate: 72.55
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 1, Window: 14, TP: 7, FP: 0, FN: 2, Threshold: 0.3144, Rate: 65.9
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 0, TP: 1, FP: 0, FN: 1, Threshold: 0.3474, Rate: 53.199999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 1, TP: 5, FP: 0, FN: 3, Threshold: 0.3383, Rate: 44.699999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 2, TP: 1, FP: 1, FN: 0, Threshold: 0.347, Rate: 59.2
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 3, TP: 0, FP: 0, FN: 4, Threshold: 0.3452, Rate: 58.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 4, TP: 2, FP: 1, FN: 0, Threshold: 0.3639, Rate: 64.05
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 5, TP: 12, FP: 0, FN: 5, Threshold: 0.3801, Rate: 60.8
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 6, TP: 6, FP: 0, FN: 1, Threshold: 0.362, Rate: 44.0
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 7, TP: 14, FP: 0, FN: 4, Threshold: 0.3535, Rate: 60.8
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 8, TP: 10, FP: 0, FN: 3, Threshold: 0.3548, Rate: 71.1
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 9, TP: 5, FP: 0, FN: 1, Threshold: 0.3477, Rate: 46.6
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 10, TP: 7, FP: 0, FN: 3, Threshold: 0.3197, Rate: 48.95
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 11, TP: 10, FP: 0, FN: 5, Threshold: 0.3226, Rate: 61.6
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 12, TP: 7, FP: 0, FN: 7, Threshold: 0.3447, Rate: 72.35
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 13, TP: 10, FP: 0, FN: 4, Threshold: 0.3468, Rate: 73.85
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 2, Window: 14, TP: 7, FP: 0, FN: 2, Threshold: 0.3458, Rate: 66.3
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 0, TP: 0, FP: 0, FN: 2, Threshold: 0.313, Rate: 36.85
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 1, TP: 6, FP: 0, FN: 2, Threshold: 0.3116, Rate: 23.95
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 2, TP: 1, FP: 1, FN: 0, Threshold: 0.3144, Rate: 52.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 3, TP: 0, FP: 0, FN: 4, Threshold: 0.3059, Rate: 54.35
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 4, TP: 2, FP: 1, FN: 0, Threshold: 0.3232, Rate: 40.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 5, TP: 9, FP: 0, FN: 8, Threshold: 0.3387, Rate: 40.050000000000004
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 6, TP: 6, FP: 0, FN: 1, Threshold: 0.3252, Rate: 34.3
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 7, TP: 10, FP: 0, FN: 8, Threshold: 0.3196, Rate: 60.75
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 8, TP: 7, FP: 0, FN: 6, Threshold: 0.323, Rate: 46.4
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 9, TP: 3, FP: 0, FN: 3, Threshold: 0.3316, Rate: 39.199999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 10, TP: 5, FP: 1, FN: 5, Threshold: 0.314, Rate: 34.35
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 11, TP: 8, FP: 0, FN: 7, Threshold: 0.3047, Rate: 34.55
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 12, TP: 6, FP: 0, FN: 8, Threshold: 0.3125, Rate: 51.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 13, TP: 8, FP: 0, FN: 6, Threshold: 0.3185, Rate: 51.3
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 3, Window: 14, TP: 6, FP: 0, FN: 3, Threshold: 0.3198, Rate: 42.05
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 0, TP: 0, FP: 0, FN: 2, Threshold: 0.3054, Rate: 29.8
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 1, TP: 5, FP: 0, FN: 3, Threshold: 0.3102, Rate: 36.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 2, TP: 1, FP: 1, FN: 0, Threshold: 0.3201, Rate: 49.6
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 3, TP: 0, FP: 0, FN: 4, Threshold: 0.317, Rate: 50.1
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 4, TP: 2, FP: 0, FN: 0, Threshold: 0.3292, Rate: 30.900000000000002
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 5, TP: 10, FP: 0, FN: 7, Threshold: 0.3423, Rate: 37.8
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 6, TP: 4, FP: 0, FN: 3, Threshold: 0.3309, Rate: 33.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 7, TP: 9, FP: 0, FN: 9, Threshold: 0.3257, Rate: 55.849999999999994
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 8, TP: 7, FP: 0, FN: 6, Threshold: 0.3268, Rate: 62.65
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 9, TP: 3, FP: 0, FN: 3, Threshold: 0.3201, Rate: 48.0
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 10, TP: 6, FP: 0, FN: 4, Threshold: 0.3043, Rate: 46.199999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 11, TP: 8, FP: 0, FN: 7, Threshold: 0.3038, Rate: 40.4
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 12, TP: 5, FP: 0, FN: 9, Threshold: 0.3172, Rate: 56.300000000000004
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 13, TP: 8, FP: 0, FN: 6, Threshold: 0.3214, Rate: 60.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 4, Window: 14, TP: 5, FP: 0, FN: 4, Threshold: 0.3243, Rate: 51.2
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 0, TP: 0, FP: 0, FN: 2, Threshold: 0.2873, Rate: 34.45
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 1, TP: 3, FP: 0, FN: 5, Threshold: 0.2883, Rate: 24.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 2, TP: 1, FP: 1, FN: 0, Threshold: 0.2943, Rate: 47.849999999999994
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 3, TP: 0, FP: 0, FN: 4, Threshold: 0.2882, Rate: 39.699999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 4, TP: 2, FP: 0, FN: 0, Threshold: 0.3023, Rate: 12.05
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 5, TP: 6, FP: 0, FN: 11, Threshold: 0.3066, Rate: 14.9
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 6, TP: 3, FP: 0, FN: 4, Threshold: 0.2997, Rate: 35.45
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 7, TP: 9, FP: 0, FN: 9, Threshold: 0.3019, Rate: 52.85
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 8, TP: 7, FP: 0, FN: 6, Threshold: 0.2981, Rate: 51.0
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 9, TP: 3, FP: 0, FN: 3, Threshold: 0.2973, Rate: 34.85
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 10, TP: 3, FP: 0, FN: 7, Threshold: 0.2848, Rate: 38.199999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 11, TP: 7, FP: 0, FN: 8, Threshold: 0.2835, Rate: 22.75
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 12, TP: 3, FP: 0, FN: 11, Threshold: 0.2911, Rate: 50.2
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 13, TP: 3, FP: 0, FN: 11, Threshold: 0.2943, Rate: 65.9
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 5, Window: 14, TP: 4, FP: 0, FN: 5, Threshold: 0.2973, Rate: 31.45
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 0, TP: 0, FP: 0, FN: 2, Threshold: 0.2805, Rate: 8.75
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 1, TP: 3, FP: 0, FN: 5, Threshold: 0.2859, Rate: 26.4
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 2, TP: 1, FP: 0, FN: 0, Threshold: 0.2869, Rate: 40.550000000000004
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 3, TP: 0, FP: 0, FN: 4, Threshold: 0.2806, Rate: 13.350000000000001
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 4, TP: 1, FP: 0, FN: 1, Threshold: 0.2918, Rate: 23.099999999999998
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 5, TP: 4, FP: 0, FN: 13, Threshold: 0.303, Rate: 27.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 6, TP: 2, FP: 0, FN: 5, Threshold: 0.2936, Rate: 18.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 7, TP: 8, FP: 0, FN: 10, Threshold: 0.2884, Rate: 58.65
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 8, TP: 3, FP: 0, FN: 10, Threshold: 0.2892, Rate: 49.65
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 9, TP: 2, FP: 0, FN: 4, Threshold: 0.2909, Rate: 30.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 10, TP: 4, FP: 1, FN: 6, Threshold: 0.2799, Rate: 40.0
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 11, TP: 8, FP: 0, FN: 7, Threshold: 0.2782, Rate: 40.7
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 12, TP: 1, FP: 0, FN: 13, Threshold: 0.2864, Rate: 64.05
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 13, TP: 4, FP: 0, FN: 10, Threshold: 0.2915, Rate: 70.15
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 6, Window: 14, TP: 3, FP: 0, FN: 6, Threshold: 0.2966, Rate: 40.349999999999994
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 0, TP: 0, FP: 0, FN: 2, Threshold: 0.2623, Rate: 15.15
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 1, TP: 1, FP: 1, FN: 7, Threshold: 0.2678, Rate: 19.8
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 2, TP: 1, FP: 1, FN: 0, Threshold: 0.2726, Rate: 46.199999999999996
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 3, TP: 0, FP: 0, FN: 4, Threshold: 0.2683, Rate: 27.2
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 4, TP: 1, FP: 0, FN: 1, Threshold: 0.2815, Rate: 23.45
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 5, TP: 0, FP: 0, FN: 17, Threshold: 0.2866, Rate: 17.6
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 6, TP: 1, FP: 0, FN: 6, Threshold: 0.2784, Rate: 10.25
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 7, TP: 3, FP: 0, FN: 15, Threshold: 0.2803, Rate: 51.15
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 8, TP: 1, FP: 0, FN: 12, Threshold: 0.2792, Rate: 40.15
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 9, TP: 2, FP: 0, FN: 4, Threshold: 0.2841, Rate: 30.4
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 10, TP: 2, FP: 1, FN: 8, Threshold: 0.2688, Rate: 45.1
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 11, TP: 3, FP: 0, FN: 12, Threshold: 0.2648, Rate: 34.0
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 12, TP: 2, FP: 0, FN: 12, Threshold: 0.2768, Rate: 35.5
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 13, TP: 1, FP: 0, FN: 13, Threshold: 0.2793, Rate: 58.45
# Dataset: Thy7_2020-11-11_16-05-00, Channel: 7, Window: 14, TP: 1, FP: 0, FN: 8, Threshold: 0.2842, Rate: 47.25

# %%
var="FP"
for dataset_name, channels in window_metrics_by_dataset.items():
    plt.figure(figsize=(12, 6))
    plt.title(f"{var} Over Time - {dataset_name}")

    for channel, metrics in channels.items():
        times = np.arange(len(metrics["FP"])) * overlap  # Time in seconds
        plt.plot(times, metrics[f"{var}"], label=f"Channel {channel}")
        

    print(len(channels[0]["TP"]))

    plt.xlabel("Time (s)")
    plt.ylabel(f"{var}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# 48
# 21
# 21
# 15

# %%
colors = plt.cm.tab10.colors  # color palette
# var = "FP"  # Change to "TP", "FN", etc. as needed

threshold_all = []
metric_all = []
dataset_labels = []

for i, dataset_name in enumerate(window_metrics_by_dataset.keys()):
    thresholds_dataset = []
    metric_dataset = []
    for ch in window_metrics_by_dataset[dataset_name].keys():
        thresholds = window_metrics_by_dataset[dataset_name][ch]["threshold"]
        metric_values = window_metrics_by_dataset[dataset_name][ch][var]
        
        if len(thresholds) != len(metric_values):
            print(f"Length mismatch in dataset {dataset_name}, channel {ch}")
            continue
        # Remove any pair where threshold is None
        filtered = [(t, m) for t, m in zip(thresholds, metric_values) if t is not None]

        if not filtered:
            continue  # Skip if nothing remains after filtering
        # Check how many were removed
        num_removed = len(thresholds) - len(filtered)
        if num_removed > 0:
            print(f"Removed {num_removed} entries with None thresholds in dataset {dataset_name}, channel {ch}")
            
        filtered_thresholds, filtered_metrics = zip(*filtered)

        thresholds_dataset.extend(filtered_thresholds)
        metric_dataset.extend(filtered_metrics)
    
    # Accumulate for overall
    threshold_all.extend(thresholds_dataset)
    metric_all.extend(metric_dataset)
    dataset_labels.extend([dataset_name] * len(metric_dataset))

    r_val, p_val = pearsonr(thresholds_dataset, metric_dataset)

    # Plot: threshold on x-axis, metric on y-axis
    plt.figure(figsize=(8, 6))
    plt.scatter(thresholds_dataset, metric_dataset, alpha=0.6, s=30,
                c=colors[i % len(colors)], edgecolors='k')

    # Trendline
    slope, intercept = np.polyfit(thresholds_dataset, metric_dataset, 1)
    x_vals = np.array([min(thresholds_dataset), max(thresholds_dataset)])
    y_vals = slope * x_vals + intercept
    plt.plot(x_vals, y_vals, color='red', linestyle='--', label='Trendline')

    plt.title(f"{dataset_name}: Threshold vs {var}\nr = {r_val:.3f}, p = {p_val:.2e}")
    plt.xlabel("Threshold")
    plt.ylabel(var)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\NCN\AppData\Local\Temp\ipykernel_25964\3517907428.py:42: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(thresholds_dataset, metric_dataset, alpha=0.6, s=30,

# %%
# Overall plot: Threshold vs Metric
plt.figure(figsize=(10, 7))
unique_datasets = list(window_metrics_by_dataset.keys())
for i, dataset_name in enumerate(unique_datasets):
    # Mask for current dataset
    mask = [label == dataset_name for label in dataset_labels]
    plt.scatter(
        [threshold_all[j] for j in range(len(threshold_all)) if mask[j]],
        [metric_all[j] for j in range(len(metric_all)) if mask[j]],
        alpha=0.6, s=30, c=[colors[i % len(colors)]], edgecolors='k', label=dataset_name
    )

# Overall correlation
r_all, p_all = pearsonr(threshold_all, metric_all)
print(f"Overall Pearson r = {r_all:.3f}, p = {p_all:.2e}")
plt.title(f"Overall Threshold vs {var}\nPearson r = {r_all:.3f}, p = {p_all:.2e}")

# Fit and plot overall trendline
slope, intercept = np.polyfit(threshold_all, metric_all, 1)
x_vals = np.array([min(threshold_all), max(threshold_all)])
y_vals = slope * x_vals + intercept
plt.plot(x_vals, y_vals, color='red', linestyle='--', label='Overall Trendline')

plt.xlabel("Threshold")
plt.ylabel(var)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Overall Pearson r = 0.068, p = 4.88e-02

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np

var = "FP"
third_var = "FN"

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Collect all data first
for i, dataset_name in enumerate(window_metrics_by_dataset.keys()):
    thresholds_dataset = []
    metric_dataset = []
    third_dataset = []

    for ch in window_metrics_by_dataset[dataset_name].keys():
        thresholds = window_metrics_by_dataset[dataset_name][ch]["threshold"]
        metric_values = window_metrics_by_dataset[dataset_name][ch][var]
        third_values = window_metrics_by_dataset[dataset_name][ch][third_var]

        if not (len(thresholds) == len(metric_values) == len(third_values)):
            continue

        thresholds_dataset.extend(thresholds)
        metric_dataset.extend(metric_values)
        third_dataset.extend(third_values)

    ax.scatter(
        thresholds_dataset,
        metric_dataset,
        third_dataset,
        color=colors[i % len(colors)],
        label=dataset_name,
        alpha=0.6,
        edgecolor='k',
        s=40
    )

ax.set_xlabel("Threshold")
ax.set_ylabel(var)
ax.set_zlabel(third_var)
ax.set_title(f"3D Plot: Threshold vs {var} vs {third_var}")
ax.legend()

# Animation function
def update(angle):
    ax.view_init(elev=20, azim=angle)
    return fig,

# Animate
ani = FuncAnimation(fig, update, frames=np.arange(0, 360, 2), interval=50)

# To display in Jupyter:
plt.show()

# To save as a video or GIF:
# ani.save("rotation.gif", writer='pillow', fps=20)
# ani.save("rotation.mp4", writer='ffmpeg', fps=20)
