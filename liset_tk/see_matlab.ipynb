# %%
import os 
import numpy as np
import scipy.io as sio

# %%
parent=r"E:\neurospark_mat\CNN_TRAINING_SESSIONS"

# %%
datasets=os.listdir(parent)
dataset=int(input(f"Choose dataset from {datasets}: "))
data_path=os.path.join(parent,datasets[dataset])
files=os.listdir(data_path)
print(files)
# Out:
# ['info.mat', 'lfp.dat', 'ripples.csv']

# %%
data = sio.loadmat(os.path.join(data_path,files[0]),squeeze_me=True, struct_as_record=False)

# %%
# Access top-level fields
channels = data["neurosparkmat"].channels
shanks   = data["neurosparkmat"].shanks
sf       = data["neurosparkmat"].sf

# %%
data["neurosparkmat"]._fieldnames  # List all field names
# Out:
# ['channels', 'shanks', 'sf', 'spikes', 'IISs', 'ripples']

# %%
IIS=data["neurosparkmat"].IISs

# %%
dir(IIS)
# Out:
# ['SD',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_fieldnames',
#  'signal',
#  'times']

# %%
print(IIS.times)
times=IIS.times
print(times.shape)
# Out:
# [array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)]
# (4,)
